# %% [markdown]
# # PART A:  Linguistic analysis using spaCy
#
# In the first part of the assignment, we focus on an analysis of the sentences in the training data.

# %%
import spacy
import pandas as pd
import string
from collections import Counter
nlp = spacy.load("en_core_web_sm")
punctuations = string.punctuation

# %%
df_file = open("../datas/sentences.txt", encoding='utf-8')
data = df_file.read()
print(data)
# Out:
# children are thought to be aged three , eight , and ten years , alongside an eighteen-month-old baby .
# We mixed different concentrations of ROS with the spores , plated them out on petridishes with an agar-solution where fungus can grow on .
# They feel they are under-represented in higher education and are suffering in a regional economic downturn .
# Especially as it concerns a third party building up its military presence near our borders .
# Police said three children were hospitalised for \" severe dehydration \" .
# Virginia Álvarez , who wrote the report , noted , \" instead of listening to their demands , instead of starting a dialogue , authorities are doing everything they can to impede people from protesting \" .
# US troops and tanks in Poland in 2015 , as part of an earlier deployment under Operation Atlantic Resolve .
# Furthermore , Everson argues the Fox News criteria are not \" objective , \" as Title 11 requires , because they fail to define the terms \" consistently \" and \" recognized \" when referring to polls .
# That decision was the one challenged unsuccessfully in the High Court .
# No injuries or deaths were reported in the attacks from either side , but South Korea evacuated about 80 people in the town of Yeoncheon after at least one shell landed near the area .
# The nonfatal accident left an elderly motorcyclist with broken ribs after he came off his bike avoiding the 170 tonnes of falling debris .
# One driver is accused of moving 34 people , ten of them children , into Austria from Serbia .
# Pavlensky , Oksana , and their two daughters left for Ukraine in mid-December before flying to France .
# Their detention relates to Thursday 's discovery of a lorry full of corpses in Austria .
# Robben signs contract extension with Bayern German football club FC Bayern Munich yesterday announced Dutch winger Arjen Robben has signed a one contract extension until June 2018 .
# Anastasia Slonina , an actress working in a theatre in Moscow called Teatr.doc , known for liberal plays , filed rape charges on Pavlensky and his partner Oksana .
# Bos obtained his doctorate from the University of Copenhagen .
# Criminal suspects in Hungary can generally be held for 72 hours before charge but prosecutors , citing the seriousness of the case , want the period extended .
# These actions threaten our interests , our security .
# WWikinews : What methods and equipment were used for this investigation ?
# Bianchi 's father , Philippe , described his non-progress as a \" daily torture \" .
# Next week , on January 24 , the Supreme Court is due to deliver a decision in a case challenging the government 's right to issue Article 50 — which starts the Brexit negotiations — without the consultation of Parliament .
# Furthermore , the data of radars at Maldives airports have also been analysed and shows no indication of the said flight \" , said Malaysian Transport Minister Hishamuddin Hussein .
# As well as dangerous driving and causing serious injury by dangerous driving he also faces three counts of criminal damage covering the bridge and damaged vehicles .
# All 239 passengers and crew are believed to be dead .
# Bianchi 's helmet became wedged underneath the tractor , causing a diffuse axonal injury , and he fell into a coma .
# Wikinews : Are there plans to follow this research up ?
# It is hard to extrapolate to other ants , as different species lead very different lives .
# Republican Senators set a date of January 27 to repeal Obamacare , according to NBC News .
# Last month the US expelled 35 Russian diplomats accused of espionage , and sanctioned Russian intelligence agencies .
# However , he believes Everson only has a chance of success if he actually files a lawsuit rather than simply complaining to the FEC .
# Due to his severe deterioration , Israel was forced to hospitalize him , and placed him in Assaf Harofe hospital in Israel .
# A team was duly dispatched and prepared a report with the intent to use it for assisting the victims ' families .
# At the time of the murders , Conley was wanted on an assault charge against a family member .
# At the moment it seems that sick ants mostly take care of the problem themselves .
# UK judge withholds report from Thai death penalty defendants In a judgement released today Mr Justice Green , sitting in the High Court in London , spoke of his \" very considerable unease \" as he rejected an application by two defendants in a Thai death penalty case .
# Some ants were infected with Beauveria bassiana , a fungus .
# I still have some questions left unanswered from my Ph . D. work related to how ants recognize who is a friend and who is n't .
# The Krone published an image of a non-articulated food lorry on the hard shoulder , which they report is the vehicle in question .
# Burmese nationals Zaw Lin and Wai Phyo , both 22 , are currently on trial accused of murdering David Miller , 24 , from Jersey , and Hannah Witheridge , 23 , from England .
# The driver , from Romania , refused to stop for police and was arrested following a chase .
# By adding certain chemicals , the ROS can be measured using the emission of light of a certain wave-length .
# The theatre claims to have a CCTV video footage of Pavlensky and other men beating Slonina 's boyfriend in the parking lot on October 31 .
# US economy adds 215,000 jobs in July ; unemployment rate remains steady at 5.3 % The Bureau of Labor Statistics reported that the US economy added 215,000 jobs in July .
# The camp was formed as part of a disputed ceasefire .
# In 2004 , he attended the opening of the Kaesong Industrial Region , a joint venture of the two nations .
# The Royal Thai Air Force asked that images of the accident not be shared , but this has not deterred the press .
# On Sunday , Bayern announced signings of 21-year-old Niklas Süle and 26-year-old Sebastian Rudy from TSG 1899 Hoffenheim who are to join the Bayern squad in July .
# This made only the fourth time in U.S. history that this modified form , the Medal of Freedom with distinction , has been awarded .
# Conley also felt all the victims disrespected and mistreated him .
# The study covered many parts of the brain already known to be associated with feeding , and the results suggested some areas are associated with both hunting and feeding and others only with just one behavior .
# He was elected last year and was previously the Chief Minister of Gujarat for more than twelve years .
# Following Apollo 17 , Cernan worked on the Apollo-Soyuz project before retiring from NASA and the Navy in 1976 .
# Manning was convicted in 2013 of 22 charges , including espionage , but acquitted of aiding the enemy .
# How common are they in the wild ?

# %%
doc = nlp(data) # nlp object is used to create documents with linguistic annotations

# %% [markdown]
# ### 1. Tokenization

# %%
def tokenization(text):
    
    token_list = []
    
    for token in text:
        token_list.append(token.text)
        
    return token_list

# %%
tokenization(doc)
# Out:
# ['children',
#  'are',
#  'thought',
#  'to',
#  'be',
#  'aged',
#  'three',
#  ',',
#  'eight',
#  ',',
#  'and',
#  'ten',
#  'years',
#  ',',
#  'alongside',
#  'an',
#  'eighteen',
#  '-',
#  'month',
#  '-',
#  'old',
#  'baby',
#  '.',
#  '\n',
#  'We',
#  'mixed',
#  'different',
#  'concentrations',
#  'of',
#  'ROS',
#  'with',
#  'the',
#  'spores',
#  ',',
#  'plated',
#  'them',
#  'out',
#  'on',
#  'petridishes',
#  'with',
#  'an',
#  'agar',
#  '-',
#  'solution',
#  'where',
#  'fungus',
#  'can',
#  'grow',
#  'on',
#  '.',
#  '\n',
#  'They',
#  'feel',
#  'they',
#  'are',
#  'under',
#  '-',
#  'represented',
#  'in',
#  'higher',
#  'education',
#  'and',
#  'are',
#  'suffering',
#  'in',
#  'a',
#  'regional',
#  'economic',
#  'downturn',
#  '.',
#  '\n',
#  'Especially',
#  'as',
#  'it',
#  'concerns',
#  'a',
#  'third',
#  'party',
#  'building',
#  'up',
#  'its',
#  'military',
#  'presence',
#  'near',
#  'our',
#  'borders',
#  '.',
#  '\n',
#  'Police',
#  'said',
#  'three',
#  'children',
#  'were',
#  'hospitalised',
#  'for',
#  '\\',
#  '"',
#  'severe',
#  'dehydration',
#  '\\',
#  '"',
#  '.',
#  '\n',
#  'Virginia',
#  'Álvarez',
#  ',',
#  'who',
#  'wrote',
#  'the',
#  'report',
#  ',',
#  'noted',
#  ',',
#  '\\',
#  '"',
#  'instead',
#  'of',
#  'listening',
#  'to',
#  'their',
#  'demands',
#  ',',
#  'instead',
#  'of',
#  'starting',
#  'a',
#  'dialogue',
#  ',',
#  'authorities',
#  'are',
#  'doing',
#  'everything',
#  'they',
#  'can',
#  'to',
#  'impede',
#  'people',
#  'from',
#  'protesting',
#  '\\',
#  '"',
#  '.',
#  '\n',
#  'US',
#  'troops',
#  'and',
#  'tanks',
#  'in',
#  'Poland',
#  'in',
#  '2015',
#  ',',
#  'as',
#  'part',
#  'of',
#  'an',
#  'earlier',
#  'deployment',
#  'under',
#  'Operation',
#  'Atlantic',
#  'Resolve',
#  '.',
#  '\n',
#  'Furthermore',
#  ',',
#  'Everson',
#  'argues',
#  'the',
#  'Fox',
#  'News',
#  'criteria',
#  'are',
#  'not',
#  '\\',
#  '"',
#  'objective',
#  ',',
#  '\\',
#  '"',
#  'as',
#  'Title',
#  '11',
#  'requires',
#  ',',
#  'because',
#  'they',
#  'fail',
#  'to',
#  'define',
#  'the',
#  'terms',
#  '\\',
#  '"',
#  'consistently',
#  '\\',
#  '"',
#  'and',
#  '\\',
#  '"',
#  'recognized',
#  '\\',
#  '"',
#  'when',
#  'referring',
#  'to',
#  'polls',
#  '.',
#  '\n',
#  'That',
#  'decision',
#  'was',
#  'the',
#  'one',
#  'challenged',
#  'unsuccessfully',
#  'in',
#  'the',
#  'High',
#  'Court',
#  '.',
#  '\n',
#  'No',
#  'injuries',
#  'or',
#  'deaths',
#  'were',
#  'reported',
#  'in',
#  'the',
#  'attacks',
#  'from',
#  'either',
#  'side',
#  ',',
#  'but',
#  'South',
#  'Korea',
#  'evacuated',
#  'about',
#  '80',
#  'people',
#  'in',
#  'the',
#  'town',
#  'of',
#  'Yeoncheon',
#  'after',
#  'at',
#  'least',
#  'one',
#  'shell',
#  'landed',
#  'near',
#  'the',
#  'area',
#  '.',
#  '\n',
#  'The',
#  'nonfatal',
#  'accident',
#  'left',
#  'an',
#  'elderly',
#  'motorcyclist',
#  'with',
#  'broken',
#  'ribs',
#  'after',
#  'he',
#  'came',
#  'off',
#  'his',
#  'bike',
#  'avoiding',
#  'the',
#  '170',
#  'tonnes',
#  'of',
#  'falling',
#  'debris',
#  '.',
#  '\n',
#  'One',
#  'driver',
#  'is',
#  'accused',
#  'of',
#  'moving',
#  '34',
#  'people',
#  ',',
#  'ten',
#  'of',
#  'them',
#  'children',
#  ',',
#  'into',
#  'Austria',
#  'from',
#  'Serbia',
#  '.',
#  '\n',
#  'Pavlensky',
#  ',',
#  'Oksana',
#  ',',
#  'and',
#  'their',
#  'two',
#  'daughters',
#  'left',
#  'for',
#  'Ukraine',
#  'in',
#  'mid',
#  '-',
#  'December',
#  'before',
#  'flying',
#  'to',
#  'France',
#  '.',
#  '\n',
#  'Their',
#  'detention',
#  'relates',
#  'to',
#  'Thursday',
#  "'s",
#  'discovery',
#  'of',
#  'a',
#  'lorry',
#  'full',
#  'of',
#  'corpses',
#  'in',
#  'Austria',
#  '.',
#  '\n',
#  'Robben',
#  'signs',
#  'contract',
#  'extension',
#  'with',
#  'Bayern',
#  'German',
#  'football',
#  'club',
#  'FC',
#  'Bayern',
#  'Munich',
#  'yesterday',
#  'announced',
#  'Dutch',
#  'winger',
#  'Arjen',
#  'Robben',
#  'has',
#  'signed',
#  'a',
#  'one',
#  'contract',
#  'extension',
#  'until',
#  'June',
#  '2018',
#  '.',
#  '\n',
#  'Anastasia',
#  'Slonina',
#  ',',
#  'an',
#  'actress',
#  'working',
#  'in',
#  'a',
#  'theatre',
#  'in',
#  'Moscow',
#  'called',
#  'Teatr.doc',
#  ',',
#  'known',
#  'for',
#  'liberal',
#  'plays',
#  ',',
#  'filed',
#  'rape',
#  'charges',
#  'on',
#  'Pavlensky',
#  'and',
#  'his',
#  'partner',
#  'Oksana',
#  '.',
#  '\n',
#  'Bos',
#  'obtained',
#  'his',
#  'doctorate',
#  'from',
#  'the',
#  'University',
#  'of',
#  'Copenhagen',
#  '.',
#  '\n',
#  'Criminal',
#  'suspects',
#  'in',
#  'Hungary',
#  'can',
#  'generally',
#  'be',
#  'held',
#  'for',
#  '72',
#  'hours',
#  'before',
#  'charge',
#  'but',
#  'prosecutors',
#  ',',
#  'citing',
#  'the',
#  'seriousness',
#  'of',
#  'the',
#  'case',
#  ',',
#  'want',
#  'the',
#  'period',
#  'extended',
#  '.',
#  '\n',
#  'These',
#  'actions',
#  'threaten',
#  'our',
#  'interests',
#  ',',
#  'our',
#  'security',
#  '.',
#  '\n',
#  'WWikinews',
#  ':',
#  'What',
#  'methods',
#  'and',
#  'equipment',
#  'were',
#  'used',
#  'for',
#  'this',
#  'investigation',
#  '?',
#  '\n',
#  'Bianchi',
#  "'s",
#  'father',
#  ',',
#  'Philippe',
#  ',',
#  'described',
#  'his',
#  'non',
#  '-',
#  'progress',
#  'as',
#  'a',
#  '\\',
#  '"',
#  'daily',
#  'torture',
#  '\\',
#  '"',
#  '.',
#  '\n',
#  'Next',
#  'week',
#  ',',
#  'on',
#  'January',
#  '24',
#  ',',
#  'the',
#  'Supreme',
#  'Court',
#  'is',
#  'due',
#  'to',
#  'deliver',
#  'a',
#  'decision',
#  'in',
#  'a',
#  'case',
#  'challenging',
#  'the',
#  'government',
#  "'s",
#  'right',
#  'to',
#  'issue',
#  'Article',
#  '50',
#  '—',
#  'which',
#  'starts',
#  'the',
#  'Brexit',
#  'negotiations',
#  '—',
#  'without',
#  'the',
#  'consultation',
#  'of',
#  'Parliament',
#  '.',
#  '\n',
#  'Furthermore',
#  ',',
#  'the',
#  'data',
#  'of',
#  'radars',
#  'at',
#  'Maldives',
#  'airports',
#  'have',
#  'also',
#  'been',
#  'analysed',
#  'and',
#  'shows',
#  'no',
#  'indication',
#  'of',
#  'the',
#  'said',
#  'flight',
#  '\\',
#  '"',
#  ',',
#  'said',
#  'Malaysian',
#  'Transport',
#  'Minister',
#  'Hishamuddin',
#  'Hussein',
#  '.',
#  '\n',
#  'As',
#  'well',
#  'as',
#  'dangerous',
#  'driving',
#  'and',
#  'causing',
#  'serious',
#  'injury',
#  'by',
#  'dangerous',
#  'driving',
#  'he',
#  'also',
#  'faces',
#  'three',
#  'counts',
#  'of',
#  'criminal',
#  'damage',
#  'covering',
#  'the',
#  'bridge',
#  'and',
#  'damaged',
#  'vehicles',
#  '.',
#  '\n',
#  'All',
#  '239',
#  'passengers',
#  'and',
#  'crew',
#  'are',
#  'believed',
#  'to',
#  'be',
#  'dead',
#  '.',
#  '\n',
#  'Bianchi',
#  "'s",
#  'helmet',
#  'became',
#  'wedged',
#  'underneath',
#  'the',
#  'tractor',
#  ',',
#  'causing',
#  'a',
#  'diffuse',
#  'axonal',
#  'injury',
#  ',',
#  'and',
#  'he',
#  'fell',
#  'into',
#  'a',
#  'coma',
#  '.',
#  '\n',
#  'Wikinews',
#  ':',
#  'Are',
#  'there',
#  'plans',
#  'to',
#  'follow',
#  'this',
#  'research',
#  'up',
#  '?',
#  '\n',
#  'It',
#  'is',
#  'hard',
#  'to',
#  'extrapolate',
#  'to',
#  'other',
#  'ants',
#  ',',
#  'as',
#  'different',
#  'species',
#  'lead',
#  'very',
#  'different',
#  'lives',
#  '.',
#  '\n',
#  'Republican',
#  'Senators',
#  'set',
#  'a',
#  'date',
#  'of',
#  'January',
#  '27',
#  'to',
#  'repeal',
#  'Obamacare',
#  ',',
#  'according',
#  'to',
#  'NBC',
#  'News',
#  '.',
#  '\n',
#  'Last',
#  'month',
#  'the',
#  'US',
#  'expelled',
#  '35',
#  'Russian',
#  'diplomats',
#  'accused',
#  'of',
#  'espionage',
#  ',',
#  'and',
#  'sanctioned',
#  'Russian',
#  'intelligence',
#  'agencies',
#  '.',
#  '\n',
#  'However',
#  ',',
#  'he',
#  'believes',
#  'Everson',
#  'only',
#  'has',
#  'a',
#  'chance',
#  'of',
#  'success',
#  'if',
#  'he',
#  'actually',
#  'files',
#  'a',
#  'lawsuit',
#  'rather',
#  'than',
#  'simply',
#  'complaining',
#  'to',
#  'the',
#  'FEC',
#  '.',
#  '\n',
#  'Due',
#  'to',
#  'his',
#  'severe',
#  'deterioration',
#  ',',
#  'Israel',
#  'was',
#  'forced',
#  'to',
#  'hospitalize',
#  'him',
#  ',',
#  'and',
#  'placed',
#  'him',
#  'in',
#  'Assaf',
#  'Harofe',
#  'hospital',
#  'in',
#  'Israel',
#  '.',
#  '\n',
#  'A',
#  'team',
#  'was',
#  'duly',
#  'dispatched',
#  'and',
#  'prepared',
#  'a',
#  'report',
#  'with',
#  'the',
#  'intent',
#  'to',
#  'use',
#  'it',
#  'for',
#  'assisting',
#  'the',
#  'victims',
#  "'",
#  'families',
#  '.',
#  '\n',
#  'One',
#  'set',
#  'stimulated',
#  'prey',
#  'pursuit',
#  'behavior',
#  ',',
#  'such',
#  'as',
#  'stalking',
#  ',',
#  'and',
#  'the',
#  'other',
#  'stimulated',
#  'the',
#  'animal',
#  'to',
#  'use',
#  'its',
#  'jaw',
#  'and',
#  'neck',
#  'muscles',
#  '.',
#  '\n',
#  'May',
#  "'s",
#  'speech',
#  'stressed',
#  'the',
#  'need',
#  'for',
#  'friendliness',
#  'between',
#  'Britain',
#  'and',
#  'the',
#  'EU',
#  'but',
#  'also',
#  'ruled',
#  'out',
#  'any',
#  'deal',
#  'that',
#  'did',
#  'not',
#  'allow',
#  'the',
#  'British',
#  'government',
#  'to',
#  'control',
#  'immigration',
#  ',',
#  'or',
#  'which',
#  'would',
#  'require',
#  'Britain',
#  'to',
#  'continue',
#  'being',
#  'bound',
#  'by',
#  'decisions',
#  'of',
#  'the',
#  'European',
#  'Court',
#  'of',
#  'Justice',
#  '.',
#  '\n',
#  'We',
#  "'re",
#  'working',
#  'with',
#  'legislative',
#  'leaders',
#  'at',
#  'this',
#  'very',
#  'moment',
#  'to',
#  'begin',
#  'to',
#  'craft',
#  'legislation',
#  'that',
#  'will',
#  'repeal',
#  'the',
#  'most',
#  'corrosive',
#  'elements',
#  'of',
#  'Obamacare',
#  '—',
#  'the',
#  'individual',
#  'mandate',
#  ',',
#  'the',
#  'taxes',
#  ',',
#  'the',
#  'penalties',
#  '—',
#  'but',
#  'at',
#  'the',
#  'same',
#  'time',
#  ',',
#  'moving',
#  'separate',
#  'legislation',
#  'that',
#  'will',
#  'allow',
#  'us',
#  'to',
#  'introduce',
#  'the',
#  'kind',
#  'of',
#  'reforms',
#  'in',
#  'American',
#  'health',
#  'care',
#  'that',
#  "'ll",
#  'lower',
#  'the',
#  'cost',
#  'of',
#  'health',
#  'insurance',
#  'without',
#  'growing',
#  'the',
#  'size',
#  'of',
#  'government',
#  ',',
#  '\\',
#  '"',
#  'said',
#  'Vice',
#  'President',
#  '-',
#  'elect',
#  'Mike',
#  'Pence',
#  '.',
#  '\n',
#  'The',
#  'JAS',
#  '39C',
#  'Gripen',
#  'crashed',
#  'onto',
#  'a',
#  'runway',
#  'at',
#  'around',
#  '9:30',
#  'am',
#  'local',
#  'time',
#  '(',
#  '0230',
#  'UTC',
#  ')',
#  'and',
#  'exploded',
#  ',',
#  'closing',
#  'the',
#  'airport',
#  'to',
#  'commercial',
#  'flights',
#  '.',
#  '\n',
#  'After',
#  'the',
#  'service',
#  ',',
#  'Black',
#  'was',
#  'to',
#  'be',
#  'interred',
#  'in',
#  'a',
#  'private',
#  'ceremony',
#  ',',
#  'next',
#  'to',
#  'the',
#  'graves',
#  'of',
#  'her',
#  'parents',
#  'at',
#  'the',
#  'Allerton',
#  'cemetery',
#  '.',
#  '\n',
#  'Other',
#  'planned',
#  'host',
#  'nations',
#  'are',
#  'Estonia',
#  ',',
#  'Latvia',
#  ',',
#  'Lithuania',
#  ',',
#  'Romania',
#  ',',
#  'Bulgaria',
#  ',',
#  'and',
#  'Hungary',
#  '.',
#  '\n',
#  'Tomasz',
#  'Szatkowski',
#  ',',
#  'Polish',
#  'Undersecretary',
#  ...]

# %%
def num_of_tokens(text):
    
    total_token = 0
    for token in text:
        total_token += 1
    
    return total_token

# %%
num_of_tokens(doc) # 16130 tokens
# Out:
# 16130

# %%
def num_of_types(text):
    
    """
    Type is different from the number of actual occurrences which would be known as tokens.
    """
    
    token_list = set(tokenization(text))
    return len(token_list)

# %%
num_of_types(doc) # 3746 types
# Out:
# 3746

# %%
def num_of_words(text):
    
    """
    A word is a speech sound or a combination of sounds, or its representation in writing, 
    that symbolizes and communicates a meaning and may consist of a single morpheme or a combination of morphemes.
    """
    
    total_words = 0
    words = []
    
    for token in text:
        if token.text not in punctuations and token.text != '\n':
            total_words += 1
            words.append(token.text)
    
    return total_words, words

# %%
num_of_words(doc)# 13265 words
# Out:
# (13265,
#  ['children',
#   'are',
#   'thought',
#   'to',
#   'be',
#   'aged',
#   'three',
#   'eight',
#   'and',
#   'ten',
#   'years',
#   'alongside',
#   'an',
#   'eighteen',
#   'month',
#   'old',
#   'baby',
#   'We',
#   'mixed',
#   'different',
#   'concentrations',
#   'of',
#   'ROS',
#   'with',
#   'the',
#   'spores',
#   'plated',
#   'them',
#   'out',
#   'on',
#   'petridishes',
#   'with',
#   'an',
#   'agar',
#   'solution',
#   'where',
#   'fungus',
#   'can',
#   'grow',
#   'on',
#   'They',
#   'feel',
#   'they',
#   'are',
#   'under',
#   'represented',
#   'in',
#   'higher',
#   'education',
#   'and',
#   'are',
#   'suffering',
#   'in',
#   'a',
#   'regional',
#   'economic',
#   'downturn',
#   'Especially',
#   'as',
#   'it',
#   'concerns',
#   'a',
#   'third',
#   'party',
#   'building',
#   'up',
#   'its',
#   'military',
#   'presence',
#   'near',
#   'our',
#   'borders',
#   'Police',
#   'said',
#   'three',
#   'children',
#   'were',
#   'hospitalised',
#   'for',
#   'severe',
#   'dehydration',
#   'Virginia',
#   'Álvarez',
#   'who',
#   'wrote',
#   'the',
#   'report',
#   'noted',
#   'instead',
#   'of',
#   'listening',
#   'to',
#   'their',
#   'demands',
#   'instead',
#   'of',
#   'starting',
#   'a',
#   'dialogue',
#   'authorities',
#   'are',
#   'doing',
#   'everything',
#   'they',
#   'can',
#   'to',
#   'impede',
#   'people',
#   'from',
#   'protesting',
#   'US',
#   'troops',
#   'and',
#   'tanks',
#   'in',
#   'Poland',
#   'in',
#   '2015',
#   'as',
#   'part',
#   'of',
#   'an',
#   'earlier',
#   'deployment',
#   'under',
#   'Operation',
#   'Atlantic',
#   'Resolve',
#   'Furthermore',
#   'Everson',
#   'argues',
#   'the',
#   'Fox',
#   'News',
#   'criteria',
#   'are',
#   'not',
#   'objective',
#   'as',
#   'Title',
#   '11',
#   'requires',
#   'because',
#   'they',
#   'fail',
#   'to',
#   'define',
#   'the',
#   'terms',
#   'consistently',
#   'and',
#   'recognized',
#   'when',
#   'referring',
#   'to',
#   'polls',
#   'That',
#   'decision',
#   'was',
#   'the',
#   'one',
#   'challenged',
#   'unsuccessfully',
#   'in',
#   'the',
#   'High',
#   'Court',
#   'No',
#   'injuries',
#   'or',
#   'deaths',
#   'were',
#   'reported',
#   'in',
#   'the',
#   'attacks',
#   'from',
#   'either',
#   'side',
#   'but',
#   'South',
#   'Korea',
#   'evacuated',
#   'about',
#   '80',
#   'people',
#   'in',
#   'the',
#   'town',
#   'of',
#   'Yeoncheon',
#   'after',
#   'at',
#   'least',
#   'one',
#   'shell',
#   'landed',
#   'near',
#   'the',
#   'area',
#   'The',
#   'nonfatal',
#   'accident',
#   'left',
#   'an',
#   'elderly',
#   'motorcyclist',
#   'with',
#   'broken',
#   'ribs',
#   'after',
#   'he',
#   'came',
#   'off',
#   'his',
#   'bike',
#   'avoiding',
#   'the',
#   '170',
#   'tonnes',
#   'of',
#   'falling',
#   'debris',
#   'One',
#   'driver',
#   'is',
#   'accused',
#   'of',
#   'moving',
#   '34',
#   'people',
#   'ten',
#   'of',
#   'them',
#   'children',
#   'into',
#   'Austria',
#   'from',
#   'Serbia',
#   'Pavlensky',
#   'Oksana',
#   'and',
#   'their',
#   'two',
#   'daughters',
#   'left',
#   'for',
#   'Ukraine',
#   'in',
#   'mid',
#   'December',
#   'before',
#   'flying',
#   'to',
#   'France',
#   'Their',
#   'detention',
#   'relates',
#   'to',
#   'Thursday',
#   "'s",
#   'discovery',
#   'of',
#   'a',
#   'lorry',
#   'full',
#   'of',
#   'corpses',
#   'in',
#   'Austria',
#   'Robben',
#   'signs',
#   'contract',
#   'extension',
#   'with',
#   'Bayern',
#   'German',
#   'football',
#   'club',
#   'FC',
#   'Bayern',
#   'Munich',
#   'yesterday',
#   'announced',
#   'Dutch',
#   'winger',
#   'Arjen',
#   'Robben',
#   'has',
#   'signed',
#   'a',
#   'one',
#   'contract',
#   'extension',
#   'until',
#   'June',
#   '2018',
#   'Anastasia',
#   'Slonina',
#   'an',
#   'actress',
#   'working',
#   'in',
#   'a',
#   'theatre',
#   'in',
#   'Moscow',
#   'called',
#   'Teatr.doc',
#   'known',
#   'for',
#   'liberal',
#   'plays',
#   'filed',
#   'rape',
#   'charges',
#   'on',
#   'Pavlensky',
#   'and',
#   'his',
#   'partner',
#   'Oksana',
#   'Bos',
#   'obtained',
#   'his',
#   'doctorate',
#   'from',
#   'the',
#   'University',
#   'of',
#   'Copenhagen',
#   'Criminal',
#   'suspects',
#   'in',
#   'Hungary',
#   'can',
#   'generally',
#   'be',
#   'held',
#   'for',
#   '72',
#   'hours',
#   'before',
#   'charge',
#   'but',
#   'prosecutors',
#   'citing',
#   'the',
#   'seriousness',
#   'of',
#   'the',
#   'case',
#   'want',
#   'the',
#   'period',
#   'extended',
#   'These',
#   'actions',
#   'threaten',
#   'our',
#   'interests',
#   'our',
#   'security',
#   'WWikinews',
#   'What',
#   'methods',
#   'and',
#   'equipment',
#   'were',
#   'used',
#   'for',
#   'this',
#   'investigation',
#   'Bianchi',
#   "'s",
#   'father',
#   'Philippe',
#   'described',
#   'his',
#   'non',
#   'progress',
#   'as',
#   'a',
#   'daily',
#   'torture',
#   'Next',
#   'week',
#   'on',
#   'January',
#   '24',
#   'the',
#   'Supreme',
#   'Court',
#   'is',
#   'due',
#   'to',
#   'deliver',
#   'a',
#   'decision',
#   'in',
#   'a',
#   'case',
#   'challenging',
#   'the',
#   'government',
#   "'s",
#   'right',
#   'to',
#   'issue',
#   'Article',
#   '50',
#   '—',
#   'which',
#   'starts',
#   'the',
#   'Brexit',
#   'negotiations',
#   '—',
#   'without',
#   'the',
#   'consultation',
#   'of',
#   'Parliament',
#   'Furthermore',
#   'the',
#   'data',
#   'of',
#   'radars',
#   'at',
#   'Maldives',
#   'airports',
#   'have',
#   'also',
#   'been',
#   'analysed',
#   'and',
#   'shows',
#   'no',
#   'indication',
#   'of',
#   'the',
#   'said',
#   'flight',
#   'said',
#   'Malaysian',
#   'Transport',
#   'Minister',
#   'Hishamuddin',
#   'Hussein',
#   'As',
#   'well',
#   'as',
#   'dangerous',
#   'driving',
#   'and',
#   'causing',
#   'serious',
#   'injury',
#   'by',
#   'dangerous',
#   'driving',
#   'he',
#   'also',
#   'faces',
#   'three',
#   'counts',
#   'of',
#   'criminal',
#   'damage',
#   'covering',
#   'the',
#   'bridge',
#   'and',
#   'damaged',
#   'vehicles',
#   'All',
#   '239',
#   'passengers',
#   'and',
#   'crew',
#   'are',
#   'believed',
#   'to',
#   'be',
#   'dead',
#   'Bianchi',
#   "'s",
#   'helmet',
#   'became',
#   'wedged',
#   'underneath',
#   'the',
#   'tractor',
#   'causing',
#   'a',
#   'diffuse',
#   'axonal',
#   'injury',
#   'and',
#   'he',
#   'fell',
#   'into',
#   'a',
#   'coma',
#   'Wikinews',
#   'Are',
#   'there',
#   'plans',
#   'to',
#   'follow',
#   'this',
#   'research',
#   'up',
#   'It',
#   'is',
#   'hard',
#   'to',
#   'extrapolate',
#   'to',
#   'other',
#   'ants',
#   'as',
#   'different',
#   'species',
#   'lead',
#   'very',
#   'different',
#   'lives',
#   'Republican',
#   'Senators',
#   'set',
#   'a',
#   'date',
#   'of',
#   'January',
#   '27',
#   'to',
#   'repeal',
#   'Obamacare',
#   'according',
#   'to',
#   'NBC',
#   'News',
#   'Last',
#   'month',
#   'the',
#   'US',
#   'expelled',
#   '35',
#   'Russian',
#   'diplomats',
#   'accused',
#   'of',
#   'espionage',
#   'and',
#   'sanctioned',
#   'Russian',
#   'intelligence',
#   'agencies',
#   'However',
#   'he',
#   'believes',
#   'Everson',
#   'only',
#   'has',
#   'a',
#   'chance',
#   'of',
#   'success',
#   'if',
#   'he',
#   'actually',
#   'files',
#   'a',
#   'lawsuit',
#   'rather',
#   'than',
#   'simply',
#   'complaining',
#   'to',
#   'the',
#   'FEC',
#   'Due',
#   'to',
#   'his',
#   'severe',
#   'deterioration',
#   'Israel',
#   'was',
#   'forced',
#   'to',
#   'hospitalize',
#   'him',
#   'and',
#   'placed',
#   'him',
#   'in',
#   'Assaf',
#   'Harofe',
#   'hospital',
#   'in',
#   'Israel',
#   'A',
#   'team',
#   'was',
#   'duly',
#   'dispatched',
#   'and',
#   'prepared',
#   'a',
#   'report',
#   'with',
#   'the',
#   'intent',
#   'to',
#   'use',
#   'it',
#   'for',
#   'assisting',
#   'the',
#   'victims',
#   'families',
#   'One',
#   'set',
#   'stimulated',
#   'prey',
#   'pursuit',
#   'behavior',
#   'such',
#   'as',
#   'stalking',
#   'and',
#   'the',
#   'other',
#   'stimulated',
#   'the',
#   'animal',
#   'to',
#   'use',
#   'its',
#   'jaw',
#   'and',
#   'neck',
#   'muscles',
#   'May',
#   "'s",
#   'speech',
#   'stressed',
#   'the',
#   'need',
#   'for',
#   'friendliness',
#   'between',
#   'Britain',
#   'and',
#   'the',
#   'EU',
#   'but',
#   'also',
#   'ruled',
#   'out',
#   'any',
#   'deal',
#   'that',
#   'did',
#   'not',
#   'allow',
#   'the',
#   'British',
#   'government',
#   'to',
#   'control',
#   'immigration',
#   'or',
#   'which',
#   'would',
#   'require',
#   'Britain',
#   'to',
#   'continue',
#   'being',
#   'bound',
#   'by',
#   'decisions',
#   'of',
#   'the',
#   'European',
#   'Court',
#   'of',
#   'Justice',
#   'We',
#   "'re",
#   'working',
#   'with',
#   'legislative',
#   'leaders',
#   'at',
#   'this',
#   'very',
#   'moment',
#   'to',
#   'begin',
#   'to',
#   'craft',
#   'legislation',
#   'that',
#   'will',
#   'repeal',
#   'the',
#   'most',
#   'corrosive',
#   'elements',
#   'of',
#   'Obamacare',
#   '—',
#   'the',
#   'individual',
#   'mandate',
#   'the',
#   'taxes',
#   'the',
#   'penalties',
#   '—',
#   'but',
#   'at',
#   'the',
#   'same',
#   'time',
#   'moving',
#   'separate',
#   'legislation',
#   'that',
#   'will',
#   'allow',
#   'us',
#   'to',
#   'introduce',
#   'the',
#   'kind',
#   'of',
#   'reforms',
#   'in',
#   'American',
#   'health',
#   'care',
#   'that',
#   "'ll",
#   'lower',
#   'the',
#   'cost',
#   'of',
#   'health',
#   'insurance',
#   'without',
#   'growing',
#   'the',
#   'size',
#   'of',
#   'government',
#   'said',
#   'Vice',
#   'President',
#   'elect',
#   'Mike',
#   'Pence',
#   'The',
#   'JAS',
#   '39C',
#   'Gripen',
#   'crashed',
#   'onto',
#   'a',
#   'runway',
#   'at',
#   'around',
#   '9:30',
#   'am',
#   'local',
#   'time',
#   '0230',
#   'UTC',
#   'and',
#   'exploded',
#   'closing',
#   'the',
#   'airport',
#   'to',
#   'commercial',
#   'flights',
#   'After',
#   'the',
#   'service',
#   'Black',
#   'was',
#   'to',
#   'be',
#   'interred',
#   'in',
#   'a',
#   'private',
#   'ceremony',
#   'next',
#   'to',
#   'the',
#   'graves',
#   'of',
#   'her',
#   'parents',
#   'at',
#   'the',
#   'Allerton',
#   'cemetery',
#   'Other',
#   'planned',
#   'host',
#   'nations',
#   'are',
#   'Estonia',
#   'Latvia',
#   'Lithuania',
#   'Romania',
#   'Bulgaria',
#   'and',
#   'Hungary',
#   'Tomasz',
#   'Szatkowski',
#   'Polish',
#   'Undersecretary',
#   'of',
#   'State',
#   'for',
#   'Defence',
#   'noted',
#   'large',
#   'exercises',
#   'by',
#   'Russia',
#   'near',
#   'the',
#   'Polish',
#   'border',
#   'as',
#   'another',
#   'reason',
#   'the',
#   'troops',
#   'were',
#   'needed',
#   'Wikinews',
#   'Are',
#   'there',
#   'any',
#   'ethical',
#   'considerations',
#   'around',
#   'exposing',
#   'ants',
#   'to',
#   'toxins',
#   'and',
#   'parasites',
#   'His',
#   'most',
#   'recent',
#   'stint',
#   'behind',
#   'bars',
#   'came',
#   'last',
#   'month',
#   'when',
#   'he',
#   'was',
#   'arrested',
#   'for',
#   'allegedly',
#   'slamming',
#   'his',
#   'girlfriend',
#   "'s",
#   'head',
#   'into',
#   'a',
#   'refrigerator',
#   'in',
#   'the',
#   'same',
#   'home',
#   'involved',
#   'on',
#   'Saturday',
#   'In',
#   'yesterday',
#   "'s",
#   'speech',
#   'May',
#   'also',
#   'ruled',
#   'out',
#   'continued',
#   'membership',
#   'of',
#   'the',
#   'customs',
#   'union',
#   'as',
#   'this',
#   'prevented',
#   'Britain',
#   'from',
#   'negotiating',
#   'trade',
#   'deals',
#   'with',
#   'non',
#   'EU',
#   'countries',
#   'She',
#   'posted',
#   'the',
#   'photo',
#   'with',
#   'the',
#   'caption',
#   'Park',
#   'where',
#   'you',
#   'bloody',
#   'well',
#   'please',
#   'and',
#   'you',
#   'wo',
#   "n't",
#   'even',
#   'be',
#   'fined',
#   'Afterwards',
#   'each',
#   'ant',
#   'was',
#   'dipped',
#   'in',
#   'the',
#   'solution',
#   'for',
#   'a',
#   'couple',
#   'of',
#   'seconds',
#   'dried',
#   'on',
#   'a',
#   'cloth',
#   'and',
#   'put',
#   'in',
#   'the',
#   'nest',
#   'Pavlensky',
#   'said',
#   'he',
#   'does',
#   'not',
#   'appear',
#   'in',
#   'the',
#   'video',
#   'Amnesty',
#   'International',
#   'condemned',
#   'the',
#   'law',
#   'in',
#   'a',
#   'report',
#   'With',
#   'threats',
#   'of',
#   'fines',
#   'or',
#   'threats',
#   'of',
#   'being',
#   'beaten',
#   'the',
#   'government',
#   'is',
#   'trying',
#   'to',
#   'stigmatize',
#   'and',
#   'criminalize',
#   'people',
#   'who',
#   'are',
#   'just',
#   'practicing',
#   'their',
#   'rights',
#   ...])

# %%
def average_num_of_words_per_sentence(text):

    words_list = tokenization(text)

    terminals = set([".", "?", "!"])
    terminal_count = 0

    for word in words_list:
        if word in terminals:
            terminal_count += 1


    avg_num_words = (len(words_list) - terminal_count)  / float(terminal_count)
    
    return round(avg_num_words,2) # 23.63 number of words per sentence

# %%
average_num_of_words_per_sentence(doc)
# Out:
# 23.63

# %%
def average_word_length(text):

    words_list = tokenization(text)
    avg_num_words = 0
    
    avg_num_words = sum(len(word) for word in words_list) / len(words_list)            
    
    return round(avg_num_words,2) # 4.21 average word length

# %%
average_word_length(doc)
# Out:
# 4.21

# %% [markdown]
# ### 2. Word Classes
#
# Run the default part-of-speech tagger on the dataset and identify the ten most frequent `POS tags`. Complete the table for these ten tags.

# %%
print(f"TOKEN\tPOS\tTAG".format('Token','Lemma','Pos'))
print("-"*50)

for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# TOKEN	POS	TAG
# --------------------------------------------------
# children NOUN NNS
# are AUX VBP
# thought VERB VBN
# to PART TO
# be AUX VB
# aged VERB VBN
# three NUM CD
# , PUNCT ,
# eight NUM CD
# , PUNCT ,
# and CCONJ CC
# ten NUM CD
# years NOUN NNS
# , PUNCT ,
# alongside ADP IN
# an DET DT
# eighteen NUM CD
# - PUNCT HYPH
# month NOUN NN
# - PUNCT HYPH
# old ADJ JJ
# baby NOUN NN
# . PUNCT .
#
#  SPACE _SP
# We PRON PRP
# mixed VERB VBD
# different ADJ JJ
# concentrations NOUN NNS
# of ADP IN
# ROS PROPN NNP
# with ADP IN
# the DET DT
# spores NOUN NNS
# , PUNCT ,
# plated VERB VBD
# them PRON PRP
# out ADP RP
# on ADP IN
# petridishes NOUN NNS
# with ADP IN
# an DET DT
# agar NOUN NN
# - PUNCT HYPH
# solution NOUN NN
# where SCONJ WRB
# fungus NOUN NN
# can AUX MD
# grow VERB VB
# on ADP RP
# . PUNCT .
#
#  SPACE _SP
# They PRON PRP
# feel VERB VBP
# they PRON PRP
# are AUX VBP
# under ADV RB
# - PUNCT HYPH
# represented VERB VBN
# in ADP IN
# higher ADJ JJR
# education NOUN NN
# and CCONJ CC
# are AUX VBP
# suffering VERB VBG
# in ADP IN
# a DET DT
# regional ADJ JJ
# economic ADJ JJ
# downturn NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Especially ADV RB
# as SCONJ IN
# it PRON PRP
# concerns VERB VBZ
# a DET DT
# third ADJ JJ
# party NOUN NN
# building VERB VBG
# up ADP RP
# its PRON PRP$
# military ADJ JJ
# presence NOUN NN
# near ADP IN
# our PRON PRP$
# borders NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Police PROPN NNP
# said VERB VBD
# three NUM CD
# children NOUN NNS
# were AUX VBD
# hospitalised VERB VBN
# for ADP IN
# \ NOUN NN
# " PUNCT ''
# severe ADJ JJ
# dehydration NOUN NN
# \ NOUN NN
# " PUNCT ''
# . PUNCT .
#
#  SPACE _SP
# Virginia PROPN NNP
# Álvarez PROPN NNP
# , PUNCT ,
# who PRON WP
# wrote VERB VBD
# the DET DT
# report NOUN NN
# , PUNCT ,
# noted VERB VBD
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# instead ADV RB
# of ADP IN
# listening VERB VBG
# to ADP IN
# their PRON PRP$
# demands NOUN NNS
# , PUNCT ,
# instead ADV RB
# of ADP IN
# starting VERB VBG
# a DET DT
# dialogue NOUN NN
# , PUNCT ,
# authorities NOUN NNS
# are AUX VBP
# doing VERB VBG
# everything PRON NN
# they PRON PRP
# can AUX MD
# to PART TO
# impede VERB VB
# people NOUN NNS
# from ADP IN
# protesting VERB VBG
# \ NOUN NN
# " PUNCT ''
# . PUNCT .
#
#  SPACE _SP
# US PROPN NNP
# troops NOUN NNS
# and CCONJ CC
# tanks NOUN NNS
# in ADP IN
# Poland PROPN NNP
# in ADP IN
# 2015 NUM CD
# , PUNCT ,
# as ADP IN
# part NOUN NN
# of ADP IN
# an DET DT
# earlier ADJ JJR
# deployment NOUN NN
# under ADP IN
# Operation PROPN NNP
# Atlantic PROPN NNP
# Resolve PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Furthermore ADV RB
# , PUNCT ,
# Everson PROPN NNP
# argues VERB VBZ
# the DET DT
# Fox PROPN NNP
# News PROPN NNP
# criteria NOUN NNS
# are AUX VBP
# not PART RB
# \ ADJ JJ
# " PUNCT ''
# objective NOUN NN
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# as SCONJ IN
# Title NOUN NN
# 11 NUM CD
# requires VERB VBZ
# , PUNCT ,
# because SCONJ IN
# they PRON PRP
# fail VERB VBP
# to PART TO
# define VERB VB
# the DET DT
# terms NOUN NNS
# \ PROPN NNP
# " PUNCT ''
# consistently ADV RB
# \ PROPN NNP
# " PUNCT ''
# and CCONJ CC
# \ PROPN NNP
# " PUNCT ''
# recognized VERB VBD
# \ PROPN NNP
# " PUNCT ''
# when SCONJ WRB
# referring VERB VBG
# to ADP IN
# polls NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# That DET DT
# decision NOUN NN
# was AUX VBD
# the DET DT
# one NUM CD
# challenged VERB VBN
# unsuccessfully ADV RB
# in ADP IN
# the DET DT
# High PROPN NNP
# Court PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# No DET DT
# injuries NOUN NNS
# or CCONJ CC
# deaths NOUN NNS
# were AUX VBD
# reported VERB VBN
# in ADP IN
# the DET DT
# attacks NOUN NNS
# from ADP IN
# either DET DT
# side NOUN NN
# , PUNCT ,
# but CCONJ CC
# South PROPN NNP
# Korea PROPN NNP
# evacuated VERB VBD
# about ADV RB
# 80 NUM CD
# people NOUN NNS
# in ADP IN
# the DET DT
# town NOUN NN
# of ADP IN
# Yeoncheon PROPN NNP
# after SCONJ IN
# at ADV RB
# least ADV RBS
# one NUM CD
# shell NOUN NN
# landed VERB VBD
# near ADP IN
# the DET DT
# area NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# nonfatal ADJ JJ
# accident NOUN NN
# left VERB VBD
# an DET DT
# elderly ADJ JJ
# motorcyclist NOUN NN
# with ADP IN
# broken ADJ JJ
# ribs NOUN NNS
# after SCONJ IN
# he PRON PRP
# came VERB VBD
# off ADP IN
# his PRON PRP$
# bike NOUN NN
# avoiding VERB VBG
# the DET DT
# 170 NUM CD
# tonnes NOUN NNS
# of ADP IN
# falling VERB VBG
# debris NOUN NN
# . PUNCT .
#
#  SPACE _SP
# One NUM CD
# driver NOUN NN
# is AUX VBZ
# accused VERB VBN
# of ADP IN
# moving VERB VBG
# 34 NUM CD
# people NOUN NNS
# , PUNCT ,
# ten NUM CD
# of ADP IN
# them PRON PRP
# children NOUN NNS
# , PUNCT ,
# into ADP IN
# Austria PROPN NNP
# from ADP IN
# Serbia PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Pavlensky PROPN NNP
# , PUNCT ,
# Oksana PROPN NNP
# , PUNCT ,
# and CCONJ CC
# their PRON PRP$
# two NUM CD
# daughters NOUN NNS
# left VERB VBD
# for ADP IN
# Ukraine PROPN NNP
# in ADP IN
# mid NOUN NN
# - NOUN NN
# December PROPN NNP
# before ADP IN
# flying VERB VBG
# to ADP IN
# France PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Their PRON PRP$
# detention NOUN NN
# relates VERB VBZ
# to ADP IN
# Thursday PROPN NNP
# 's PART POS
# discovery NOUN NN
# of ADP IN
# a DET DT
# lorry NOUN NN
# full ADJ JJ
# of ADP IN
# corpses NOUN NNS
# in ADP IN
# Austria PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Robben PROPN NNP
# signs VERB VBZ
# contract NOUN NN
# extension NOUN NN
# with ADP IN
# Bayern ADJ JJ
# German ADJ JJ
# football NOUN NN
# club NOUN NN
# FC PROPN NNP
# Bayern PROPN NNP
# Munich PROPN NNP
# yesterday NOUN NN
# announced VERB VBD
# Dutch ADJ JJ
# winger NOUN NN
# Arjen PROPN NNP
# Robben PROPN NNP
# has AUX VBZ
# signed VERB VBN
# a DET DT
# one NUM CD
# contract NOUN NN
# extension NOUN NN
# until ADP IN
# June PROPN NNP
# 2018 NUM CD
# . PUNCT .
#
#  SPACE _SP
# Anastasia PROPN NNP
# Slonina PROPN NNP
# , PUNCT ,
# an DET DT
# actress NOUN NN
# working VERB VBG
# in ADP IN
# a DET DT
# theatre NOUN NN
# in ADP IN
# Moscow PROPN NNP
# called VERB VBD
# Teatr.doc PROPN NNP
# , PUNCT ,
# known VERB VBN
# for ADP IN
# liberal ADJ JJ
# plays NOUN NNS
# , PUNCT ,
# filed VERB VBD
# rape NOUN NN
# charges NOUN NNS
# on ADP IN
# Pavlensky PROPN NNP
# and CCONJ CC
# his PRON PRP$
# partner NOUN NN
# Oksana PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Bos PROPN NNP
# obtained VERB VBD
# his PRON PRP$
# doctorate NOUN NN
# from ADP IN
# the DET DT
# University PROPN NNP
# of ADP IN
# Copenhagen PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Criminal ADJ JJ
# suspects NOUN NNS
# in ADP IN
# Hungary PROPN NNP
# can AUX MD
# generally ADV RB
# be AUX VB
# held VERB VBN
# for ADP IN
# 72 NUM CD
# hours NOUN NNS
# before ADP IN
# charge NOUN NN
# but CCONJ CC
# prosecutors NOUN NNS
# , PUNCT ,
# citing VERB VBG
# the DET DT
# seriousness NOUN NN
# of ADP IN
# the DET DT
# case NOUN NN
# , PUNCT ,
# want VERB VBP
# the DET DT
# period NOUN NN
# extended VERB VBN
# . PUNCT .
#
#  SPACE _SP
# These DET DT
# actions NOUN NNS
# threaten VERB VBP
# our PRON PRP$
# interests NOUN NNS
# , PUNCT ,
# our PRON PRP$
# security NOUN NN
# . PUNCT .
#
#  SPACE _SP
# WWikinews PROPN NNPS
# : PUNCT :
# What DET WDT
# methods NOUN NNS
# and CCONJ CC
# equipment NOUN NN
# were AUX VBD
# used VERB VBN
# for ADP IN
# this DET DT
# investigation NOUN NN
# ? PUNCT .
#
#  SPACE _SP
# Bianchi PROPN NNP
# 's PART POS
# father NOUN NN
# , PUNCT ,
# Philippe PROPN NNP
# , PUNCT ,
# described VERB VBD
# his PRON PRP$
# non ADJ JJ
# - ADJ JJ
# progress NOUN NN
# as ADP IN
# a DET DT
# \ PROPN NNP
# " PUNCT ''
# daily ADJ JJ
# torture NOUN NN
# \ NOUN NN
# " PUNCT ''
# . PUNCT .
#
#  SPACE _SP
# Next ADJ JJ
# week NOUN NN
# , PUNCT ,
# on ADP IN
# January PROPN NNP
# 24 NUM CD
# , PUNCT ,
# the DET DT
# Supreme PROPN NNP
# Court PROPN NNP
# is AUX VBZ
# due ADJ JJ
# to PART TO
# deliver VERB VB
# a DET DT
# decision NOUN NN
# in ADP IN
# a DET DT
# case NOUN NN
# challenging VERB VBG
# the DET DT
# government NOUN NN
# 's PART POS
# right NOUN NN
# to PART TO
# issue VERB VB
# Article NOUN NN
# 50 NUM CD
# — PUNCT :
# which PRON WDT
# starts VERB VBZ
# the DET DT
# Brexit PROPN NNP
# negotiations NOUN NNS
# — PUNCT :
# without ADP IN
# the DET DT
# consultation NOUN NN
# of ADP IN
# Parliament PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Furthermore ADV RB
# , PUNCT ,
# the DET DT
# data NOUN NNS
# of ADP IN
# radars NOUN NNS
# at ADP IN
# Maldives PROPN NNP
# airports NOUN NNS
# have AUX VBP
# also ADV RB
# been AUX VBN
# analysed VERB VBN
# and CCONJ CC
# shows VERB VBZ
# no DET DT
# indication NOUN NN
# of ADP IN
# the DET DT
# said VERB VBN
# flight NOUN NN
# \ PROPN NNP
# " PUNCT ''
# , PUNCT ,
# said VERB VBD
# Malaysian ADJ JJ
# Transport PROPN NNP
# Minister PROPN NNP
# Hishamuddin PROPN NNP
# Hussein PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# As ADV RB
# well ADV RB
# as ADP IN
# dangerous ADJ JJ
# driving NOUN NN
# and CCONJ CC
# causing VERB VBG
# serious ADJ JJ
# injury NOUN NN
# by ADP IN
# dangerous ADJ JJ
# driving NOUN NN
# he PRON PRP
# also ADV RB
# faces VERB VBZ
# three NUM CD
# counts NOUN NNS
# of ADP IN
# criminal ADJ JJ
# damage NOUN NN
# covering VERB VBG
# the DET DT
# bridge NOUN NN
# and CCONJ CC
# damaged ADJ JJ
# vehicles NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# All DET DT
# 239 NUM CD
# passengers NOUN NNS
# and CCONJ CC
# crew NOUN NN
# are AUX VBP
# believed VERB VBN
# to PART TO
# be AUX VB
# dead ADJ JJ
# . PUNCT .
#
#  SPACE _SP
# Bianchi PROPN NNP
# 's PART POS
# helmet NOUN NN
# became AUX VBD
# wedged VERB VBN
# underneath ADP IN
# the DET DT
# tractor NOUN NN
# , PUNCT ,
# causing VERB VBG
# a DET DT
# diffuse ADJ JJ
# axonal ADJ JJ
# injury NOUN NN
# , PUNCT ,
# and CCONJ CC
# he PRON PRP
# fell VERB VBD
# into ADP IN
# a DET DT
# coma NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Wikinews PROPN NNP
# : PUNCT :
# Are AUX VBP
# there PRON EX
# plans NOUN NNS
# to PART TO
# follow VERB VB
# this DET DT
# research NOUN NN
# up ADP RP
# ? PUNCT .
#
#  SPACE _SP
# It PRON PRP
# is AUX VBZ
# hard ADJ JJ
# to PART TO
# extrapolate VERB VB
# to ADP IN
# other ADJ JJ
# ants NOUN NNS
# , PUNCT ,
# as SCONJ IN
# different ADJ JJ
# species NOUN NNS
# lead VERB VBP
# very ADV RB
# different ADJ JJ
# lives NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Republican PROPN NNP
# Senators PROPN NNPS
# set VERB VBD
# a DET DT
# date NOUN NN
# of ADP IN
# January PROPN NNP
# 27 NUM CD
# to PART TO
# repeal VERB VB
# Obamacare PROPN NNP
# , PUNCT ,
# according VERB VBG
# to ADP IN
# NBC PROPN NNP
# News PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Last ADJ JJ
# month NOUN NN
# the DET DT
# US PROPN NNP
# expelled VERB VBD
# 35 NUM CD
# Russian ADJ JJ
# diplomats NOUN NNS
# accused VERB VBN
# of ADP IN
# espionage NOUN NN
# , PUNCT ,
# and CCONJ CC
# sanctioned VERB VBN
# Russian ADJ JJ
# intelligence NOUN NN
# agencies NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# However ADV RB
# , PUNCT ,
# he PRON PRP
# believes VERB VBZ
# Everson PROPN NNP
# only ADV RB
# has VERB VBZ
# a DET DT
# chance NOUN NN
# of ADP IN
# success NOUN NN
# if SCONJ IN
# he PRON PRP
# actually ADV RB
# files VERB VBZ
# a DET DT
# lawsuit NOUN NN
# rather ADV RB
# than ADP IN
# simply ADV RB
# complaining VERB VBG
# to ADP IN
# the DET DT
# FEC PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Due ADP IN
# to ADP IN
# his PRON PRP$
# severe ADJ JJ
# deterioration NOUN NN
# , PUNCT ,
# Israel PROPN NNP
# was AUX VBD
# forced VERB VBN
# to PART TO
# hospitalize VERB VB
# him PRON PRP
# , PUNCT ,
# and CCONJ CC
# placed VERB VBD
# him PRON PRP
# in ADP IN
# Assaf PROPN NNP
# Harofe PROPN NNP
# hospital NOUN NN
# in ADP IN
# Israel PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# A DET DT
# team NOUN NN
# was AUX VBD
# duly ADV RB
# dispatched VERB VBN
# and CCONJ CC
# prepared VERB VBD
# a DET DT
# report NOUN NN
# with ADP IN
# the DET DT
# intent NOUN NN
# to PART TO
# use VERB VB
# it PRON PRP
# for ADP IN
# assisting VERB VBG
# the DET DT
# victims NOUN NNS
# ' PART POS
# families NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# One NUM CD
# set NOUN NN
# stimulated VERB VBD
# prey NOUN NN
# pursuit PROPN NNP
# behavior NOUN NN
# , PUNCT ,
# such ADJ JJ
# as ADP IN
# stalking VERB VBG
# , PUNCT ,
# and CCONJ CC
# the DET DT
# other ADJ JJ
# stimulated VERB VBD
# the DET DT
# animal NOUN NN
# to PART TO
# use VERB VB
# its PRON PRP$
# jaw NOUN NN
# and CCONJ CC
# neck NOUN NN
# muscles NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# May PROPN NNP
# 's PART POS
# speech NOUN NN
# stressed VERB VBD
# the DET DT
# need NOUN NN
# for ADP IN
# friendliness NOUN NN
# between ADP IN
# Britain PROPN NNP
# and CCONJ CC
# the DET DT
# EU PROPN NNP
# but CCONJ CC
# also ADV RB
# ruled VERB VBD
# out ADP RP
# any DET DT
# deal NOUN NN
# that PRON WDT
# did AUX VBD
# not PART RB
# allow VERB VB
# the DET DT
# British ADJ JJ
# government NOUN NN
# to PART TO
# control VERB VB
# immigration NOUN NN
# , PUNCT ,
# or CCONJ CC
# which PRON WDT
# would AUX MD
# require VERB VB
# Britain PROPN NNP
# to PART TO
# continue VERB VB
# being AUX VBG
# bound VERB VBN
# by ADP IN
# decisions NOUN NNS
# of ADP IN
# the DET DT
# European PROPN NNP
# Court PROPN NNP
# of ADP IN
# Justice PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# We PRON PRP
# 're AUX VBP
# working VERB VBG
# with ADP IN
# legislative ADJ JJ
# leaders NOUN NNS
# at ADP IN
# this DET DT
# very ADJ JJ
# moment NOUN NN
# to PART TO
# begin VERB VB
# to PART TO
# craft VERB VB
# legislation NOUN NN
# that PRON WDT
# will AUX MD
# repeal VERB VB
# the DET DT
# most ADV RBS
# corrosive ADJ JJ
# elements NOUN NNS
# of ADP IN
# Obamacare PROPN NNP
# — PUNCT :
# the DET DT
# individual ADJ JJ
# mandate NOUN NN
# , PUNCT ,
# the DET DT
# taxes NOUN NNS
# , PUNCT ,
# the DET DT
# penalties NOUN NNS
# — PUNCT :
# but CCONJ CC
# at ADP IN
# the DET DT
# same ADJ JJ
# time NOUN NN
# , PUNCT ,
# moving VERB VBG
# separate ADJ JJ
# legislation NOUN NN
# that PRON WDT
# will AUX MD
# allow VERB VB
# us PRON PRP
# to PART TO
# introduce VERB VB
# the DET DT
# kind NOUN NN
# of ADP IN
# reforms NOUN NNS
# in ADP IN
# American ADJ JJ
# health NOUN NN
# care NOUN NN
# that PRON WDT
# 'll AUX MD
# lower VERB VB
# the DET DT
# cost NOUN NN
# of ADP IN
# health NOUN NN
# insurance NOUN NN
# without ADP IN
# growing VERB VBG
# the DET DT
# size NOUN NN
# of ADP IN
# government NOUN NN
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# said VERB VBD
# Vice PROPN NNP
# President PROPN NNP
# - PUNCT HYPH
# elect PROPN NNP
# Mike PROPN NNP
# Pence PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# JAS PROPN NNP
# 39C NUM CD
# Gripen PROPN NNP
# crashed VERB VBD
# onto ADP IN
# a DET DT
# runway NOUN NN
# at ADP IN
# around ADV RB
# 9:30 NUM CD
# am NOUN NN
# local ADJ JJ
# time NOUN NN
# ( PUNCT -LRB-
# 0230 NUM CD
# UTC PROPN NNP
# ) PUNCT -RRB-
# and CCONJ CC
# exploded VERB VBD
# , PUNCT ,
# closing VERB VBG
# the DET DT
# airport NOUN NN
# to ADP IN
# commercial ADJ JJ
# flights NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# After ADP IN
# the DET DT
# service NOUN NN
# , PUNCT ,
# Black PROPN NNP
# was AUX VBD
# to PART TO
# be AUX VB
# interred VERB VBN
# in ADP IN
# a DET DT
# private ADJ JJ
# ceremony NOUN NN
# , PUNCT ,
# next ADV RB
# to ADP IN
# the DET DT
# graves NOUN NNS
# of ADP IN
# her PRON PRP$
# parents NOUN NNS
# at ADP IN
# the DET DT
# Allerton PROPN NNP
# cemetery NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Other ADJ JJ
# planned ADJ JJ
# host NOUN NN
# nations NOUN NNS
# are AUX VBP
# Estonia PROPN NNP
# , PUNCT ,
# Latvia PROPN NNP
# , PUNCT ,
# Lithuania PROPN NNP
# , PUNCT ,
# Romania PROPN NNP
# , PUNCT ,
# Bulgaria PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Hungary PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Tomasz PROPN NNP
# Szatkowski PROPN NNP
# , PUNCT ,
# Polish PROPN NNP
# Undersecretary PROPN NNP
# of ADP IN
# State PROPN NNP
# for ADP IN
# Defence PROPN NNP
# , PUNCT ,
# noted VERB VBD
# \ PROPN NNP
# " PUNCT ''
# large ADJ JJ
# exercises NOUN NNS
# \ ADJ JJ
# " PUNCT ''
# by ADP IN
# Russia PROPN NNP
# near ADP IN
# the DET DT
# Polish ADJ JJ
# border NOUN NN
# as ADP IN
# another DET DT
# reason NOUN NN
# the DET DT
# troops NOUN NNS
# were AUX VBD
# needed VERB VBN
# . PUNCT .
#
#  SPACE _SP
# Wikinews PROPN NNP
# : PUNCT :
# Are AUX VBP
# there PRON EX
# any DET DT
# ethical ADJ JJ
# considerations NOUN NNS
# around ADP IN
# exposing VERB VBG
# ants NOUN NNS
# to ADP IN
# toxins NOUN NNS
# and CCONJ CC
# parasites NOUN NNS
# ? PUNCT .
#
#  SPACE _SP
# His PRON PRP$
# most ADV RBS
# recent ADJ JJ
# stint NOUN NN
# behind ADP IN
# bars NOUN NNS
# came VERB VBD
# last ADJ JJ
# month NOUN NN
# , PUNCT ,
# when SCONJ WRB
# he PRON PRP
# was AUX VBD
# arrested VERB VBN
# for ADP IN
# allegedly ADV RB
# slamming VERB VBG
# his PRON PRP$
# girlfriend NOUN NN
# 's PART POS
# head NOUN NN
# into ADP IN
# a DET DT
# refrigerator NOUN NN
# in ADP IN
# the DET DT
# same ADJ JJ
# home NOUN NN
# involved VERB VBN
# on ADP IN
# Saturday PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# In ADP IN
# yesterday NOUN NN
# 's PART POS
# speech NOUN NN
# May AUX MD
# also ADV RB
# ruled VERB VBD
# out ADP RP
# continued ADJ JJ
# membership NOUN NN
# of ADP IN
# the DET DT
# customs NOUN NNS
# union NOUN NN
# as SCONJ IN
# this PRON DT
# prevented VERB VBD
# Britain PROPN NNP
# from ADP IN
# negotiating VERB VBG
# trade NOUN NN
# deals NOUN NNS
# with ADP IN
# non ADJ JJ
# - ADJ JJ
# EU ADJ JJ
# countries NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# She PRON PRP
# posted VERB VBD
# the DET DT
# photo NOUN NN
# with ADP IN
# the DET DT
# caption NOUN NN
# : PUNCT :
# \ PROPN NNP
# " PUNCT ''
# Park PROPN NNP
# where SCONJ WRB
# you PRON PRP
# bloody VERB VBP
# well INTJ UH
# please INTJ UH
# and CCONJ CC
# you PRON PRP
# wo AUX MD
# n't PART RB
# even ADV RB
# be AUX VB
# fined VERB VBN
# . PUNCT .
#
#  SPACE _SP
# Afterwards ADV RB
# , PUNCT ,
# each DET DT
# ant NOUN NN
# was AUX VBD
# dipped VERB VBN
# in ADP IN
# the DET DT
# solution NOUN NN
# for ADP IN
# a DET DT
# couple NOUN NN
# of ADP IN
# seconds NOUN NNS
# , PUNCT ,
# dried VERB VBN
# on ADP IN
# a DET DT
# cloth NOUN NN
# and CCONJ CC
# put VERB VBD
# in ADP IN
# the DET DT
# nest NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Pavlensky PROPN NNP
# said VERB VBD
# he PRON PRP
# does AUX VBZ
# not PART RB
# appear VERB VB
# in ADP IN
# the DET DT
# video NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Amnesty PROPN NNP
# International PROPN NNP
# condemned VERB VBD
# the DET DT
# law NOUN NN
# in ADP IN
# a DET DT
# report NOUN NN
# : PUNCT :
# \ PROPN NNP
# " PUNCT ''
# With ADP IN
# threats NOUN NNS
# of ADP IN
# fines NOUN NNS
# or CCONJ CC
# threats NOUN NNS
# of ADP IN
# being AUX VBG
# beaten VERB VBN
# , PUNCT ,
# the DET DT
# government NOUN NN
# is AUX VBZ
# trying VERB VBG
# to PART TO
# stigmatize VERB VB
# and CCONJ CC
# criminalize VERB VB
# people NOUN NNS
# who PRON WP
# are AUX VBP
# just ADV RB
# practicing VERB VBG
# their PRON PRP$
# rights NOUN NNS
# . PUNCT .
# \ PROPN NNP
# " PUNCT ''
#
#  SPACE _SP
# Air PROPN NNP
# Force PROPN NNP
# spokesperson NOUN NN
# Pongsak PROPN NNP
# Semachai PROPN NNP
# said VERB VBD
# an DET DT
# investigatory NOUN NN
# commission NOUN NN
# would AUX MD
# be AUX VB
# formed VERB VBN
# . PUNCT .
#
#  SPACE _SP
# Researchers NOUN NNS
# noted VERB VBD
# the DET DT
# subjects NOUN NNS
# did AUX VBD
# not PART RB
# attack VERB VB
# any PRON DT
# of ADP IN
# the DET DT
# other ADJ JJ
# mice NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Police NOUN NNS
# today NOUN NN
# found VERB VBD
# 26 NUM CD
# migrants NOUN NNS
# in ADP IN
# a DET DT
# lorry NOUN NN
# near ADP IN
# Braunau PROPN NNP
# am AUX VBP
# Inn PROPN NNP
# , PUNCT ,
# Austria PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# I PRON PRP
# have VERB VBP
# no DET DT
# doubt NOUN NN
# that SCONJ IN
# as SCONJ IN
# time NOUN NN
# goes VERB VBZ
# on ADP RP
# , PUNCT ,
# there PRON EX
# will AUX MD
# be AUX VB
# more ADJ JJR
# and CCONJ CC
# more ADJ JJR
# cases NOUN NNS
# documented VERB VBN
# . PUNCT .
#
#  SPACE _SP
# A DET DT
# suggestion NOUN NN
# had AUX VBD
# been AUX VBN
# the DET DT
# addition NOUN NN
# of ADP IN
# a DET DT
# canopy NOUN NN
# over ADP IN
# the DET DT
# car NOUN NN
# 's PART POS
# cockpit NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Trump PROPN NNP
# has AUX VBZ
# indicated VERB VBN
# he PRON PRP
# seeks VERB VBZ
# closer ADJ JJR
# ties NOUN NNS
# with ADP IN
# Russia PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# According VERB VBG
# to ADP IN
# the DET DT
# report NOUN NN
# , PUNCT ,
# the DET DT
# 63 NUM CD
# - PUNCT HYPH
# year NOUN NN
# - PUNCT HYPH
# old ADJ JJ
# Choe PROPN NNP
# had AUX VBD
# disagreed VERB VBN
# with ADP IN
# Supreme PROPN NNP
# Leader PROPN NNP
# Kim PROPN NNP
# Jong PROPN NNP
# - PUNCT HYPH
# un PROPN NNP
# 's PART POS
# forestry NOUN NN
# policies NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# contract NOUN NN
# had AUX VBD
# previously ADV RB
# been AUX VBN
# for ADP IN
# two NUM CD
# races NOUN NNS
# , PUNCT ,
# but CCONJ CC
# after ADP IN
# acquiring VERB VBG
# sponsorship NOUN NN
# , PUNCT ,
# the DET DT
# deal NOUN NN
# was AUX VBD
# increased VERB VBN
# by ADP IN
# five NUM CD
# events NOUN NNS
# ; PUNCT :
# earlier ADV RBR
# in ADP IN
# August PROPN NNP
# , PUNCT ,
# Wilson PROPN NNP
# recorded VERB VBD
# a DET DT
# best ADJ JJS
# finish NOUN NN
# of ADP IN
# second ADJ JJ
# at ADP IN
# Mid PROPN NNP
# - PROPN NNP
# Ohio ADJ JJ
# Sports PROPN NNPS
# Car PROPN NNP
# Course NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Earlier ADV RBR
# this DET DT
# week NOUN NN
# around ADP IN
# a DET DT
# quarter NOUN NN
# of ADP IN
# 4,000 NUM CD
# troops NOUN NNS
# earmarked VERB VBN
# for ADP IN
# Poland PROPN NNP
# crossed VERB VBD
# into ADP IN
# Poland PROPN NNP
# from ADP IN
# Germany PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Then ADV RB
# for ADP IN
# about ADV RB
# two NUM CD
# weeks NOUN NNS
# we PRON PRP
# count VERB VBP
# every DET DT
# day NOUN NN
# how SCONJ WRB
# many ADJ JJ
# ants NOUN NNS
# died VERB VBD
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# incident NOUN NN
# has AUX VBZ
# now ADV RB
# gained VERB VBN
# international ADJ JJ
# attention NOUN NN
# . PUNCT .
#
#  SPACE _SP
# This PRON DT
# is AUX VBZ
# the DET DT
# Bianchi PROPN NNP
# family NOUN NN
# 's PART POS
# second ADJ JJ
# driver NOUN NN
# death NOUN NN
# . PUNCT .
#
#  SPACE _SP
# We PRON PRP
# can AUX MD
# rule VERB VB
# out ADP RP
# that SCONJ IN
# they PRON PRP
# were AUX VBD
# Africans PROPN NNPS
# \ PROPN NNP
# " PUNCT ''
# . PUNCT .
#
#  SPACE _SP
# Cquote2.svg INTJ UH
# This PRON DT
# is AUX VBZ
# the DET DT
# first ADJ JJ
# F1 NOUN NN
# race NOUN NN
# - PUNCT HYPH
# related VERB VBN
# driver NOUN NN
# death NOUN NN
# since SCONJ IN
# the DET DT
# 1994 NUM CD
# San PROPN NNP
# Marino PROPN NNP
# Grand PROPN NNP
# Prix PROPN NNP
# , PUNCT ,
# when SCONJ WRB
# Ayrton PROPN NNP
# Senna PROPN NNP
# was AUX VBD
# killed VERB VBN
# . PUNCT .
#
#  SPACE _SP
# Interior PROPN NNP
# Minister PROPN NNP
# Johanna PROPN NNP
# Mikl PROPN NNP
# - PUNCT HYPH
# Leitner PROPN NNP
# called VERB VBD
# it PRON PRP
# \ PROPN NNP
# " PUNCT ''
# a DET DT
# dark ADJ JJ
# day NOUN NN
# \ NOUN NN
# " PUNCT ''
# and CCONJ CC
# called VERB VBD
# for ADP IN
# European PROPN NNP
# Union PROPN NNP
# - PUNCT HYPH
# wide ADJ JJ
# measures NOUN NNS
# to PART TO
# protect VERB VB
# immigrant ADJ JJ
# refugees NOUN NNS
# and CCONJ CC
# tackle VERB VB
# human ADJ JJ
# traffickers NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Some DET DT
# army NOUN NN
# doctors NOUN NNS
# were AUX VBD
# sent VERB VBN
# from ADP IN
# North PROPN NNP
# Eastern PROPN NNP
# Indira PROPN NNP
# Gandhi PROPN NNP
# Regional PROPN NNP
# Institute PROPN NNP
# of ADP IN
# Health PROPN NNP
# and CCONJ CC
# Medical PROPN NNP
# Sciences PROPN NNPS
# . PUNCT .
#
#  SPACE _SP
# How SCONJ WRB
# widespread ADJ JJ
# do AUX VBP
# you PRON PRP
# think VERB VB
# this DET DT
# phenomenon NOUN NN
# could AUX MD
# be AUX VB
# in ADP IN
# reality NOUN NN
# ? PUNCT .
#
#  SPACE _SP
# Police NOUN NNS
# found VERB VBD
# even ADV RB
# more ADV RBR
# dead ADJ JJ
# bodies NOUN NNS
# from ADP IN
# the DET DT
# crash NOUN NN
# on ADP IN
# the DET DT
# ground NOUN NN
# , PUNCT ,
# raising VERB VBG
# the DET DT
# reported VERB VBN
# death NOUN NN
# toll NOUN NN
# as ADV RB
# high ADJ JJ
# as ADP IN
# 142 NUM CD
# people NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# rotation NOUN NN
# is AUX VBZ
# due ADJ JJ
# to ADP IN
# a DET DT
# treaty NOUN NN
# with ADP IN
# Russia PROPN NNP
# preventing VERB VBG
# permanent ADJ JJ
# deployment NOUN NN
# to ADP IN
# any DET DT
# particular ADJ JJ
# territory NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Like ADP IN
# other ADJ JJ
# riots NOUN NNS
# this DET DT
# year NOUN NN
# , PUNCT ,
# overcrowding NOUN NN
# may AUX MD
# have AUX VB
# contributed VERB VBN
# to ADP IN
# the DET DT
# latest ADJ JJS
# riot NOUN NN
# . PUNCT .
#
#  SPACE _SP
# In ADP IN
# one NUM CD
# of ADP IN
# several ADJ JJ
# painful ADJ JJ
# performances NOUN NNS
# , PUNCT ,
# Pyotr PROPN NNP
# Pavlensky PROPN NNP
# sewed VERB VBD
# his PRON PRP$
# lips NOUN NNS
# to PART TO
# support VERB VB
# members NOUN NNS
# of ADP IN
# musical ADJ JJ
# band NOUN NN
# Pussy PROPN NNP
# Riot PROPN NNP
# who PRON WP
# were AUX VBD
# imprisoned VERB VBN
# that DET DT
# time NOUN NN
# . PUNCT .
#
#  SPACE _SP
# That PRON DT
# said VERB VBD
# , PUNCT ,
# I PRON PRP
# plan VERB VBP
# to PART TO
# investigate VERB VB
# this DET DT
# question NOUN NN
# ( PUNCT -LRB-
# among ADP IN
# others NOUN NNS
# ) PUNCT -RRB-
# further ADV RB
# [ PUNCT -LRB-
# in ADP IN
# ] PUNCT -RRB-
# the DET DT
# next ADJ JJ
# couple NOUN NN
# of ADP IN
# years NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# After ADP IN
# his PRON PRP$
# departure NOUN NN
# , PUNCT ,
# he PRON PRP
# briefly ADV RB
# served VERB VBD
# as ADP IN
# CEO NOUN NN
# of ADP IN
# the DET DT
# American PROPN NNP
# Red PROPN NNP
# Cross PROPN NNP
# , PUNCT ,
# worked VERB VBD
# in ADP IN
# the DET DT
# cabinet NOUN NN
# of ADP IN
# Indiana PROPN NNP
# governor NOUN NN
# Mitch PROPN NNP
# Daniels PROPN NNP
# , PUNCT ,
# and CCONJ CC
# worked VERB VBD
# for ADP IN
# the DET DT
# tax NOUN NN
# consulting NOUN NN
# firm NOUN NN
# alliantgroup PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Defence PROPN NNP
# Minister PROPN NNP
# Antoni PROPN NNP
# Macierewicz PROPN NNP
# was AUX VBD
# also ADV RB
# at ADP IN
# the DET DT
# ceremony NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Occasional ADJ JJ
# attacks NOUN NNS
# continue VERB VBP
# , PUNCT ,
# and CCONJ CC
# the DET DT
# latest ADJ JJS
# is AUX VBZ
# the DET DT
# worst ADJ JJS
# in ADP IN
# years NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# On ADP IN
# July PROPN NNP
# 1 NUM CD
# , PUNCT ,
# the DET DT
# \ NOUN NN
# " PUNCT ''
# Citizens PROPN NNPS
# ' PART POS
# Security PROPN NNP
# law NOUN NN
# \ NOUN NN
# " PUNCT ''
# went VERB VBD
# into ADP IN
# effect NOUN NN
# . PUNCT .
#
#  SPACE _SP
# We PRON PRP
# would AUX MD
# have AUX VB
# preferred VERB VBN
# a DET DT
# different ADJ JJ
# solution NOUN NN
# but CCONJ CC
# they PRON PRP
# have VERB VBP
# the DET DT
# legal ADJ JJ
# right NOUN NN
# to PART TO
# impose VERB VB
# the DET DT
# fine ADJ JJ
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# Portillo PROPN NNP
# said VERB VBD
# , PUNCT ,
# but CCONJ CC
# the DET DT
# public ADJ JJ
# posting NOUN NN
# of ADP IN
# the DET DT
# photo NOUN NN
# impugned VERB VBD
# the DET DT
# officers NOUN NNS
# ' PART POS
# sense NOUN NN
# of ADP IN
# honor NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Matt PROPN NNP
# O'Brien PROPN NNP
# of ADP IN
# The DET DT
# Washington PROPN NNP
# Post PROPN NNP
# claims VERB VBZ
# a DET DT
# large ADJ JJ
# tax NOUN NN
# cut NOUN NN
# that PRON WDT
# would AUX MD
# result VERB VB
# for ADP IN
# the DET DT
# wealthiest ADJ JJS
# 1 NUM CD
# % NOUN NN
# of ADP IN
# citizens NOUN NNS
# if SCONJ IN
# Obamacare PROPN NNP
# funds NOUN NNS
# were AUX VBD
# not PART RB
# converted VERB VBN
# to ADP IN
# other ADJ JJ
# purposes NOUN NNS
# , PUNCT ,
# estimated VERB VBN
# at ADP IN
# about ADV RB
# $ SYM $
# 32,820 NUM CD
# annually ADV RB
# per ADP IN
# person NOUN NN
# by ADP IN
# the DET DT
# Tax PROPN NNP
# Policy PROPN NNP
# Center PROPN NNP
# , PUNCT ,
# is AUX VBZ
# also ADV RB
# a DET DT
# significant ADJ JJ
# motive NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Reportedly ADV RB
# the DET DT
# lorry NOUN NN
# traveled VERB VBD
# from ADP IN
# Kecskemet PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Video PROPN NNP
# from ADP IN
# a DET DT
# passing VERB VBG
# motorist NOUN NN
# shows VERB VBZ
# at ADV RB
# least ADV RBS
# one NUM CD
# helicopter NOUN NN
# on ADP IN
# - PUNCT HYPH
# scene NOUN NN
# . PUNCT .
#
#  SPACE _SP
# This PRON DT
# was AUX VBD
# in ADP IN
# response NOUN NN
# to ADP IN
# a DET DT
# CIA PROPN NNP
# report NOUN NN
# issued VERB VBD
# two NUM CD
# weeks NOUN NNS
# earlier ADV RBR
# that PRON WDT
# concluded VERB VBD
# the DET DT
# Russian ADJ JJ
# government NOUN NN
# hacked VERB VBD
# servers NOUN NNS
# belonging VERB VBG
# to ADP IN
# the DET DT
# U.S. PROPN NNP
# Republican ADJ JJ
# and CCONJ CC
# Democratic ADJ JJ
# parties NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Hyza PROPN NNP
# told VERB VBD
# us PRON PRP
# the DET DT
# new ADJ JJ
# owners NOUN NNS
# have AUX VBP
# not PART RB
# changed VERB VBN
# the DET DT
# branding NOUN NN
# on ADP IN
# the DET DT
# vehicle NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# enclave NOUN NN
# , PUNCT ,
# Russian ADJ JJ
# territory NOUN NN
# lying VERB VBG
# between ADP IN
# Poland PROPN NNP
# and CCONJ CC
# Lithuania PROPN NNP
# , PUNCT ,
# now ADV RB
# has VERB VBZ
# nuclear ADJ JJ
# - PUNCT HYPH
# capable ADJ JJ
# Iskanders PROPN NNP
# and CCONJ CC
# anti ADJ JJ
# - ADJ JJ
# ship ADJ JJ
# Bastion PROPN NNP
# equipment NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Adnan PROPN NNP
# 's PART POS
# strike NOUN NN
# lasted VERB VBD
# over ADP IN
# 50 NUM CD
# days NOUN NNS
# , PUNCT ,
# and CCONJ CC
# he PRON PRP
# was AUX VBD
# in ADP IN
# mortal ADJ JJ
# danger NOUN NN
# for ADP IN
# the DET DT
# last ADJ JJ
# couple NOUN NN
# of ADP IN
# weeks NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# Independent PROPN NNP
# reported VERB VBD
# self NOUN NN
# - PUNCT HYPH
# medicating VERB VBG
# ants NOUN NNS
# a DET DT
# first ADJ JJ
# among ADP IN
# insects NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# It PRON PRP
# was AUX VBD
# agreed VERB VBN
# at ADP IN
# a DET DT
# NATO PROPN NNP
# summit NOUN NN
# in ADP IN
# Warsaw PROPN NNP
# last ADJ JJ
# year NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Västerås PROPN NNP
# is AUX VBZ
# in ADP IN
# central ADJ JJ
# Sweden PROPN NNP
# , PUNCT ,
# approximately ADV RB
# 115 NUM CD
# km NOUN NNS
# ( PUNCT -LRB-
# 70 NUM CD
# miles NOUN NNS
# ) PUNCT -RRB-
# west ADV RB
# from ADP IN
# the DET DT
# capital NOUN NN
# Stockholm PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# According VERB VBG
# to ADP IN
# WDBJ NOUN NN
# president NOUN NN
# and CCONJ CC
# general ADJ JJ
# manager NOUN NN
# Jeffrey PROPN NNP
# Marks PROPN NNP
# , PUNCT ,
# speaking VERB VBG
# to ADP IN
# CBS PROPN NNP
# News PROPN NNP
# , PUNCT ,
# Flanagan PROPN NNP
# was AUX VBD
# \ PROPN NNP
# " PUNCT ''
# an DET DT
# unhappy ADJ JJ
# man NOUN NN
# \ PROPN NNP
# " PUNCT ''
# and CCONJ CC
# \ PROPN NNP
# " PUNCT ''
# difficult ADJ JJ
# to PART TO
# work VERB VB
# with ADP IN
# \ PROPN NNP
# " PUNCT ''
# . PUNCT .
#
#  SPACE _SP
# Job PROPN NNP
# growth NOUN NN
# is AUX VBZ
# quite ADV RB
# strong ADJ JJ
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# stated VERB VBD
# Jim PROPN NNP
# O'Sullivan PROPN NNP
# , PUNCT ,
# chief ADJ JJ
# economist NOUN NN
# at ADP IN
# High PROPN NNP
# Frequency PROPN NNP
# Economics PROPN NNP
# , PUNCT ,
# a DET DT
# data NOUN NNS
# analysis NOUN NN
# firm NOUN NN
# in ADP IN
# New PROPN NNP
# York PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# There PRON EX
# 's VERB VBZ
# conflicting ADJ JJ
# evidence NOUN NN
# about ADP IN
# whether SCONJ IN
# sick ADJ JJ
# ants NOUN NNS
# actually ADV RB
# smell VERB VBP
# different ADJ JJ
# from ADP IN
# healthy ADJ JJ
# ones NOUN NNS
# or CCONJ CC
# not PART RB
# . PUNCT .
#
#  SPACE _SP
# Part PROPN NNP
# of ADP IN
# Operation PROPN NNP
# Atlantic PROPN NNP
# Resolve PROPN NNP
# , PUNCT ,
# the DET DT
# deployment NOUN NN
# is AUX VBZ
# set VERB VBN
# to PART TO
# include VERB VB
# Abrams PROPN NNP
# tanks NOUN NNS
# , PUNCT ,
# Bradley PROPN NNP
# Fighting PROPN NNP
# Vehicles PROPN NNPS
# , PUNCT ,
# and CCONJ CC
# Paladin PROPN NNP
# artillery NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# victims NOUN NNS
# are AUX VBP
# thought VERB VBN
# to PART TO
# have AUX VB
# suffocated VERB VBN
# . PUNCT .
#
#  SPACE _SP
# NB PROPN NNP
# : PUNCT :
# I PRON PRP
# first ADV RB
# want VERB VBP
# to PART TO
# find VERB VB
# out ADP RP
# where SCONJ WRB
# they PRON PRP
# get VERB VBP
# it PRON PRP
# from ADP IN
# in ADP IN
# nature NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Anna PROPN NNP
# Merlan PROPN NNP
# of ADP IN
# Jezebel PROPN NNP
# and CCONJ CC
# Anthony PROPN NNP
# Taylor PROPN NNP
# of ADP IN
# the DET DT
# Associated PROPN NNP
# Press PROPN NNP
# dismiss VERB VBP
# Trump PROPN NNP
# 's PART POS
# timeline NOUN NN
# as ADP IN
# \ PROPN NNP
# " PUNCT ''
# impossible PROPN NNP
# \ PROPN NNP
# " PUNCT ''
# given VERB VBN
# the DET DT
# complicated ADJ JJ
# nature NOUN NN
# of ADP IN
# U.S. PROPN NNP
# congressional ADJ JJ
# workings NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Despite SCONJ IN
# being AUX VBG
# a DET DT
# trans PROPN NNP
# woman NOUN NN
# , PUNCT ,
# Manning PROPN NNP
# was AUX VBD
# housed VERB VBN
# in ADP IN
# a DET DT
# men NOUN NNS
# 's PART POS
# prison NOUN NN
# , PUNCT ,
# the DET DT
# U.S. PROPN NNP
# Disciplinary ADJ JJ
# Barracks PROPN NNPS
# at ADP IN
# Fort PROPN NNP
# Leavenworth PROPN NNP
# , PUNCT ,
# Kansas PROPN NNP
# . PUNCT .
# She PRON PRP
# spent VERB VBD
# a DET DT
# long ADJ JJ
# period NOUN NN
# in ADP IN
# solitary ADJ JJ
# confinement NOUN NN
# and CCONJ CC
# attempted VERB VBN
# suicide NOUN NN
# twice ADV RB
# in ADP IN
# 2016 NUM CD
# . PUNCT .
#
#  SPACE _SP
# Could AUX MD
# healthy ADJ JJ
# ants NOUN NNS
# perhaps ADV RB
# tell VERB VB
# other ADJ JJ
# ants NOUN NNS
# are AUX VBP
# infected VERB VBN
# and CCONJ CC
# encourage VERB VB
# this DET DT
# behaviour NOUN NN
# ? PUNCT .
#
#  SPACE _SP
# Following VERB VBG
# months NOUN NNS
# of ADP IN
# political ADJ JJ
# unrest NOUN NN
# , PUNCT ,
# since SCONJ IN
# the DET DT
# explosion NOUN NN
# the DET DT
# Thai PROPN NNP
# baht NOUN NN
# hit VERB VBD
# a DET DT
# six NUM CD
# year NOUN NN
# low ADJ JJ
# . PUNCT .
#
#  SPACE _SP
# This PRON DT
# means VERB VBZ
# the DET DT
# experimenter NOUN NN
# does AUX VBZ
# n't PART RB
# know VERB VB
# which PRON WDT
# ants NOUN NNS
# belong VERB VBP
# to ADP IN
# which DET WDT
# treatment NOUN NN
# , PUNCT ,
# so CCONJ CC
# it PRON PRP
# 's AUX VBZ
# impossible ADJ JJ
# to PART TO
# influence VERB VB
# the DET DT
# results NOUN NNS
# with ADP IN
# \ PROPN NNP
# ' PART POS
# observer NOUN NN
# bias NOUN NN
# \ PROPN NNP
# ' PUNCT ''
# . PUNCT .
#
#  SPACE _SP
# After ADP IN
# the DET DT
# exchange NOUN NN
# of ADP IN
# fire NOUN NN
# , PUNCT ,
# North PROPN NNP
# Korea PROPN NNP
# stated VERB VBD
# it PRON PRP
# would AUX MD
# attack VERB VB
# any DET DT
# loudspeakers NOUN NNS
# broadcasting VERB VBG
# propaganda NOUN NN
# and CCONJ CC
# would AUX MD
# respond VERB VB
# , PUNCT ,
# militarily ADV RB
# , PUNCT ,
# within ADP IN
# 48 NUM CD
# hours NOUN NNS
# if SCONJ IN
# the DET DT
# broadcasts NOUN NNS
# do AUX VBP
# not PART RB
# stop VERB VB
# . PUNCT .
#
#  SPACE _SP
# When SCONJ WRB
# he PRON PRP
# heard VERB VBD
# about ADP IN
# the DET DT
# discovery NOUN NN
# in ADP IN
# Vabbinfaru PROPN NNP
# resort NOUN NN
# we PRON PRP
# immediately ADV RB
# called VERB VBD
# the DET DT
# Police PROPN NNP
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# said VERB VBD
# Mohamed PROPN NNP
# Ibrahim PROPN NNP
# , PUNCT ,
# a DET DT
# councilman NOUN NN
# for ADP IN
# Fehendhoo PROPN NNP
# Island PROPN NNP
# , PUNCT ,
# to ADP IN
# Haveeru PROPN NNP
# Daily PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# name NOUN NN
# is AUX VBZ
# a DET DT
# pun ADJ JJ
# referencing VERB VBG
# ants NOUN NNS
# , PUNCT ,
# its PRON PRP$
# primary ADJ JJ
# topic NOUN NN
# , PUNCT ,
# science NOUN NN
# , PUNCT ,
# and CCONJ CC
# \ PROPN NNP
# " PUNCT ''
# non ADJ JJ
# - ADJ JJ
# scientific ADJ JJ
# \ NOUN NN
# " PUNCT ''
# jargon NOUN NN
# - PUNCT HYPH
# free ADJ JJ
# communication NOUN NN
# . PUNCT .
#
#  SPACE _SP
# On ADP IN
# the DET DT
# day NOUN NN
# the DET DT
# plane NOUN NN
# went VERB VBD
# missing ADJ JJ
# , PUNCT ,
# residents NOUN NNS
# on ADP IN
# the DET DT
# small ADJ JJ
# Maldive ADJ JJ
# island NOUN NN
# of ADP IN
# Kudahuvadhoo PROPN NNP
# claimed VERB VBD
# to PART TO
# have AUX VB
# seen VERB VBN
# a DET DT
# very ADV RB
# \ NOUN NN
# " PUNCT ''
# low ADJ JJ
# flying VERB VBG
# jumbo ADJ JJ
# jet NOUN NN
# \ NOUN NN
# " PUNCT ''
# crash NOUN NN
# into ADP IN
# the DET DT
# Indian PROPN NNP
# Ocean PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# We PRON PRP
# need VERB VBP
# to PART TO
# be AUX VB
# voting VERB VBG
# for ADP IN
# a DET DT
# replacement NOUN NN
# plan NOUN NN
# at ADP IN
# the DET DT
# same ADJ JJ
# time NOUN NN
# that PRON WDT
# we PRON PRP
# vote VERB VBP
# for ADP IN
# repeal NOUN NN
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# added VERB VBD
# Representative PROPN NNP
# Mark PROPN NNP
# Meadows PROPN NNP
# of ADP IN
# North PROPN NNP
# Carolina PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# shrine NOUN NN
# is AUX VBZ
# a DET DT
# popular ADJ JJ
# attraction NOUN NN
# in ADP IN
# Thailand PROPN NNP
# 's PART POS
# capital NOUN NN
# , PUNCT ,
# where SCONJ WRB
# at ADV RB
# least ADV RBS
# 20 NUM CD
# people NOUN NNS
# , PUNCT ,
# including VERB VBG
# at ADP IN
# least ADV RBS
# eight NUM CD
# foreigners NOUN NNS
# , PUNCT ,
# are AUX VBP
# reported VERB VBN
# dead ADJ JJ
# with ADP IN
# upwards ADJ JJ
# of ADP IN
# 100 NUM CD
# injured VERB VBN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# flight NOUN NN
# was AUX VBD
# operated VERB VBN
# by ADP IN
# ACT PROPN NNP
# Airlines PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Placed VERB VBN
# in ADP IN
# the DET DT
# intensive ADJ JJ
# care NOUN NN
# unit NOUN NN
# , PUNCT ,
# in ADP IN
# December PROPN NNP
# he PRON PRP
# began VERB VBD
# rehabilitation NOUN NN
# therapy NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# death NOUN NN
# toll NOUN NN
# was AUX VBD
# yesterday NOUN NN
# finalised VERB VBN
# at ADP IN
# 71 NUM CD
# . PUNCT .
#
#  SPACE _SP
# And CCONJ CC
# afterwards ADV RB
# either PRON DT
# infected VERB VBD
# them PRON PRP
# or CCONJ CC
# not PART RB
# . PUNCT .
#
#  SPACE _SP
# Russian ADJ JJ
# Presidential ADJ JJ
# spokesperson NOUN NN
# Dmitry PROPN NNP
# Peskov PROPN NNP
# echoed VERB VBD
# Putin PROPN NNP
# , PUNCT ,
# saying VERB VBG
# the DET DT
# troops NOUN NNS
# are AUX VBP
# \ PROPN NNP
# " PUNCT ''
# a DET DT
# threat NOUN NN
# . PUNCT .
#
#  SPACE _SP
# At ADP IN
# least ADJ JJS
# fifty NUM CD
# died VERB VBD
# . PUNCT .
#
#  SPACE _SP
# Manas PROPN NNP
# international ADJ JJ
# airport NOUN NN
# is AUX VBZ
# located VERB VBN
# outside ADP IN
# the DET DT
# capital NOUN NN
# city NOUN NN
# of ADP IN
# Bishkek PROPN NNP
# , PUNCT ,
# and CCONJ CC
# has AUX VBZ
# been AUX VBN
# the DET DT
# location NOUN NN
# of ADP IN
# other ADJ JJ
# fatal ADJ JJ
# crashes NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# In ADP IN
# the DET DT
# wake NOUN NN
# of ADP IN
# this DET DT
# year NOUN NN
# 's PART POS
# riots NOUN NNS
# , PUNCT ,
# the DET DT
# Brazilian ADJ JJ
# President PROPN NNP
# Michel PROPN NNP
# Temer PROPN NNP
# announced VERB VBD
# to ADP IN
# Reuters PROPN NNP
# yesterday NOUN NN
# a DET DT
# plan NOUN NN
# , PUNCT ,
# under ADP IN
# joint ADJ JJ
# cooperation NOUN NN
# of ADP IN
# state NOUN NN
# and CCONJ CC
# federal ADJ JJ
# governments NOUN NNS
# , PUNCT ,
# to PART TO
# build VERB VB
# nearly ADV RB
# thirty NUM CD
# prisons NOUN NNS
# by ADP IN
# 2018 NUM CD
# , PUNCT ,
# including VERB VBG
# \ PROPN NNP
# " PUNCT ''
# five NUM CD
# maximum ADJ JJ
# security NOUN NN
# prisons NOUN NNS
# to PART TO
# house VERB VB
# the DET DT
# most ADV RBS
# violent ADJ JJ
# convicts NOUN NNS
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# and CCONJ CC
# to PART TO
# create VERB VB
# intelligence NOUN NN
# units NOUN NNS
# in ADP IN
# effort NOUN NN
# to PART TO
# counter VERB VB
# the DET DT
# influence NOUN NN
# of ADP IN
# powerful ADJ JJ
# inmates NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Moreover ADV RB
# , PUNCT ,
# he PRON PRP
# declares VERB VBZ
# himself PRON PRP
# as ADP IN
# the DET DT
# \ NOUN NN
# " PUNCT ''
# second ADV RB
# - PUNCT HYPH
# most ADV RBS
# exciting ADJ JJ
# \ PROPN NNP
# " PUNCT ''
# candidate NOUN NN
# , PUNCT ,
# reserving VERB VBG
# first ADJ JJ
# place NOUN NN
# for ADP IN
# Trump PROPN NNP
# , PUNCT ,
# whom PRON WP
# Martin PROPN NNP
# praises VERB VBZ
# throughout ADP IN
# his PRON PRP$
# announcement NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Dozens NOUN NNS
# of ADP IN
# refugees NOUN NNS
# and CCONJ CC
# aid NOUN NN
# workers NOUN NNS
# died VERB VBD
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# military NOUN NN
# is AUX VBZ
# not PART RB
# allowed VERB VBN
# to PART TO
# fly VERB VB
# civilian ADJ JJ
# passengers NOUN NNS
# , PUNCT ,
# according VERB VBG
# to ADP IN
# the DET DT
# air NOUN NN
# force PROPN NNP
# chief NOUN NN
# , PUNCT ,
# unless SCONJ IN
# they PRON PRP
# are AUX VBP
# related VERB VBN
# to ADP IN
# military ADJ JJ
# personnel NOUN NNS
# , PUNCT ,
# or CCONJ CC
# under ADP IN
# some DET DT
# special ADJ JJ
# circumstances NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# A DET DT
# video NOUN NN
# of ADP IN
# the DET DT
# shooting NOUN NN
# , PUNCT ,
# which PRON WDT
# appeared VERB VBD
# to PART TO
# have AUX VB
# been AUX VBN
# captured VERB VBN
# from ADP IN
# the DET DT
# point NOUN NN
# of ADP IN
# view NOUN NN
# of ADP IN
# the DET DT
# shooter NOUN NN
# , PUNCT ,
# was AUX VBD
# posted VERB VBN
# on ADP IN
# Bryce PROPN NNP
# Williams PROPN NNP
# ' PART POS
# Twitter PROPN NNP
# and CCONJ CC
# Facebook PROPN NNP
# pages NOUN NNS
# several ADJ JJ
# hours NOUN NNS
# afterwards ADV RB
# . PUNCT .
#
#  SPACE _SP
# Also ADV RB
# included VERB VBN
# were AUX VBD
# trucks NOUN NNS
# , PUNCT ,
# tanks NOUN NNS
# , PUNCT ,
# and CCONJ CC
# Humvees PROPN NNPS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# report NOUN NN
# , PUNCT ,
# which PRON WDT
# cites VERB VBZ
# an DET DT
# unnamed ADJ JJ
# source NOUN NN
# , PUNCT ,
# has AUX VBZ
# not PART RB
# been AUX VBN
# confirmed VERB VBN
# by ADP IN
# Wikinews PROPN NNP
# or CCONJ CC
# other ADJ JJ
# agencies NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# August PROPN NNP
# 27 NUM CD
# collapse NOUN NN
# caused VERB VBD
# millions NOUN NNS
# of ADP IN
# pounds NOUN NNS
# of ADP IN
# damage NOUN NN
# , PUNCT ,
# and CCONJ CC
# closed VERB VBD
# a DET DT
# major ADJ JJ
# route NOUN NN
# for ADP IN
# more ADJ JJR
# than ADP IN
# 24 NUM CD
# hours NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# We PRON PRP
# measured VERB VBD
# the DET DT
# ROS PROPN NNP
# - PUNCT HYPH
# concentration NOUN NN
# in ADP IN
# the DET DT
# bodies NOUN NNS
# of ADP IN
# ants NOUN NNS
# after SCONJ IN
# they PRON PRP
# ingested VERB VBD
# the DET DT
# food NOUN NN
# with ADP IN
# the DET DT
# medicine NOUN NN
# using VERB VBG
# a DET DT
# spectrophotometer NOUN NN
# . PUNCT .
#
#  SPACE _SP
# In ADP IN
# Victory PROPN NNP
# Lane PROPN NNP
# , PUNCT ,
# he PRON PRP
# stated VERB VBD
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# My PRON PRP$
# first ADJ JJ
# thoughts NOUN NNS
# are AUX VBP
# with ADP IN
# Justin PROPN NNP
# , PUNCT ,
# for ADP IN
# sure ADJ JJ
# [ PUNCT -LRB-
# ... PUNCT NFP
# ] PUNCT -RRB-
# He PRON PRP
# 's AUX VBZ
# a DET DT
# friend NOUN NN
# , PUNCT ,
# a DET DT
# teammate NOUN NN
# , PUNCT ,
# and CCONJ CC
# it PRON PRP
# 's AUX VBZ
# a DET DT
# bit NOUN NN
# hard ADV RB
# not PART RB
# knowing VERB VBG
# anything PRON NN
# . PUNCT .
# \ PROPN NNP
# " PUNCT ''
#
#  SPACE _SP
# Based VERB VBN
# on ADP IN
# the DET DT
# monitoring NOUN NN
# up ADP RP
# to ADP IN
# date NOUN NN
# , PUNCT ,
# no DET DT
# indication NOUN NN
# of ADP IN
# Flight PROPN NNP
# MH370 PROPN NNP
# has AUX VBZ
# been AUX VBN
# observed VERB VBN
# on ADP IN
# any DET DT
# military ADJ JJ
# radars NOUN NNS
# in ADP IN
# the DET DT
# country NOUN NN
# [ PUNCT -LRB-
# Maldives PROPN NNP
# ] PUNCT -RRB-
# . PUNCT .
#
#  SPACE _SP
# Everson PROPN NNP
# served VERB VBD
# as ADP IN
# Commissioner PROPN NNP
# of ADP IN
# the DET DT
# IRS PROPN NNP
# from ADP IN
# 2003 NUM CD
# to ADP IN
# 2007 NUM CD
# , PUNCT ,
# during ADP IN
# the DET DT
# George PROPN NNP
# W. PROPN NNP
# Bush PROPN NNP
# administration NOUN NN
# . PUNCT .
#
#  SPACE _SP
# In ADP IN
# 2013 NUM CD
# , PUNCT ,
# he PRON PRP
# joined VERB VBD
# Marussia PROPN NNP
# F1 PROPN NNP
# ; PUNCT :
# the DET DT
# following ADJ JJ
# year NOUN NN
# , PUNCT ,
# at ADP IN
# the DET DT
# 2014 NUM CD
# Monaco PROPN NNP
# Grand PROPN NNP
# Prix PROPN NNP
# , PUNCT ,
# he PRON PRP
# scored VERB VBD
# his PRON PRP$
# and CCONJ CC
# Marussia PROPN NNP
# 's PART POS
# first ADJ JJ
# points NOUN NNS
# with ADP IN
# a DET DT
# ninth ADJ JJ
# - PUNCT HYPH
# place NOUN NN
# finish NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# report NOUN NN
# is AUX VBZ
# known VERB VBN
# to PART TO
# contain VERB VB
# some DET DT
# material NOUN NN
# disputed VERB VBN
# by ADP IN
# Lin PROPN NNP
# and CCONJ CC
# Phyo PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Today NOUN NN
# we PRON PRP
# have AUX VBP
# made VERB VBN
# a DET DT
# big ADJ JJ
# step NOUN NN
# in ADP IN
# this DET DT
# direction NOUN NN
# \ PROPN NNP
# " PUNCT ''
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# final ADJ JJ
# decision NOUN NN
# on ADP IN
# lifting VERB VBG
# Presidential ADJ JJ
# immunity NOUN NN
# now ADV RB
# falls VERB VBZ
# to ADP IN
# Congress PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Fighter ADJ JJ
# jet NOUN NN
# crashes NOUN NNS
# during ADP IN
# Children PROPN NNP
# 's PART POS
# Day PROPN NNP
# airshow ADV RB
# in ADP IN
# Thailand PROPN NNP
# A PROPN NNP
# fighter NOUN NN
# jet NOUN NN
# crashed VERB VBD
# , PUNCT ,
# killing VERB VBG
# the DET DT
# pilot NOUN NN
# , PUNCT ,
# at ADP IN
# Hat PROPN NNP
# Yai PROPN NNP
# International PROPN NNP
# Airport PROPN NNP
# , PUNCT ,
# Songkhla​ PROPN NNP
# , PUNCT ,
# Thailand PROPN NNP
# this DET DT
# morning NOUN NN
# during ADP IN
# an DET DT
# annual ADJ JJ
# Children PROPN NNPS
# 's PART POS
# Day NOUN NN
# airshow ADV RB
# . PUNCT .
#
#  SPACE _SP
# Wilson PROPN NNP
# , PUNCT ,
# a DET DT
# former ADJ JJ
# Formula PROPN NNP
# One PROPN NNP
# and CCONJ CC
# Champ PROPN NNP
# Car NOUN NN
# driver NOUN NN
# , PUNCT ,
# did AUX VBD
# not PART RB
# have VERB VB
# a DET DT
# ride NOUN NN
# entering VERB VBG
# the DET DT
# 2015 NUM CD
# season NOUN NN
# , PUNCT ,
# and CCONJ CC
# joined VERB VBD
# Andretti PROPN NNP
# on ADP IN
# a DET DT
# seven NUM CD
# - PUNCT HYPH
# race NOUN NN
# deal NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Legal ADJ JJ
# charity NOUN NN
# Reprieve PROPN NNP
# , PUNCT ,
# who PRON WP
# assisted VERB VBD
# the DET DT
# two NUM CD
# men NOUN NNS
# , PUNCT ,
# said VERB VBD
# in ADP IN
# a DET DT
# statement NOUN NN
# \ NOUN NN
# " PUNCT ''
# Concerns NOUN NNS
# about ADP IN
# the DET DT
# conduct NOUN NN
# of ADP IN
# the DET DT
# Thai PROPN NNP
# investigation NOUN NN
# and CCONJ CC
# the DET DT
# safety NOUN NN
# of ADP IN
# any DET DT
# convictions NOUN NNS
# resulting VERB VBG
# have AUX VBP
# been AUX VBN
# raised VERB VBN
# from ADP IN
# the DET DT
# very ADJ JJ
# beginning NOUN NN
# [ PUNCT -LRB-
# ... PUNCT NFP
# ] X XX
# only ADV RB
# the DET DT
# defence NOUN NN
# lawyers NOUN NNS
# in ADP IN
# Thailand PROPN NNP
# are AUX VBP
# in ADP IN
# a DET DT
# position NOUN NN
# to PART TO
# judge VERB VB
# whether SCONJ IN
# the DET DT
# information NOUN NN
# could AUX MD
# be AUX VB
# of ADP IN
# assistance NOUN NN
# . PUNCT .
# \ PROPN NNP
# " PUNCT ''
#
#  SPACE _SP
# The DET DT
# band NOUN NN
# members NOUN NNS
# were AUX VBD
# charged VERB VBN
# with ADP IN
# hooliganism NOUN NN
# for ADP IN
# performing VERB VBG
# an DET DT
# anti ADJ JJ
# - ADJ JJ
# Putin ADJ JJ
# song NOUN NN
# in ADP IN
# a DET DT
# church NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Agence PROPN NNP
# France PROPN NNP
# Presse PROPN NNP
# ( PUNCT -LRB-
# AFP PROPN NNP
# ) PUNCT -RRB-
# and CCONJ CC
# Rio PROPN NNP
# de PROPN NNP
# Janeiro PROPN NNP
# newspaper NOUN NN
# O PROPN NNP
# Globo PROPN NNP
# report NOUN NN
# that SCONJ IN
# the DET DT
# gang NOUN NN
# members NOUN NNS
# of ADP IN
# the DET DT
# Primeiro PROPN NNP
# Comando PROPN NNP
# da PROPN NNP
# Capital PROPN NNP
# ( PUNCT -LRB-
# PCC PROPN NNP
# ) PUNCT -RRB-
# and CCONJ CC
# Comando PROPN NNP
# Vermelho PROPN NNP
# were AUX VBD
# the DET DT
# latest ADJ JJS
# riot NOUN NN
# 's PART POS
# participants NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Hungary PROPN NNP
# is AUX VBZ
# presently ADV RB
# building VERB VBG
# a DET DT
# border NOUN NN
# fence NOUN NN
# across ADP IN
# the DET DT
# Serbian ADJ JJ
# frontier NOUN NN
# , PUNCT ,
# as ADP IN
# migrants NOUN NNS
# from ADP IN
# war NOUN NN
# - PUNCT HYPH
# torn VERB VBN
# Syria PROPN NNP
# and CCONJ CC
# other ADJ JJ
# regions NOUN NNS
# seek VERB VBP
# access NOUN NN
# to ADP IN
# the DET DT
# Schengen PROPN NNP
# Area PROPN NNP
# of ADP IN
# free ADJ JJ
# movement NOUN NN
# , PUNCT ,
# which PRON WDT
# covers VERB VBZ
# most ADJ JJS
# of ADP IN
# the DET DT
# EU PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Shortly ADV RB
# after ADV RB
# , PUNCT ,
# Flanagan PROPN NNP
# pulled VERB VBD
# off ADP RP
# the DET DT
# road NOUN NN
# and CCONJ CC
# shot VERB VBD
# himself PRON PRP
# . PUNCT .
#
#  SPACE _SP
# This DET DT
# week NOUN NN
# , PUNCT ,
# Obama PROPN NNP
# also ADV RB
# commuted VERB VBD
# the DET DT
# sentences NOUN NNS
# of ADP IN
# Oscar PROPN NNP
# Lopez PROPN NNP
# Rivera PROPN NNP
# , PUNCT ,
# a DET DT
# Puerto ADJ JJ
# Rican ADJ JJ
# nationalist NOUN NN
# linked VERB VBN
# to ADP IN
# bombings NOUN NNS
# in ADP IN
# the DET DT
# 1970s NOUN NNS
# and CCONJ CC
# 1980s NOUN NNS
# , PUNCT ,
# James PROPN NNP
# E. PROPN NNP
# Cartwright PROPN NNP
# , PUNCT ,
# a DET DT
# former ADJ JJ
# Marine PROPN NNP
# general NOUN NN
# and CCONJ CC
# White PROPN NNP
# House PROPN NNP
# Chief PROPN NNP
# of ADP IN
# Staff PROPN NNP
# convicted VERB VBN
# of ADP IN
# lying VERB VBG
# to ADP IN
# the DET DT
# FBI PROPN NNP
# , PUNCT ,
# and CCONJ CC
# over ADP IN
# two NUM CD
# hundred NUM CD
# other ADJ JJ
# individuals NOUN NNS
# , PUNCT ,
# mostly ADV RB
# drug NOUN NN
# offenders NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# topic NOUN NN
# had AUX VBD
# been AUX VBN
# controversial ADJ JJ
# : PUNCT :
# while SCONJ IN
# some PRON DT
# supported VERB VBD
# it PRON PRP
# for ADP IN
# safety NOUN NN
# reasons NOUN NNS
# , PUNCT ,
# others NOUN NNS
# opposed VERB VBD
# it PRON PRP
# because SCONJ IN
# of ADP IN
# history NOUN NN
# , PUNCT ,
# possibly ADV RB
# affecting VERB VBG
# the DET DT
# aerodynamics NOUN NNS
# of ADP IN
# the DET DT
# car NOUN NN
# , PUNCT ,
# limiting VERB VBG
# one NUM CD
# 's PART POS
# peripheral ADJ JJ
# vision NOUN NN
# and CCONJ CC
# movement NOUN NN
# inside ADP IN
# the DET DT
# car NOUN NN
# , PUNCT ,
# and CCONJ CC
# worry VERB VB
# about ADP IN
# escaping VERB VBG
# an DET DT
# upside NOUN NN
# - PUNCT HYPH
# down NOUN NN
# or CCONJ CC
# burning VERB VBG
# car NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# mice NOUN NNS
# behaved VERB VBD
# normally ADV RB
# at ADP IN
# all DET DT
# other ADJ JJ
# times NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Yesterday NOUN NN
# , PUNCT ,
# reports NOUN NNS
# stated VERB VBD
# several ADJ JJ
# more ADJ JJR
# pieces NOUN NNS
# of ADP IN
# debris NOUN NN
# , PUNCT ,
# one NUM CD
# piece NOUN NN
# measuring VERB VBG
# some DET DT
# eight NUM CD
# feet NOUN NNS
# by ADP IN
# two NUM CD
# feet NOUN NNS
# ( PUNCT -LRB-
# about ADV RB
# 2.4 NUM CD
# by ADP IN
# 0.6 NUM CD
# m NUM CD
# ) PUNCT -RRB-
# , PUNCT ,
# were AUX VBD
# found VERB VBN
# on ADP IN
# Baa PROPN NNP
# Atoll PROPN NNP
# , PUNCT ,
# Fehendhoo PROPN NNP
# and CCONJ CC
# Fulhahdhoo PROPN NNP
# and CCONJ CC
# washed VERB VBD
# ashore ADV RB
# sometime ADV RB
# in ADP IN
# the DET DT
# past ADJ JJ
# few ADJ JJ
# days NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Many ADJ JJ
# are AUX VBP
# set VERB VBN
# to PART TO
# be AUX VB
# based VERB VBN
# in ADP IN
# Żagań PROPN NNP
# , PUNCT ,
# where SCONJ WRB
# Polish ADJ JJ
# Prime PROPN NNP
# Minister PROPN NNP
# Beata PROPN NNP
# Szydło PROPN NNP
# and CCONJ CC
# Defence PROPN NNP
# Minister PROPN NNP
# Antoni PROPN NNP
# Macierewicz PROPN NNP
# are AUX VBP
# scheduled VERB VBN
# to PART TO
# ceremonially ADV RB
# welcome VERB VB
# them PRON PRP
# tomorrow NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Nigerian ADJ JJ
# jet NOUN NN
# attacks NOUN NNS
# refugee NOUN NN
# camp NOUN NN
# , PUNCT ,
# killing VERB VBG
# dozens NOUN NNS
# A DET DT
# Nigerian PROPN NNP
# Air PROPN NNP
# Force PROPN NNP
# jet NOUN NN
# fighter NOUN NN
# mistook VERB VBP
# refugees NOUN NNS
# for ADP IN
# rebels NOUN NNS
# yesterday NOUN NN
# , PUNCT ,
# Nigerian ADJ JJ
# military NOUN NN
# said VERB VBD
# , PUNCT ,
# firing VERB VBG
# on ADP IN
# a DET DT
# camp NOUN NN
# in ADP IN
# Rann PROPN NNP
# , PUNCT ,
# Borno PROPN NNP
# State PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# filibuster NOUN NN
# is AUX VBZ
# a DET DT
# last ADJ JJ
# - PUNCT HYPH
# ditch NOUN NN
# tactic NOUN NN
# in ADP IN
# which PRON WDT
# parties NOUN NNS
# opposed VERB VBN
# to ADP IN
# a DET DT
# certain ADJ JJ
# motion NOUN NN
# refuse VERB VBP
# to PART TO
# relinquish VERB VB
# the DET DT
# floor NOUN NN
# until SCONJ IN
# their PRON PRP$
# opponents NOUN NNS
# give VERB VBP
# in ADP RP
# or CCONJ CC
# compromise NOUN NN
# . PUNCT .
#
#  SPACE _SP
# South PROPN NNP
# Korea PROPN NNP
# 's PART POS
# Ministry PROPN NNP
# of ADP IN
# Unification PROPN NNP
# told VERB VBD
# both DET DT
# Reuters PROPN NNP
# and CCONJ CC
# BBC PROPN NNP
# it PRON PRP
# was AUX VBD
# monitoring VERB VBG
# the DET DT
# situation NOUN NN
# but CCONJ CC
# Choe PROPN NNP
# has AUX VBZ
# not PART RB
# been AUX VBN
# seen VERB VBN
# publicly ADV RB
# since SCONJ IN
# December PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Once ADV RB
# again ADV RB
# , PUNCT ,
# a DET DT
# tragedy NOUN NN
# has AUX VBZ
# struck VERB VBN
# … PUNCT NFP
# our PRON PRP$
# city NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Everson PROPN NNP
# argues VERB VBZ
# Fox PROPN NNP
# News PROPN NNP
# , PUNCT ,
# in ADP IN
# violation NOUN NN
# of ADP IN
# Title NOUN NN
# 11 NUM CD
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# structure NOUN NN
# [ PUNCT -LRB-
# d X XX
# ] X XX
# the DET DT
# debates NOUN NNS
# to PART TO
# promote VERB VB
# or CCONJ CC
# advance VERB VB
# one NUM CD
# candidate NOUN NN
# over ADP IN
# another DET DT
# \ NOUN NN
# " PUNCT ''
# through ADP IN
# a DET DT
# July PROPN NNP
# 27 NUM CD
# change NOUN NN
# to ADP IN
# its PRON PRP$
# criteria NOUN NNS
# that PRON WDT
# replaced VERB VBD
# a DET DT
# pre ADJ JJ
# - ADJ JJ
# existing VERB VBG
# one NUM CD
# percent NOUN NN
# polling NOUN NN
# threshold NOUN NN
# with ADP IN
# a DET DT
# threshold NOUN NN
# admitting VERB VBG
# those DET DT
# \ PROPN NNP
# ...
# 1 NUM CD
# – PUNCT :
# 2 NUM CD
# resulted VERB VBD
# in ADP IN
# at ADV RB
# least ADV RBS
# 56 NUM CD
# killed VERB VBN
# inmates NOUN NNS
# , PUNCT ,
# of ADP IN
# whom PRON WP
# many ADJ JJ
# were AUX VBD
# beheaded VERB VBN
# and CCONJ CC
# dismembered VERB VBN
# . PUNCT .
#
#  SPACE _SP
# On ADP IN
# the DET DT
# day NOUN NN
# of ADP IN
# the DET DT
# discovery NOUN NN
# Hyza PROPN NNP
# quickly ADV RB
# removed VERB VBD
# a DET DT
# graphic NOUN NN
# from ADP IN
# their PRON PRP$
# homepage NOUN NN
# featuring VERB VBG
# cartoon NOUN NN
# chicken NOUN NN
# stowaways NOUN NNS
# in ADP IN
# a DET DT
# car NOUN NN
# being AUX VBG
# inspected VERB VBN
# at ADP IN
# a DET DT
# customs NOUN NN
# post NOUN NN
# . PUNCT .
#
#  SPACE _SP
# I PRON PRP
# do AUX VBP
# n't PART RB
# own VERB VB
# a DET DT
# car NOUN NN
# , PUNCT ,
# so SCONJ IN
# that PRON DT
# means VERB VBZ
# I PRON PRP
# ' AUX VBP
# m AUX VBP
# excused VERB VBN
# right ADJ JJ
# ? PUNCT .
#
#  SPACE _SP
# NASA PROPN NNP
# said VERB VBD
# mountains NOUN NNS
# on ADP IN
# the DET DT
# planet NOUN NN
# may AUX MD
# be AUX VB
# made VERB VBN
# of ADP IN
# water NOUN NN
# - PUNCT HYPH
# ice NOUN NN
# . PUNCT .
#
#  SPACE _SP
# We PRON PRP
# collected VERB VBD
# wild ADJ JJ
# colonies NOUN NNS
# of ADP IN
# Formica PROPN NNP
# fusca NOUN NN
# by ADP IN
# searching VERB VBG
# through ADP IN
# old ADJ JJ
# tree NOUN NN
# - PUNCT HYPH
# trunks NOUN NNS
# in ADP IN
# old ADJ JJ
# logging NOUN NN
# sites NOUN NNS
# in ADP IN
# southern ADJ JJ
# Finland PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# 32 NUM CD
# - PUNCT HYPH
# year NOUN NN
# - PUNCT HYPH
# old ADJ JJ
# artist NOUN NN
# has AUX VBZ
# been AUX VBN
# charged VERB VBN
# on ADP IN
# several ADJ JJ
# occasions NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Thailand PROPN NNP
# began VERB VBD
# purchasing VERB VBG
# the DET DT
# Swedish PROPN NNP
# - PUNCT HYPH
# built VERB VBN
# Gripen PROPN NNP
# jets NOUN NNS
# in ADP IN
# 2008 NUM CD
# and CCONJ CC
# has VERB VBZ
# twelve NUM CD
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# four NUM CD
# accused VERB VBN
# were AUX VBD
# escorted VERB VBN
# into ADP IN
# court NOUN NN
# in ADP IN
# Kecskemet PROPN NNP
# , PUNCT ,
# central ADJ JJ
# Hungary PROPN NNP
# , PUNCT ,
# by ADP IN
# a DET DT
# police NOUN NN
# convoy NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# arrested VERB VBN
# men NOUN NNS
# are AUX VBP
# thought VERB VBN
# to PART TO
# include VERB VB
# the DET DT
# vehicle NOUN NN
# 's PART POS
# owner NOUN NN
# and CCONJ CC
# at ADV RB
# least ADV RBS
# two NUM CD
# drivers NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Since SCONJ IN
# the DET DT
# annexation NOUN NN
# of ADP IN
# Crimea PROPN NNP
# , PUNCT ,
# Russia PROPN NNP
# has AUX VBZ
# recently ADV RB
# been AUX VBN
# increasing VERB VBG
# its PRON PRP$
# military ADJ JJ
# presence NOUN NN
# in ADP IN
# Kalingrad PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Authorities NOUN NNS
# say VERB VBP
# the DET DT
# suspect NOUN NN
# may AUX MD
# have AUX VB
# already ADV RB
# left VERB VBN
# Thailand PROPN NNP
# and CCONJ CC
# was AUX VBD
# assisted VERB VBN
# by ADP IN
# others NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# French ADJ JJ
# President PROPN NNP
# François PROPN NNP
# Hollande PROPN NNP
# visited VERB VBD
# the DET DT
# scene NOUN NN
# last ADJ JJ
# week NOUN NN
# . PUNCT .
#
#  SPACE _SP
# It PRON PRP
# also ADV RB
# says VERB VBZ
# they PRON PRP
# have AUX VBP
# not PART RB
# backed VERB VBN
# up ADP RP
# their PRON PRP$
# torture NOUN NN
# claims NOUN NNS
# with ADP IN
# evidence NOUN NN
# , PUNCT ,
# medical ADJ JJ
# or CCONJ CC
# otherwise ADV RB
# . PUNCT .
#
#  SPACE _SP
# Choe PROPN NNP
# was AUX VBD
# involved VERB VBN
# with ADP IN
# trade NOUN NN
# talks NOUN NNS
# between ADP IN
# the DET DT
# two NUM CD
# Koreas PROPN NNPS
# in ADP IN
# the DET DT
# mid-2000s NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# In ADP IN
# a DET DT
# recently ADV RB
# - PUNCT HYPH
# accepted VERB VBN
# Evolution PROPN NNP
# paper NOUN NN
# Bos PROPN NNP
# and CCONJ CC
# colleagues NOUN NNS
# describe VERB VBP
# ants NOUN NNS
# appearing VERB VBG
# to ADP IN
# self NOUN NN
# - PUNCT HYPH
# medicate NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Yesterday NOUN NN
# , PUNCT ,
# former ADJ JJ
# Indian ADJ JJ
# president NOUN NN
# APJ PROPN NNP
# Abdul PROPN NNP
# Kalam PROPN NNP
# died VERB VBD
# at ADP IN
# the DET DT
# age NOUN NN
# of ADP IN
# 83 NUM CD
# after ADP IN
# collapsing VERB VBG
# at ADP IN
# about ADV RB
# 6:30 NUM CD
# p.m. NOUN NN
# local ADJ JJ
# time NOUN NN
# ( PUNCT -LRB-
# 0000 NUM CD
# today NOUN NN
# UTC PROPN NNP
# ) PUNCT -RRB-
# while SCONJ IN
# delivering VERB VBG
# a DET DT
# speech NOUN NN
# about ADP IN
# Livable PROPN NNP
# Planet PROPN NNP
# Earth PROPN NNP
# at ADP IN
# the DET DT
# Indian PROPN NNP
# Institute PROPN NNP
# of ADP IN
# Management PROPN NNP
# Shillong PROPN NNP
# , PUNCT ,
# in ADP IN
# Meghalaya PROPN NNP
# , PUNCT ,
# India PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# One NUM CD
# piece NOUN NN
# appears VERB VBZ
# to PART TO
# have VERB VB
# a DET DT
# serial ADJ JJ
# number NOUN NN
# on ADP IN
# the DET DT
# side NOUN NN
# , PUNCT ,
# possibly ADV RB
# reading VERB VBG
# \ PROPN NNP
# ' PART POS
# 021411270507 NUM CD
# . PUNCT .
# \ PROPN NNP
# ' PUNCT ''
#
#  SPACE _SP
# Some PROPN NNP
# also ADV RB
# noted VERB VBD
# the DET DT
# colors NOUN NNS
# appeared VERB VBD
# to PART TO
# resemble VERB VB
# that PRON DT
# of ADP IN
# a DET DT
# Malaysia PROPN NNP
# Airlines PROPN NNP
# plane NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Earlier ADJ JJR
# today NOUN NN
# the DET DT
# company NOUN NN
# 's PART POS
# website NOUN NN
# sported VERB VBD
# an DET DT
# apparent ADJ JJ
# anti ADJ JJ
# - ADJ JJ
# immigration ADJ JJ
# graphic NOUN NN
# , PUNCT ,
# which PRON WDT
# has AUX VBZ
# since SCONJ IN
# been AUX VBN
# removed VERB VBN
# . PUNCT .
#
#  SPACE _SP
# Bomb PROPN NNP
# kills VERB VBZ
# at ADV RB
# least ADJ JJS
# 50 NUM CD
# in ADP IN
# Gao PROPN NNP
# , PUNCT ,
# Mali PROPN NNP
# A DET DT
# vehicle NOUN NN
# packed VERB VBN
# with ADP IN
# explosives NOUN NNS
# was AUX VBD
# detonated VERB VBN
# this DET DT
# morning NOUN NN
# in ADP IN
# Gao PROPN NNP
# , PUNCT ,
# Mali PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Choe PROPN NNP
# , PUNCT ,
# one NUM CD
# of ADP IN
# seven NUM CD
# vice NOUN NN
# premiers NOUN NNS
# , PUNCT ,
# was AUX VBD
# in ADP IN
# charge NOUN NN
# of ADP IN
# construction NOUN NN
# and CCONJ CC
# building NOUN NN
# material NOUN NN
# industries NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# unidentified ADJ JJ
# man NOUN NN
# has AUX VBZ
# been AUX VBN
# summonsed VERB VBN
# to PART TO
# appear VERB VB
# at ADP IN
# Maidstone PROPN NNP
# Magistrates PROPN NNPS
# ' PART POS
# Court PROPN NNP
# on ADP IN
# February PROPN NNP
# 17 NUM CD
# . PUNCT .
#
#  SPACE _SP
# Malian ADJ JJ
# President PROPN NNP
# Ibrahim PROPN NNP
# Boubacar PROPN NNP
# Keita PROPN NNP
# took VERB VBD
# to ADP IN
# Twitter PROPN NNP
# today NOUN NN
# to PART TO
# declare VERB VB
# three NUM CD
# days NOUN NNS
# of ADP IN
# mourning NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Prosecutors NOUN NNS
# allege VERB VBP
# Baldetti PROPN NNP
# and CCONJ CC
# Molina PROPN NNP
# between ADP IN
# them PRON PRP
# received VERB VBD
# half NOUN NN
# of ADP IN
# all DET DT
# bribes NOUN NNS
# in ADP IN
# the DET DT
# case NOUN NN
# . PUNCT .
#
#  SPACE _SP
# IndyCar PROPN NNP
# driver NOUN NN
# Justin PROPN NNP
# Wilson PROPN NNP
# dies VERB VBZ
# aged ADJ JJ
# 37 NUM CD
# Yesterday NOUN NN
# , PUNCT ,
# 37 NUM CD
# - PUNCT HYPH
# year NOUN NN
# old ADJ JJ
# IndyCar PROPN NNP
# Series PROPN NNP
# driver NOUN NN
# Justin PROPN NNP
# Wilson PROPN NNP
# died VERB VBD
# of ADP IN
# injuries NOUN NNS
# sustained VERB VBN
# on ADP IN
# Sunday PROPN NNP
# during ADP IN
# the DET DT
# ABC PROPN NNP
# Supply PROPN NNP
# 500 NUM CD
# at ADP IN
# Pocono PROPN NNP
# Raceway PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# A DET DT
# further ADJ JJ
# question NOUN NN
# raised VERB VBN
# had AUX VBD
# been AUX VBN
# regarding VERB VBG
# Wilson PROPN NNP
# 's PART POS
# height NOUN NN
# : PUNCT :
# at ADP IN
# 6 NUM CD
# feet NOUN NNS
# , PUNCT ,
# 3.5 NUM CD
# inches NOUN NNS
# ( PUNCT -LRB-
# 1.92 NUM CD
# m NOUN NN
# ) PUNCT -RRB-
# tall ADJ JJ
# , PUNCT ,
# Wilson PROPN NNP
# was AUX VBD
# the DET DT
# tallest ADJ JJS
# IndyCar PROPN NNP
# Series PROPN NNP
# driver NOUN NN
# ; PUNCT :
# however ADV RB
# , PUNCT ,
# driver NOUN NN
# Josef PROPN NNP
# Newgarden PROPN NNP
# refuted VERB VBD
# the DET DT
# statement NOUN NN
# , PUNCT ,
# saying VERB VBG
# , PUNCT ,
# \ PROPN NNP
# " PUNCT ''
# They PRON PRP
# make VERB VBP
# a DET DT
# regulation NOUN NN
# for ADP IN
# how SCONJ WRB
# tall ADJ JJ
# you PRON PRP
# can AUX MD
# be AUX VB
# inside ADP IN
# the DET DT
# car NOUN NN
# sitting VERB VBG
# compared VERB VBN
# to ADP IN
# the DET DT
# roll NOUN NN
# hoop NOUN NN
# [ PUNCT -LRB-
# ... PUNCT NFP
# ] PUNCT -RRB-
# It PRON PRP
# 's AUX VBZ
# safe ADJ JJ
# for ADP IN
# any DET DT
# height NOUN NN
# for ADP IN
# any DET DT
# driver NOUN NN
# that PRON WDT
# gets VERB VBZ
# in ADP IN
# the DET DT
# car NOUN NN
# . PUNCT .
# \ PROPN NNP
# " PUNCT ''
#
#  SPACE _SP
# For ADP IN
# example NOUN NN
# , PUNCT ,
# once SCONJ IN
# we PRON PRP
# find VERB VBP
# the DET DT
# source NOUN NN
# of ADP IN
# the DET DT
# medicine NOUN NN
# in ADP IN
# nature NOUN NN
# ... PUNCT :
# would AUX MD
# species VERB VB
# without ADP IN
# access NOUN NN
# to ADP IN
# this DET DT
# source NOUN NN
# also ADV RB
# have AUX VBP
# evolved VERB VBN
# the DET DT
# same ADJ JJ
# behaviour NOUN NN
# in ADP IN
# the DET DT
# lab NOUN NN
# ? PUNCT .
#
#  SPACE _SP
# Yonhap PROPN NNP
# has AUX VBZ
# attributed VERB VBN
# roughly ADV RB
# 70 NUM CD
# executions NOUN NNS
# of ADP IN
# officials NOUN NNS
# to ADP IN
# Kim PROPN NNP
# Jong PROPN NNP
# - PUNCT HYPH
# un PROPN NNP
# 's PART POS
# rule NOUN NN
# which PRON WDT
# began VERB VBD
# after ADP IN
# the DET DT
# death NOUN NN
# of ADP IN
# his PRON PRP$
# father NOUN NN
# Kim PROPN NNP
# Jong PROPN NNP
# - PUNCT HYPH
# il PROPN NNP
# in ADP IN
# December PROPN NNP
# 2011 NUM CD
# . PUNCT .
#
#  SPACE _SP
# At ADP IN
# the DET DT
# time NOUN NN
# of ADP IN
# the DET DT
# murders NOUN NNS
# , PUNCT ,
# Conley PROPN NNP
# was AUX VBD
# wanted VERB VBN
# on ADP IN
# an DET DT
# assault NOUN NN
# charge NOUN NN
# against ADP IN
# a DET DT
# family NOUN NN
# member NOUN NN
# . PUNCT .
#
#  SPACE _SP
# At ADP IN
# the DET DT
# moment NOUN NN
# it PRON PRP
# seems VERB VBZ
# that SCONJ IN
# sick ADJ JJ
# ants NOUN NNS
# mostly ADV RB
# take VERB VBP
# care NOUN NN
# of ADP IN
# the DET DT
# problem NOUN NN
# themselves PRON PRP
# . PUNCT .
#
#  SPACE _SP
# UK PROPN NNP
# judge NOUN NN
# withholds VERB VBZ
# report NOUN NN
# from ADP IN
# Thai PROPN NNP
# death NOUN NN
# penalty NOUN NN
# defendants NOUN NNS
# In ADP IN
# a DET DT
# judgement NOUN NN
# released VERB VBN
# today NOUN NN
# Mr PROPN NNP
# Justice PROPN NNP
# Green PROPN NNP
# , PUNCT ,
# sitting VERB VBG
# in ADP IN
# the DET DT
# High PROPN NNP
# Court PROPN NNP
# in ADP IN
# London PROPN NNP
# , PUNCT ,
# spoke VERB VBD
# of ADP IN
# his PRON PRP$
# \ NOUN NN
# " PUNCT ''
# very ADV RB
# considerable ADJ JJ
# unease NOUN NN
# \ PROPN NNP
# " PUNCT ''
# as SCONJ IN
# he PRON PRP
# rejected VERB VBD
# an DET DT
# application NOUN NN
# by ADP IN
# two NUM CD
# defendants NOUN NNS
# in ADP IN
# a DET DT
# Thai PROPN NNP
# death NOUN NN
# penalty NOUN NN
# case NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Some DET DT
# ants NOUN NNS
# were AUX VBD
# infected VERB VBN
# with ADP IN
# Beauveria PROPN NNP
# bassiana PROPN NNP
# , PUNCT ,
# a DET DT
# fungus NOUN NN
# . PUNCT .
#
#  SPACE _SP
# I PRON PRP
# still ADV RB
# have VERB VBP
# some DET DT
# questions NOUN NNS
# left VERB VBN
# unanswered ADJ JJ
# from ADP IN
# my PRON PRP$
# Ph PROPN NNP
# . PUNCT .
# D. PROPN NNP
# work NOUN NN
# related VERB VBN
# to ADP IN
# how SCONJ WRB
# ants NOUN NNS
# recognize VERB VBP
# who PRON WP
# is AUX VBZ
# a DET DT
# friend NOUN NN
# and CCONJ CC
# who PRON WP
# is AUX VBZ
# n't PART RB
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# Krone PROPN NNP
# published VERB VBD
# an DET DT
# image NOUN NN
# of ADP IN
# a DET DT
# non ADJ JJ
# - ADJ JJ
# articulated ADJ JJ
# food NOUN NN
# lorry NOUN NN
# on ADP IN
# the DET DT
# hard ADJ JJ
# shoulder NOUN NN
# , PUNCT ,
# which PRON WDT
# they PRON PRP
# report VERB VBP
# is AUX VBZ
# the DET DT
# vehicle NOUN NN
# in ADP IN
# question NOUN NN
# . PUNCT .
#
#  SPACE _SP
# Burmese ADJ JJ
# nationals NOUN NNS
# Zaw PROPN NNP
# Lin PROPN NNP
# and CCONJ CC
# Wai PROPN NNP
# Phyo PROPN NNP
# , PUNCT ,
# both DET DT
# 22 NUM CD
# , PUNCT ,
# are AUX VBP
# currently ADV RB
# on ADP IN
# trial NOUN NN
# accused VERB VBN
# of ADP IN
# murdering VERB VBG
# David PROPN NNP
# Miller PROPN NNP
# , PUNCT ,
# 24 NUM CD
# , PUNCT ,
# from ADP IN
# Jersey PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Hannah PROPN NNP
# Witheridge PROPN NNP
# , PUNCT ,
# 23 NUM CD
# , PUNCT ,
# from ADP IN
# England PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# driver NOUN NN
# , PUNCT ,
# from ADP IN
# Romania PROPN NNP
# , PUNCT ,
# refused VERB VBD
# to PART TO
# stop VERB VB
# for ADP IN
# police NOUN NNS
# and CCONJ CC
# was AUX VBD
# arrested VERB VBN
# following VERB VBG
# a DET DT
# chase NOUN NN
# . PUNCT .
#
#  SPACE _SP
# By ADP IN
# adding VERB VBG
# certain ADJ JJ
# chemicals NOUN NNS
# , PUNCT ,
# the DET DT
# ROS PROPN NNP
# can AUX MD
# be AUX VB
# measured VERB VBN
# using VERB VBG
# the DET DT
# emission NOUN NN
# of ADP IN
# light NOUN NN
# of ADP IN
# a DET DT
# certain ADJ JJ
# wave NOUN NN
# - PUNCT HYPH
# length NOUN NN
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# theatre NOUN NN
# claims VERB VBZ
# to PART TO
# have VERB VB
# a DET DT
# CCTV PROPN NNP
# video NOUN NN
# footage NOUN NN
# of ADP IN
# Pavlensky PROPN NNP
# and CCONJ CC
# other ADJ JJ
# men NOUN NNS
# beating VERB VBG
# Slonina PROPN NNP
# 's PART POS
# boyfriend NOUN NN
# in ADP IN
# the DET DT
# parking NOUN NN
# lot NOUN NN
# on ADP IN
# October PROPN NNP
# 31 NUM CD
# . PUNCT .
#
#  SPACE _SP
# US PROPN NNP
# economy NOUN NN
# adds VERB VBZ
# 215,000 NUM CD
# jobs NOUN NNS
# in ADP IN
# July PROPN NNP
# ; PUNCT :
# unemployment NOUN NN
# rate NOUN NN
# remains VERB VBZ
# steady ADJ JJ
# at ADP IN
# 5.3 NUM CD
# % NOUN NN
# The DET DT
# Bureau PROPN NNP
# of ADP IN
# Labor PROPN NNP
# Statistics PROPN NNPS
# reported VERB VBD
# that SCONJ IN
# the DET DT
# US PROPN NNP
# economy NOUN NN
# added VERB VBD
# 215,000 NUM CD
# jobs NOUN NNS
# in ADP IN
# July PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# camp NOUN NN
# was AUX VBD
# formed VERB VBN
# as ADP IN
# part NOUN NN
# of ADP IN
# a DET DT
# disputed VERB VBN
# ceasefire NOUN NN
# . PUNCT .
#
#  SPACE _SP
# In ADP IN
# 2004 NUM CD
# , PUNCT ,
# he PRON PRP
# attended VERB VBD
# the DET DT
# opening NOUN NN
# of ADP IN
# the DET DT
# Kaesong PROPN NNP
# Industrial PROPN NNP
# Region PROPN NNP
# , PUNCT ,
# a DET DT
# joint ADJ JJ
# venture NOUN NN
# of ADP IN
# the DET DT
# two NUM CD
# nations NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# Royal PROPN NNP
# Thai PROPN NNP
# Air PROPN NNP
# Force PROPN NNP
# asked VERB VBD
# that SCONJ IN
# images NOUN NNS
# of ADP IN
# the DET DT
# accident NOUN NN
# not PART RB
# be AUX VB
# shared VERB VBN
# , PUNCT ,
# but CCONJ CC
# this PRON DT
# has AUX VBZ
# not PART RB
# deterred VERB VBN
# the DET DT
# press NOUN NN
# . PUNCT .
#
#  SPACE _SP
# On ADP IN
# Sunday PROPN NNP
# , PUNCT ,
# Bayern PROPN NNP
# announced VERB VBD
# signings NOUN NNS
# of ADP IN
# 21 NUM CD
# - PUNCT HYPH
# year NOUN NN
# - PUNCT HYPH
# old ADJ JJ
# Niklas PROPN NNP
# Süle PROPN NNP
# and CCONJ CC
# 26 NUM CD
# - PUNCT HYPH
# year NOUN NN
# - PUNCT HYPH
# old ADJ JJ
# Sebastian ADJ JJ
# Rudy PROPN NNP
# from ADP IN
# TSG PROPN NNP
# 1899 NUM CD
# Hoffenheim PROPN NNP
# who PRON WP
# are AUX VBP
# to PART TO
# join VERB VB
# the DET DT
# Bayern PROPN NNP
# squad NOUN NN
# in ADP IN
# July PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# This PRON DT
# made VERB VBD
# only ADV RB
# the DET DT
# fourth ADJ JJ
# time NOUN NN
# in ADP IN
# U.S. PROPN NNP
# history NOUN NN
# that SCONJ IN
# this DET DT
# modified VERB VBN
# form NOUN NN
# , PUNCT ,
# the DET DT
# Medal PROPN NNP
# of ADP IN
# Freedom PROPN NNP
# with ADP IN
# distinction NOUN NN
# , PUNCT ,
# has AUX VBZ
# been AUX VBN
# awarded VERB VBN
# . PUNCT .
#
#  SPACE _SP
# Conley PROPN NNP
# also ADV RB
# felt VERB VBD
# all DET PDT
# the DET DT
# victims NOUN NNS
# disrespected VERB VBN
# and CCONJ CC
# mistreated VERB VBD
# him PRON PRP
# . PUNCT .
#
#  SPACE _SP
# The DET DT
# study NOUN NN
# covered VERB VBD
# many ADJ JJ
# parts NOUN NNS
# of ADP IN
# the DET DT
# brain NOUN NN
# already ADV RB
# known VERB VBN
# to PART TO
# be AUX VB
# associated VERB VBN
# with ADP IN
# feeding NOUN NN
# , PUNCT ,
# and CCONJ CC
# the DET DT
# results NOUN NNS
# suggested VERB VBD
# some DET DT
# areas NOUN NNS
# are AUX VBP
# associated VERB VBN
# with ADP IN
# both PRON DT
# hunting VERB VBG
# and CCONJ CC
# feeding NOUN NN
# and CCONJ CC
# others NOUN NNS
# only ADV RB
# with ADP IN
# just ADV RB
# one NUM CD
# behavior NOUN NN
# . PUNCT .
#
#  SPACE _SP
# He PRON PRP
# was AUX VBD
# elected VERB VBN
# last ADJ JJ
# year NOUN NN
# and CCONJ CC
# was AUX VBD
# previously ADV RB
# the DET DT
# Chief PROPN NNP
# Minister PROPN NNP
# of ADP IN
# Gujarat PROPN NNP
# for ADP IN
# more ADJ JJR
# than ADP IN
# twelve NUM CD
# years NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# Following VERB VBG
# Apollo PROPN NNP
# 17 NUM CD
# , PUNCT ,
# Cernan PROPN NNP
# worked VERB VBD
# on ADP IN
# the DET DT
# Apollo PROPN NNP
# - PUNCT HYPH
# Soyuz PROPN NNP
# project NOUN NN
# before ADP IN
# retiring VERB VBG
# from ADP IN
# NASA PROPN NNP
# and CCONJ CC
# the DET DT
# Navy PROPN NNP
# in ADP IN
# 1976 NUM CD
# . PUNCT .
#
#  SPACE _SP
# Manning PROPN NNP
# was AUX VBD
# convicted VERB VBN
# in ADP IN
# 2013 NUM CD
# of ADP IN
# 22 NUM CD
# charges NOUN NNS
# , PUNCT ,
# including VERB VBG
# espionage NOUN NN
# , PUNCT ,
# but CCONJ CC
# acquitted VERB VBN
# of ADP IN
# aiding VERB VBG
# the DET DT
# enemy NOUN NN
# . PUNCT .
#
#  SPACE _SP
# How SCONJ WRB
# common ADJ JJ
# are AUX VBP
# they PRON PRP
# in ADP IN
# the DET DT
# wild NOUN NN
# ? PUNCT .
#
#  SPACE _SP

# %%
tag_frequencies = Counter()

for sentence in doc.sents:
    tags = []
    for token in sentence: 
        if not token.is_punct:
            tags.append(token.tag_)
    tag_frequencies.update(tags)
    
print(tag_frequencies)
# Out:
# Counter({'NN': 2008, 'NNP': 1851, 'IN': 1745, 'DT': 1378, 'JJ': 853, 'NNS': 774, 'VBD': 660, '_SP': 653, 'VBN': 499, 'RB': 451, 'CD': 357, 'CC': 346, 'PRP': 338, 'VB': 326, 'VBZ': 301, 'VBG': 295, 'VBP': 195, 'TO': 182, 'PRP$': 145, 'POS': 94, 'MD': 93, 'WDT': 74, 'WRB': 46, 'RP': 40, 'WP': 38, 'NNPS': 35, 'JJS': 27, 'JJR': 23, 'RBS': 18, 'RBR': 18, 'EX': 14, 'UH': 7, '$': 4, 'PDT': 3, 'XX': 2, 'FW': 2})

# %%
token_frequencies = Counter()

for sentence in doc.sents:
    tokens = []
    for token in sentence: 
        if not token.is_punct:
            tokens.append(token.text)
    token_frequencies.update(tokens)
    
print(token_frequencies)
# Out:
# Counter({'the': 723, '\n': 653, 'of': 352, 'to': 333, 'and': 286, 'in': 285, 'a': 279, 'The': 124, 'on': 116, 'was': 111, "'s": 110, 'for': 102, 'with': 85, 'at': 84, 'is': 84, 'that': 79, 'as': 76, 'from': 65, 'has': 65, 'were': 62, 'it': 58, 'said': 56, 'he': 55, 'have': 55, 'his': 53, 'by': 52, 'are': 50, 'an': 49, 'not': 49, 'be': 48, 'this': 47, 'been': 46, 'ants': 42, 'they': 37, 'which': 37, 'their': 34, 'also': 34, 'had': 33, 'or': 31, 'who': 30, 'one': 30, 'about': 30, 'would': 30, 'year': 29, 'police': 27, 'other': 26, 'I': 26, 'but': 25, 'It': 25, 'our': 24, 'report': 24, 'US': 24, 'after': 24, 'He': 24, 'time': 23, 'In': 23, 'We': 22, 'two': 22, 'more': 22, 'we': 22, 'before': 20, 'Russian': 20, 'This': 20, 'can': 19, 'military': 19, 'troops': 19, 'Republican': 19, 'President': 19, 'do': 19, 'U.S.': 19, 'government': 18, 'Minister': 18, 'Wikinews': 18, 'any': 18, 'presidential': 18, 'its': 17, 'least': 17, 'many': 17, 'into': 16, 'some': 16, 'out': 15, 'people': 15, 'News': 15, 'last': 15, 'law': 15, 'over': 15, 'car': 15, 'Wilson': 15, 'during': 15, 'former': 15, 'Obama': 15, 'where': 14, 'Police': 14, 'when': 14, 'reported': 14, 'driver': 14, 'Pavlensky': 14, 'lorry': 14, 'case': 14, 'no': 14, 'dead': 14, 'very': 14, 'if': 14, 'local': 14, 'Russia': 14, 'you': 14, 'death': 14, 'first': 14, 'told': 14, 'so': 14, 'candidate': 14, 'Martin': 14, 'Everson': 13, 'Korea': 13, 'A': 13, 'will': 13, 'most': 13, 'found': 13, 'Bush': 13, 'old': 12, 'under': 12, 'accused': 12, 'security': 12, 'Bianchi': 12, 'only': 12, 'According': 12, 'day': 12, 'died': 12, 'now': 12, 'since': 12, 'North': 12, 'vehicle': 12, 'Thai': 12, 'them': 11, 'near': 11, 'yesterday': 11, 'without': 11, 'there': 11, 'May': 11, 'did': 11, 'European': 11, 'around': 11, 'After': 11, 'Trump': 11, 'president': 11, 'Manning': 11, 'food': 11, 'later': 11, 'says': 11, 'month': 10, 'announced': 10, 'called': 10, 'Hungary': 10, 'between': 10, "n't": 10, 'today': 10, 'family': 10, 'response': 10, 'while': 10, 'all': 10, 'both': 10, 'say': 10, 'Jackson': 10, 'court': 10, 'authorities': 9, 'Poland': 9, 'decision': 9, 'accident': 9, 'debris': 9, 'known': 9, 'according': 9, 'than': 9, 'being': 9, 'Justice': 9, 'care': 9, 'killed': 9, 'could': 9, 'several': 9, 'Hyza': 9, 'days': 9, 'men': 9, 'months': 9, 'political': 9, 'Thailand': 9, 'including': 9, 'state': 9, 'himself': 9, 'country': 9, 'made': 9, 'seven': 9, 'statement': 9, 'Prime': 9, 'Party': 9, 'debate': 9, 'released': 9, 'UK': 9, 'years': 8, 'different': 8, 'fungus': 8, 'up': 8, 'deployment': 8, 'Fox': 8, 'because': 8, 'left': 8, 'One': 8, 'Austria': 8, 'hours': 8, 'species': 8, 'set': 8, 'team': 8, 'use': 8, 'same': 8, 'crashed': 8, 'Polish': 8, 'how': 8, 'plan': 8, 'On': 8, 'July': 8, 'new': 8, 'stated': 8, 'New': 8, 'NB': 8, '2016': 8, 'saying': 8, 'following': 8, '2014': 8, 'seek': 8, 'see': 8, 'three': 7, 'Court': 7, 'South': 7, 'off': 7, 'December': 7, 'Robben': 7, 'described': 7, 'right': 7, '50': 7, 'well': 7, 'research': 7, 'Obamacare': 7, 'speech': 7, 'EU': 7, 'us': 7, 'American': 7, 'health': 7, 'ceremony': 7, 'her': 7, 'border': 7, 'home': 7, 'just': 7, 'Force': 7, 'Choe': 7, 'crash': 7, 'members': 7, 'Adnan': 7, 'self': 7, 'growth': 7, 'evidence': 7, 'infected': 7, 'seen': 7, 'jet': 7, 'Indian': 7, 'Mark': 7, 'began': 7, 'Putin': 7, '2013': 7, 'Formula': 7, 'safety': 7, 'through': 7, 'then': 7, '2012': 7, 'candidates': 7, 'took': 7, 'Federal': 7, 'might': 7, 'press': 7, 'Kalam': 7, 'against': 7, 'here': 7, 'like': 7, 'news': 7, 'media': 7, 'Molina': 7, 'aged': 6, 'ROS': 6, 'building': 6, 'noted': 6, 'part': 6, 'earlier': 6, 'France': 6, 'Bayern': 6, 'week': 6, '24': 6, 'due': 6, 'shows': 6, 'actually': 6, 'victims': 6, 'behavior': 6, 'continue': 6, "'re": 6, 'UTC': 6, 'another': 6, 'recent': 6, 'arrested': 6, 'even': 6, 'Air': 6, 'spokesperson': 6, 'previously': 6, 'five': 6, 'second': 6, 'race': 6, 'riot': 6, 'worked': 6, 'went': 6, 'anti': 6, 'general': 6, 'chief': 6, 'There': 6, 'know': 6, 'plan ...

# %%
# TODO : find the 3 most frequent ones

# %% [markdown]
# ### 3. N-Grams
#
# N-grams are a combination of N tokens that usually co-occur. For example, the word new occurs in a lot of contexts, but the word york frequently occurs with new. So we combine the two and get `new york` to give better information. Combining 2 tokens(unigrams) gives us a **bigram**. Higher order **n-grams** are formed using 2 (n-1)-grams. 2 bigrams give a **trigram**, 2 trigrams form a quadgram and so on.
#
# Calculate the distribution of n-grams and provide the 3 most frequent.
#  - `Token bigrams`
#  - `Token trigrams`
#  - `POS bigrams`
#  - `POS trigrams`

# %%
#for chunk in doc.noun_chunks:
#    print(chunk.text, chunk.root.text, chunk.root.dep_,chunk.root.head.text)

# %%
def n_grams(text,tokens,n):
    tokens = [token.text for token in text]
    
    return [tokens[i:i+n] for i in range(len(tokens)-n+1)]

# %%
token_bigrams = n_grams(doc,tokens,2)
token_trigrams = n_grams(doc,tokens,4)
#print(token_bigrams)
print(token_trigrams) # ['children', 'are', 'thought', 'to']

# %%
def most_frequent(List):
    counter = 0
    item = List[0]
     
    for i in List:
        curr_frequency = List.count(i)
        if(curr_frequency > counter):
            counter = curr_frequency
            item = i
 
    return item

# %%
most_frequent(token_bigrams)

# %%
most_frequent(token_trigrams)

# %%
# TODO : find the POS bigrams and POS trigrams

# %% [markdown]
# ### 4. Lemmatization
#
# Provide an example for a lemma that occurs in `more than two inflections` in the dataset.

# %%
def lemmatization(text):
    
    for token in text:
        if token.pos_ == 'VERB':
            print('{} -> {}'.format(token, token.lemma_))

# %%
lemmatization(doc)
# Out:
# thought -> think
# aged -> age
# mixed -> mix
# plated -> plate
# grow -> grow
# feel -> feel
# represented -> represent
# suffering -> suffer
# concerns -> concern
# building -> build
# said -> say
# hospitalised -> hospitalise
# wrote -> write
# noted -> note
# listening -> listen
# starting -> start
# doing -> do
# impede -> impede
# protesting -> protest
# argues -> argue
# requires -> require
# fail -> fail
# define -> define
# recognized -> recognize
# referring -> refer
# challenged -> challenge
# reported -> report
# evacuated -> evacuate
# landed -> land
# left -> leave
# came -> come
# avoiding -> avoid
# falling -> fall
# accused -> accuse
# moving -> move
# left -> leave
# flying -> fly
# relates -> relate
# signs -> sign
# announced -> announce
# signed -> sign
# working -> work
# called -> call
# known -> know
# filed -> file
# obtained -> obtain
# held -> hold
# citing -> cite
# want -> want
# extended -> extend
# threaten -> threaten
# used -> use
# described -> describe
# deliver -> deliver
# challenging -> challenge
# issue -> issue
# starts -> start
# analysed -> analyse
# shows -> show
# said -> say
# said -> say
# causing -> cause
# faces -> face
# covering -> cover
# believed -> believe
# wedged -> wedge
# causing -> cause
# fell -> fall
# follow -> follow
# extrapolate -> extrapolate
# lead -> lead
# set -> set
# repeal -> repeal
# according -> accord
# expelled -> expel
# accused -> accuse
# sanctioned -> sanction
# believes -> believe
# has -> have
# files -> file
# complaining -> complain
# forced -> force
# hospitalize -> hospitalize
# placed -> place
# dispatched -> dispatch
# prepared -> prepare
# use -> use
# assisting -> assist
# stimulated -> stimulate
# stalking -> stalk
# stimulated -> stimulate
# use -> use
# stressed -> stress
# ruled -> rule
# allow -> allow
# control -> control
# require -> require
# continue -> continue
# bound -> bind
# working -> work
# begin -> begin
# craft -> craft
# repeal -> repeal
# moving -> move
# allow -> allow
# introduce -> introduce
# lower -> lower
# growing -> grow
# said -> say
# crashed -> crash
# exploded -> explode
# closing -> close
# interred -> inter
# noted -> note
# needed -> need
# exposing -> expose
# came -> come
# arrested -> arrest
# slamming -> slam
# involved -> involve
# ruled -> rule
# prevented -> prevent
# negotiating -> negotiate
# posted -> post
# bloody -> bloody
# fined -> fine
# dipped -> dip
# dried -> dry
# put -> put
# said -> say
# appear -> appear
# condemned -> condemn
# beaten -> beat
# trying -> try
# stigmatize -> stigmatize
# criminalize -> criminalize
# practicing -> practice
# said -> say
# formed -> form
# noted -> note
# attack -> attack
# found -> find
# have -> have
# goes -> go
# documented -> document
# indicated -> indicate
# seeks -> seek
# According -> accord
# disagreed -> disagree
# acquiring -> acquire
# increased -> increase
# recorded -> record
# earmarked -> earmark
# crossed -> cross
# count -> count
# died -> die
# gained -> gain
# rule -> rule
# related -> relate
# killed -> kill
# called -> call
# called -> call
# protect -> protect
# tackle -> tackle
# sent -> send
# think -> think
# found -> find
# raising -> raise
# reported -> report
# preventing -> prevent
# contributed -> contribute
# sewed -> sew
# support -> support
# imprisoned -> imprison
# said -> say
# plan -> plan
# investigate -> investigate
# served -> serve
# worked -> work
# worked -> work
# continue -> continue
# went -> go
# preferred -> prefer
# have -> have
# impose -> impose
# said -> say
# impugned -> impugn
# claims -> claim
# result -> result
# converted -> convert
# estimated -> estimate
# traveled -> travel
# passing -> pass
# shows -> show
# issued -> issue
# concluded -> conclude
# hacked -> hack
# belonging -> belong
# told -> tell
# changed -> change
# lying -> lie
# has -> have
# lasted -> last
# reported -> report
# medicating -> medicate
# agreed -> agree
# According -> accord
# speaking -> speak
# work -> work
# stated -> state
# 's -> be
# smell -> smell
# set -> set
# include -> include
# thought -> think
# suffocated -> suffocate
# want -> want
# find -> find
# get -> get
# dismiss -> dismiss
# given -> give
# housed -> house
# spent -> spend
# attempted -> attempt
# tell -> tell
# infected -> infect
# encourage -> encourage
# Following -> follow
# hit -> hit
# means -> mean
# know -> know
# belong -> belong
# influence -> influence
# stated -> state
# attack -> attack
# broadcasting -> broadcast
# respond -> respond
# stop -> stop
# heard -> hear
# called -> call
# said -> say
# referencing -> reference
# went -> go
# claimed -> claim
# seen -> see
# flying -> fly
# need -> need
# voting -> vote
# vote -> vote
# added -> add
# including -> include
# reported -> report
# injured -> injure
# operated -> operate
# Placed -> place
# began -> begin
# finalised -> finalise
# infected -> infect
# echoed -> echo
# saying -> say
# died -> die
# located -> locate
# announced -> announce
# build -> build
# including -> include
# house -> house
# create -> create
# counter -> counter
# declares -> declare
# reserving -> reserve
# praises -> praise
# died -> die
# allowed -> allow
# fly -> fly
# according -> accord
# related -> relate
# appeared -> appear
# captured -> capture
# posted -> post
# included -> include
# cites -> cite
# confirmed -> confirm
# caused -> cause
# closed -> close
# measured -> measure
# ingested -> ingest
# using -> use
# stated -> state
# knowing -> know
# Based -> base
# observed -> observe
# served -> serve
# joined -> join
# scored -> score
# known -> know
# contain -> contain
# disputed -> dispute
# made -> make
# lifting -> lift
# falls -> fall
# crashed -> crash
# killing -> kill
# have -> have
# entering -> enter
# joined -> join
# assisted -> assist
# said -> say
# resulting -> result
# raised -> raise
# judge -> judge
# charged -> charge
# performing -> perform
# building -> build
# torn -> tear
# seek -> seek
# covers -> cover
# pulled -> pull
# shot -> shoot
# commuted -> commute
# linked -> link
# convicted -> convict
# lying -> lie
# supported -> support
# opposed -> oppose
# affecting -> affect
# limiting -> limit
# worry -> worry
# escaping -> escape
# burning -> burn
# behaved -> behave
# stated -> state
# measuring -> measure
# found -> find
# washed -> wash
# set -> set
# based -> base
# scheduled -> schedule
# welcome -> welcome
# killing -> kill
# mistook -> mistook
# said -> say
# firing -> fire
# opposed -> oppose
# refuse -> refuse
# relinquish -> relinquish
# give -> give
# told -> tell
# monitoring -> monitor
# seen -> see
# struck -> strike
# argues -> argue
# promote -> promote
# advance -> advance
# replaced -> replace
# existing -> exist
# admitting -> admit
# included -> include
# recognized -> recognize
# preventing -> prevent
# gaining -> gain
# intends -> intend
# focus -> focus
# protecting -> protect
# defending -> defend
# combating -> combat
# emphasizing -> emphasize
# fighting -> fight
# reports -> report
# do -> do
# coming -> come
# dismissed -> dismiss
# asserts -> assert
# included -> include
# listed -> list
# excluded -> exclude
# sold -> sell
# exported -> export
# registered -> register
# has -> have
# determined -> determine
# reported -> report
# burned -> burn
# turned -> turn
# including -> include
# provide -> provide
# placed -> place
# extracted -> extract
# flying -> fly
# vanished -> vanish
# authorised -> authorise
# annexed -> annex
# gave -> give
# choose -> choose
# infected -> infect
# known -> know
# spreading -> spread
# concerning -> concern
# ran -> run
# sought -> seek
# pictured -> picture
# enjoyed -> enjoy
# invited -> invite
# casts -> cast
# participate -> participate
# dies -> die
# walk -> walk
# died -> die
# according -> accord
# paid -> pay
# flew -> fly
# infected -> infect
# preparing -> prepare
# took -> take
# talk -> talk
# saw -> see
# enter -> enter
# according -> accord
# accused -> accuse
# claim -> claim
# tortured -> torture
# seem -> seem
# taking -> take
# ensued -> ensue
# attempted -> attempt
# pull -> pull
# arrived -> arrive
# working -> work
# exploiting -> exploit
# have -> have
# get -> get
# killed -> kill
# posted -> post
# ' -> '
# m -> m
# celebrate -> celebrate
# recognized -> recognize
# found -> find
# took -> take
# told -> tell
# affected -> affect
# said -> say
# closed -> close
# sold -> sell
# say -> say
# exported -> export
# bears -> bear
# features -> feature
# including -> include
# asked -> ask
# pardoned -> pardon
# preventing -> prevent
# housed -> house
# made -> make
# using -> use
# aerated -> aerate
# reported -> report
# fired -> fire
# living -> live
# claiming -> claim
# filed -> file
# run -> run
# argues -> argue
# violates -> violate
# \ -> \
# promote -> promote
# advance -> advance
# use -> use
# pre -> pre
# determine -> determine
# participate -> participate
# moving -> move
# funded -> fund
# want -> want
# know -> know
# pointed -> point
# start -> start
# got -> get
# penned -> pen
# spotted -> spot
# alerted -> alert
# wrapped -> wrap
# described -> describe
# do -> do
# announced -> announce
# outlined -> outline
# serve -> serve
# calls -> call
# seems -> seem
# expedited -> expedite
# meet -> meet
# require -> require
# included -> include
# recognized -> recognize
# urges -> urge
# compel -> compel
# include -> include
# dubbed -> dub
# gagging -> gag
# claim -> claim
# appeared -> appear
# headed -> head
# announced -> announce
# outlined -> outline
# serve -> serve
# calls -> call
# inspired -> inspire
# carved -> carve
# live -> live
# covered -> cover
# prevent -> prevent
# escaping -> escape
# taken -> take
# declared -> declare
# claims -> claim
# fails -> fail
# meet -> meet
# established -> establish
# researched -> research
# based -> base
# threatens -> threaten
# according -> accord
# released -> release
# mounted -> mount
# deployed -> deploy
# challenges -> challenge
# filed -> file
# challenge -> challenge
# rules -> rule
# announced -> announce
# proceed -> proceed
# found -> find
# taken -> take
# commented -> comment
# had -> have
# denied -> deny
# described -> describe
# cited -> cite
# described -> describe
# have -> have
# become -> become
# told -> tell
# agree -> agree
# granted -> grant
# had -> have
# do -> do
# were -> be
# limited -> limit
# arranged -> arrange
# conduct -> conduct
# based -> base
# exposing -> expose
# took -> take
# foraging -> forage
# counted -> count
# ruled -> rule
# have -> have
# seek -> seek
# using -> use
# calling -> call
# won -> win
# celebrate -> celebrate
# finding -> find
# fired -> fire
# aimed -> aim
# broadcasts -> broadcast
# remained -> remain
# adapt -> adapt
# make -> make
# thought -> think
# use -> use
# evolve -> evolve
# discusses -> discuss
# waited -> wait
# told -> tell
# dies -> die
# research -> research
# delivered -> deliver
# read -> read
# outlines -> outline
# running -> run
# including -> include
# degrading -> degrade
# seeking -> seek
# deny -> deny
# said -> say
# checked -> check
# remain -> remain
# released -> release
# opposes -> oppose
# drilled -> drill
# got -> get
# suffocated -> suffocate
# identified -> identify
# sampling -> sample
# told -> tell
# takes -> take
# do -> do
# 's -> be
# Cquote1.svg -> Cquote1.svg
# seems -> seem
# take -> take
# used -> use
# come -> come
# took -> take
# pictured -> picture
# said -> say
# like -> like
# see -> see
# constructed -> construct
# said -> say
# repealing -> repeal
# replacing -> replace
# wants -> want
# reformed -> reform
# grown -> grow
# underlying -> underlie
# received -> receive
# appeared -> appear
# make -> make
# quoted -> quote
# saying -> say
# announces -> announce
# proclaimed -> proclaim
# announced -> announce
# seeking -> seek
# seek -> seek
# suggests -> suggest
# plays -> play
# intervened -> intervene
# speaking -> speak
# shot -> shoot
# said -> say
# airlifted -> airlift
# looking -> look
# see -> see
# were -> be
# paying -> pay
# mentioned -> mention
# known -> know
# referring -> refer
# revealed -> reveal
# entered -> enter
# run -> run
# disabled -> disable
# applying -> apply
# using -> use
# locked -> lock
# stated -> state
# slow -> slow
# control -> control
# find -> find
# write -> write
# start -> start
# view -> view
# see -> see
# begin -> begin
# continue -> continue
# issued -> issue
# following -> follow
# announced -> announce
# wish -> wish
# make -> make
# known -> know
# passed -> pass
# admitted -> admit
# following -> follow
# fined -> fine
# posted -> post
# parked -> park
# removed -> remove
# captured -> capture
# sent -> send
# forbidden -> forbid
# provide -> provide
# involves -> involve
# inspired -> inspire
# study -> study
# opposed -> oppose
# munching -> munch
# eats -> eat
# aphid -> aphid
# joined -> join
# estimates -> estimate
# attributed -> attribute
# saying -> say
# walk -> walk
# evaluated -> evaluate
# released -> release
# targeted -> target
# abandoned -> abandon
# collect -> collect
# sent -> send
# sorted -> sort
# exported -> export
# burned -> burn
# introduced -> introduce
# add -> add
# coloring -> color
# celebrate -> celebrate
# charged -> charge
# indicated -> indicate
# charged -> charge
# described -> describe
# was -> be
# found -> find
# told -> tell
# said -> say
# avoid -> avoid
# attended -> attend
# said -> say
# represent -> represent
# clad -> clothe
# honor -> honor
# defend -> defend
# seems -> seem
# collect -> collect
# keep -> keep
# stop -> stop
# infect -> infect
# got -> get
# nailed -> nail
# naming -> name
# rose -> rise
# marking -> mark
# stalled -> stall
# run -> run
# said -> say
# started -> start
# killed -> kill
# transported -> transport
# underwent -> underwent
# listed -> list
# became -> become
# wrote -> write
# advocated -> advocate
# returning -> return
# walk -> walk
# died -> die
# means -> mean
# consider -> consider
# said -> say
# turn -> turn
# lost -> lose
# helped -> help
# shape -> shape
# achieved -> achieve
# said -> say
# had -> have
# going -> go
# call -> call
# stealing -> steal
# Following -> follow
# Exiting -> exit
# echoed -> echo
# gave -> give
# adding -> add
# agreed -> agree
# put -> put
# takes -> take
# told -> tell
# parked -> park
# responding -> respond
# pictured -> picture
# involved -> involve
# led -> lead
# produced -> produce
# nests -> nest
# foraging -> forage
# spotted -> spot
# formed -> form
# want -> want
# treated -> treat
# moved -> move
# want -> want
# continue -> continue
# playing -> play
# win -> win
# considered -> consider
# used -> use
# form -> form
# located -> locate
# fined -> fine
# posting -> post
# stop -> stop
# leave -> leave
# die -> die
# building -> build
# set -> set
# include -> include
# told -> tell
# written -> write
# said -> say
# released -> release
# tweeted -> tweet
# 's -> be
# described -> describe
# sees -> see
# attacking -> attack
# building -> build
# told -> tell
# fined -> fine
# posting -> post
# parked -> park
# reserved -> reserve
# handicapped -> handicap
# says -> say
# repeated -> repeat
# including -> include
# retracting -> retract
# lying -> lie
# has -> have
# won -> win
# Manning -> man
# views -> view
# prohibits -> prohibit
# jeopardize -> jeopardize
# protected -> protect
# called -> call
# replace -> replace
# saying -> say
# enacted -> enact
# expressed -> express
# happen -> happen
# covered -> cover
# living -> live
# living -> live
# detained -> detain
# went -> go
# tweeted -> tweet
# describe -> describe
# lost -> lose
# included -> include
# tasked -> task
# providing -> provide
# backed -> back
# quell -> quell
# threatens -> threaten
# according -> accord
# authorised -> authorise
# annexed -> annex
# medicating -> medicate
# agreed -> agree
# saying -> say
# loading -> load
# began -> begin
# says -> say
# continue -> continue
# attracted -> attract
# - -> -
# enacting -> enact
# stops -> stop
# released -> release
# stopped -> stop
# says -> say
# sold -> sell
# began -> begin
# arriving -> arrive
# According -> accord
# said -> say
# required -> require
# do -> do
# taken -> take
# is -> be
# said -> say
# saying -> say
# released -> release
# pointed -> point
# gone -> go
# acknowledged -> acknowledge
# fled -> flee
# sought -> seek
# made -> make
# undermine -> undermine
# said -> say
# wished -> wish
# guarantee -> guarantee
# sought -> seek
# doing -> do
# noted -> note
# do -> do
# said -> say
# exploded -> explode
# pictured -> picture
# accused -> accuse
# averaged -> average
# granted -> grant
# aims -> aim
# help -> help
# address -> address
# Found -> find
# calling -> call
# said -> say
# resolved -> resolve
# televised -> televise
# said -> say
# accused -> accuse
# arrested -> arrest
# gone -> go
# lasted -> last
# lasted -> last
# went -> go
# remaining -> remain
# Using -> use
# asked -> ask
# assist -> assist
# denied -> deny
# executed -> execute
# published -> publish
# claims -> claim
# executed -> execute
# offered -> offer
# says -> say
# \ -> \
# cooperate -> cooperate
# sent -> send
# sentenced -> sentence
# found -> find
# left -> leave
# reported -> report
# struggling -> struggle
# breathe -> breathe
# screamed -> scream
# said -> say
# ordered -> order
# including -> include
# had -> have
# projected -> project
# celebrate -> celebrate
# seized -> seize
# leading -> lead
# began -> begin
# resulted -> result
# killed -> kill
# disembowelled -> disembowel
# According -> accord
# ceased -> cease
# achieving -> achieve
# entailing -> entail
# indicate -> indicate
# preoccupied -> preoccupy
# tweeted -> tweet
# carve -> carve
# running -> run
# see -> see
# have -> have
# makes -> make
# gives -> give
# do -> do
# called -> call
# appear -> appear
# chose -> choose
# use -> use
# see -> see
# sanctions -> sanction
# formed -> form
# investigate -> investigate
# said -> say
# died -> die
# have -> have
# goes -> go
# documented -> document
# called -> call
# named -> name
# sentenced -> sentence
# identified -> identify
# fled -> flee
# mandated -> mandate
# requires -> require
# enter -> enter
# proceeding -> proceed
# stated -> state
# plan -> plan
# raise -> raise
# stated -> state
# raise -> raise
# seen -> see
# contacted -> contact
# policing -> police
# awaiting -> await
# agreed -> agree
# joined -> join
# ended -> end
# calls -> call
# indicated -> indicate
# views -> view
# do -> do
# According -> accord
# houses -> house
# identified -> identify
# reported -> report
# fired -> fire
# conducted -> conduct
# scored -> score
# winning -> win
# shows -> show
# exposed -> expose
# primed -> prime
# stalk -> stalk
# pounce -> pounce
# bite -> bite
# objects -> object
# remains -> remain
# averaging -> average
# led -> lead
# consider -> consider
# according -> accord
# responded -> respond
# say -> say
# made -> make
# puts -> put
# According -> accord
# quoting -> quote
# placed -> place
# told -> tell
# prepare -> prepare
# says -> say
# failed -> fail
# put -> put
# died -> die
# fell -> fall
# suffered -> suffer
# criticized -> criticize
# ran -> run
# accusing -> accuse
# abusing -> abuse
# says -> say
# called -> call
# said -> say
# ’s -> ’
# considered -> consider
# reports -> report
# rolled -> roll
# responding -> respond
# said -> say
# reassured -> reassure
# looked -> look
# held -> hold
# applying -> apply
# determined -> determine
# assist -> assist
# stood -> stand
# demanding -> demand
# leave -> leave
# cited -> cite
# had -> have
# believe -> believe
# based -> base
# believe -> believe
# passed -> pass
# discredited -> discredit
# liked -> like
# switch -> switch
# According -> accord
# taken -> take
# disposed -> dispose
# features -> feature
# ran -> run
# said -> say
# failed -> fail
# commute -> commute
# endangered -> endanger
# leaking -> leak
# set -> set
# rotate -> rotate
# became -> become
# seeping -> seep
# responding -> respond
# found -> find
# occurred -> occur
# flooded -> flood
# issued -> issue
# concluded -> conclude
# hacked -> hack
# belonging -> belong
# said -> say
# seek -> seek
# retaining -> retain
# started -> start
# collaborating -> collaborate
# growing -> grow
# said -> say
# vanishing -> vanish
# closed -> close
# remain -> remain
# announced -> announce
# released -> release
# announcing -> announce
# suffered -> suffer
# fallen -> fall
# include -> include
# crashed -> crash
# take -> take
# killing -> kill
# attracted -> attract
# researching -> research
# standing -> stand
# hurting -> hurt
# According -> accord
# waited -> wait
# announcing -> announce
# went -> go
# call -> call
# crashes -> crash
# crashed -> crash
# made -> make
# legalise -> legalise
# thought -> think
# turn -> turn
# shared -> share
# faces -> face
# joins -> join
# done -> do
# had -> have
# containing -> contain
# conducted -> conduct
# killed -> kill
# according -> accord
# chanted -> chant
# won -> win
# criticizes -> criticize
# alleged -> allege
# labeling -> label
# raped -> rape
# housed -> house
# According -> accord
# lose -> lose
# repealed -> repeal
# says -> say
# repealing -> repeal
# replacing -> replace
# say -> say
# collected -> collect
# suspected -> suspect
# killed -> kill
# held -> hold
# dies -> die
# known -> know
# killed -> kill
# alleged -> allege
# shot -> shoot
# killed -> kill
# conducting -> conduct
# opened -> open
# has -> have
# shows -> show
# branding -> brand
# locate -> locate
# healing -> heal
# retaliated -> retaliate
# firing -> fire
# According -> accord
# reported -> report
# interviewed -> interview
# deemed -> deem
# say -> say
# went -> go
# represented -> represent
# said -> say
# appeal -> appeal
# expresses -> express
# participate -> participate
# aligns -> align
# scheduled -> schedule
# seeking -> seek
# seen -> see
# calls -> call
# appointed -> appoint
# used -> use
# engineered -> engineer
# target -> target
# alter -> alter
# completed -> complete
# named -> name
# saw -> see
# parked -> park
# snapped -> snap
# waited -> wait
# feeling -> feel
# left -> leave
# losing -> lose
# feeling -> feel
# protected -> protect
# came -> come
# arrested -> arrest
# suspected -> suspect
# smuggling -> smuggle
# raped -> rape
# have -> have
# cost -> cost
# move -> move
# covers -> cover
# attended -> attend
# crossed -> cross
# said -> say
# harbor -> harbor
# hopes -> hope
# receive -> receive
# stated -> state
# seek -> seek
# seek -> seek
# relates -> relate
# known -> know
# seen -> see
# arrested -> arrest
# charged -> charge
# receiving -> receive
# denounced -> denounce
# stating -> state
# endangered -> endanger
# chose -> choose
# laced -> lace
# avoided -> avoid
# joined -> join
# state -> state
# resembled -> resemble
# resulted -> result
# trained -> train
# according -> accord
# working -> work
# crushed -> crush
# triggered -> trigger
# struck -> strike
# means -> mean
# denies -> deny
# said -> say
# set -> set
# rotate -> rotate
# found -> find
# said -> say
# took -> take
# crashed -> crash
# prohibits -> prohibit
# jeopardize -> jeopardize
# cited -> cite
# said -> say
# involved -> involve
# do -> do
# occurred -> occur
# pictured -> picture
# acknowledges -> acknowledge
# know -> know
# accused -> accuse
# structure -> structure
# \ -> \
# involved -> involve
# medicate -> medicate
# pronounced -> pronounce
# said -> say
# declare -> declare
# served -> serve
# worked -> work
# worked -> work
# dispatched -> dispatch
# command -> command
# destroy -> destroy
# stop -> stop
# prepare -> prepare
# added -> add
# say -> say
# knowing -> know
# racing -> race
# said -> say
# were -> be
# reported -> report
# continued -> continue
# change -> change
# established -> establish
# shared -> share
# put -> put
# According -> accord
# reported -> report
# requested -> request
# angered -> anger
# returned -> return
# find -> find
# changed -> change
# excluded -> exclude
# excluded -> exclude
# started -> start
# broadcast -> broadcast
# tells -> tell
# medicating -> medicate
# evolved -> evolve
# fight -> fight
# experience -> experience
# performed -> perform
# appeared -> appear
# see -> see
# signing -> sign
# said -> say
# ' -> '
# m -> m
# playing -> play
# Spending -> spend
# scored -> score
# netted -> net
# seeking -> seek
# making -> make
# end -> end
# agreed -> agree
# saying -> say
# see -> see
# come -> come
# replace -> replace
# has -> have
# weaken -> weaken
# says -> say
# have -> have
# make -> make
# fitted -> fit
# expose -> expose
# said -> say
# turn -> turn
# reported -> report
# began -> begin
# reported -> report
# say -> say
# starved -> starve
# suffocated -> suffocate
# stripped -> strip
# exposed -> expose
# beaten -> beat
# threatened -> threaten
# denied -> deny
# read -> read
# decided -> decide
# release -> release
# go -> go
# affected -> affect
# die -> die
# ingesting -> ingest
# includes -> include
# infected -> infect
# die -> die
# obtained -> obtain
# have -> have
# given -> give
# ignore -> ignore
# dates -> date
# found -> find
# murdered -> murder
# decided -> decide
# hand -> hand
# said -> say
# said -> say
# know -> know
# taken -> take
# destroyed -> destroy
# seen -> see
# flying -> fly
# said -> say
# married -> marry
# died -> die
# collided -> collide
# attending -> attend
# remaining -> remain
# leading -> lead
# crashed -> crash
# sought -> seek
# hoped -> hope
# assist -> assist
# Responding -> respond
# found -> find
# found -> find
# estimated -> estimate
# abandoned -> abandon
# heard -> hear
# view -> view
# clearing -> clear
# needed -> need
# keep -> keep
# said -> say
# excited -> excite
# located -> locate
# associated -> associate
# allowed -> allow
# speak -> speak
# go -> go
# found -> find
# write -> write
# start -> start
# view -> view
# see -> see
# gone -> go
# smuggling -> smuggle
# returning -> return
# told -> tell
# have -> have
# return -> return
# desired -> desire
# continued -> continue
# quelled -> quell
# controlled -> control
# controlled -> control
# led -> lead
# crashed -> crash
# killing -> kill
# heading -> head
# keep -> keep
# trending -> trend
# alleges -> allege
# done -> do
# ensure -> ensure
# recognizes -> recognize
# accused -> accuse
# seek -> seek
# seek -> seek
# approached -> approach
# struck -> strike
# steered -> steer
# collided -> collide
# took -> take
# suffered -> suffer
# tether -> tether
# mentioned -> mention
# developed -> develop
# positioned -> position
# welcomes -> welcome
# headed -> head
# welcoming -> welcome
# expelled -> expel
# accused -> accuse
# sanctioned -> sanction
# have -> have
# get -> get
# know -> know
# say -> say
# shows -> show
# stimulating -> stimulate
# making -> make
# Following -> follow
# declared -> declare
# made -> make
# allowed -> allow
# wave -> wave
# encounter -> encounter
# said -> say
# noted -> note
# gives -> give
# talk -> talk
# died -> die
# mentioned -> mention
# called -> call
# added -> add
# trash -> trash
# suspected -> suspect
# wash -> wash
# expressed -> express
# repealing -> repeal
# worked -> work
# Manning -> man
# released -> release
# included -> include
# logs -> log
# including -> include
# firing -> fire
# suspected -> suspect
# held -> hold
# abused -> abuse
# know -> know
# try -> try
# work -> work
# build -> build
# have -> have
# nicknamed -> nickname
# said -> say
# living -> live
# promised -> promise
# move -> move
# have -> have
# go -> go
# told -> tell
# used -> use
# live -> live
# broke -> break
# changed -> change
# led -> lead
# regarding -> regard
# hunt -> hunt
# searching -> search
# wearing -> wear
# recorded -> record
# leaving -> leave
# exploded -> explode
# measure -> measure
# counted -> count
# reduced -> reduce
# infected -> infect
# varied -> vary
# depending -> depend
# set -> set
# turn -> turn
# jump -> jump
# hold -> hold
# bite -> bite
# trying -> try
# capture -> capture
# kill -> kill
# says -> say
# show -> show
# told -> tell
# changed -> change
# say -> say
# shows -> show
# control -> control
# biting -> bite
# jawed -> jaw
# vertebrates -> vertebrate
# 's -> be
# try -> try
# cut -> cut
# pits -> pit
# accused -> accuse
# trying -> try
# defend -> defend
# jeopardising -> jeopardise
# co -> co
# - -> -
# operated -> operate
# ended -> end
# explore -> explore
# left -> leave
# constructing -> construct
# said -> say
# described -> describe
# say -> say
# wounded -> wound
# chopped -> chop
# lobe -> lobe
# labelling -> label
# approves -> approve
# approved -> approve
# impeach -> impeach
# accused -> accuse
# conspiring -> conspire
# divert -> divert
# exposed -> expose
# says -> say
# violated -> violate
# seen -> see
# ' -> '
# m -> m
# put -> put
# continue -> continue
# investigate -> investigate
# said -> say
# await -> await
# deciding -> decide
# launch -> launch
# face -> face
# moves -> move
# refused -> refuse
# impeach -> impeach
# broadened -> broaden
# served -> serve
# died -> die
# Continuing -> continue
# added -> add
# said -> say
# said -> say
# cease -> cease
# made -> make
# saw -> see
# runs -> run
# announced -> announce
# flew -> fly
# According -> accord
# speaking -> speak
# feel -> feel
# said -> say
# called -> call
# refused -> refuse
# return -> return
# encouraging -> encourage
# resulted -> result
# killed -> kill
# beheaded -> behead
# dismembered -> dismember
# removed -> remove
# featuring -> feature
# inspected -> inspect
# own -> own
# means -> mean
# excused -> excuse
# said -> say
# made -> make
# collected -> collect
# searching -> search
# charged -> charge
# began -> begin
# purchasing -> purchase
# built -> build
# has -> have
# accused -> accuse
# escorted -> escort
# arrested -> arrest
# thought -> think
# include -> include
# increasing -> increase
# say -> say
# left -> leave
# assisted -> assist
# visited -> visit
# says -> say
# backed -> back
# involved -> involve
# accepted -> accept
# describe -> describe
# appearing -> appear
# died -> die
# collapsing -> collapse
# delivering -> deliver
# appears -> appear
# have -> have
# reading -> read
# noted -> note
# appeared -> appear
# resemble -> resemble
# sported -> sport
# removed -> remove
# kills -> kill
# packed -> pack
# detonated -> detonate
# summonsed -> summons
# appear -> appear
# took -> take
# declare -> declare
# allege -> allege
# received -> receive
# dies -> die
# died -> die
# sustained -> sustain
# raised -> raise
# regarding -> regard
# refuted -> refute
# saying -> say
# make -> make
# sitting -> sit
# compared -> compare
# gets -> get
# find -> find
# species -> species
# evolved -> evolve
# attributed -> attribute
# began -> begin
# wanted -> want
# seems -> seem
# take -> take
# withholds -> withhold
# released -> release
# sitting -> sit
# spoke -> speak
# rejected -> reject
# infected -> infect
# have -> have
# left -> leave
# related -> relate
# recognize -> recognize
# published -> publish
# report -> report
# accused -> accuse
# murdering -> murder
# refused -> refuse
# stop -> stop
# arrested -> arrest
# following -> follow
# adding -> add
# measured -> measure
# using -> use
# claims -> claim
# have -> have
# beating -> beat
# adds -> add
# remains -> remain
# reported -> report
# added -> add
# formed -> form
# disputed -> dispute
# attended -> attend
# asked -> ask
# shared -> share
# deterred -> deter
# announced -> announce
# join -> join
# made -> make
# modified -> modify
# awarded -> award
# felt -> feel
# disrespected -> disrespect
# mistreated -> mistreat
# covered -> cover
# known -> know
# associated -> associate
# suggested -> suggest
# associated -> associate
# hunting -> hunt
# elected -> elect
# Following -> follow
# worked -> work
# retiring -> retire
# convicted -> convict
# including -> include
# acquitted -> acquit
# aiding -> aid

# %% [markdown]
# # 5. Named Entity Recognition
#
# Analyze the `named entities` in the *first five sentences*. Are they identified correctly? If not, explain your answer and propose a better decision

# %%
def ner(text):
    
    for ent in text.ents:
        print(ent.text, ent.label_)

# %%
ner(doc)

"""
three , eight DATE
ten years DATE
eighteen-month-old DATE
ROS GPE
third ORDINAL
three CARDINAL
\ ORG
"""
# Out:
# three , eight DATE
# ten years DATE
# eighteen-month-old DATE
# ROS GPE
# third ORDINAL
# three CARDINAL
# \ ORG
# Virginia Álvarez PERSON
# US GPE
# Poland GPE
# 2015 DATE
# Operation Atlantic Resolve ORG
# Everson PERSON
# Fox News ORG
# \ ORG
# Title 11 LAW
# the High Court ORG
# South Korea GPE
# about 80 CARDINAL
# Yeoncheon ORG
# at least one CARDINAL
# 170 tonnes QUANTITY
# One CARDINAL
# 34 CARDINAL
# ten CARDINAL
# Austria GPE
# Serbia GPE
# Oksana GPE
# two CARDINAL
# Ukraine GPE
# mid-December DATE
# France GPE
# Thursday DATE
# Austria GPE
# Robben PERSON
# Bayern German NORP
# Bayern Munich ORG
# yesterday DATE
# Dutch NORP
# Arjen Robben PERSON
# one CARDINAL
# June 2018 DATE
# Anastasia Slonina PERSON
# Moscow GPE
# Teatr.doc ORG
# Pavlensky PERSON
# Oksana ORG
# Bos PERSON
# the University of Copenhagen ORG
# Hungary GPE
# 72 hours TIME
# Bianchi PERSON
# Philippe PERSON
# daily DATE
# Next week DATE
# January 24 DATE
# the Supreme Court ORG
# Article 50 LAW
# Brexit PERSON
# Parliament ORG
# Maldives ORG
# Malaysian NORP
# Hishamuddin Hussein PERSON
# three CARDINAL
# 239 CARDINAL
# Bianchi PERSON
# Republican NORP
# January 27 DATE
# NBC News ORG
# Last month DATE
# US GPE
# 35 CARDINAL
# Russian NORP
# Russian NORP
# Everson PERSON
# FEC ORG
# Israel GPE
# Assaf Harofe PERSON
# Israel GPE
# May PERSON
# Britain GPE
# EU ORG
# British NORP
# Britain GPE
# the European Court of Justice ORG
# American NORP
# \ ORG
# Mike Pence PERSON
# Gripen ORG
# around 9:30 am TIME
# 0230 DATE
# Allerton PERSON
# Estonia GPE
# Latvia GPE
# Lithuania GPE
# Romania GPE
# Bulgaria GPE
# Hungary GPE
# Szatkowski PERSON
# Polish NORP
# Russia GPE
# Polish NORP
# last month DATE
# Saturday DATE
# yesterday DATE
# May DATE
# Britain GPE
# EU ORG
# a couple of seconds TIME
# Amnesty International PERSON
# \ ORG
# Pongsak GPE
# Semachai ORG
# today DATE
# 26 CARDINAL
# Braunau GPE
# Inn PERSON
# Austria GPE
# Russia GPE
# 63-year-old DATE
# Choe ORG
# Supreme ORG
# Kim Jong-un PERSON
# two CARDINAL
# five CARDINAL
# August DATE
# Wilson ORG
# second ORDINAL
# Mid-Ohio Sports Car Course EVENT
# Earlier this week DATE
# 4,000 CARDINAL
# Poland GPE
# Poland GPE
# Germany GPE
# about two weeks DATE
# Bianchi PERSON
# second ORDINAL
# Africans NORP
# first ORDINAL
# 1994 DATE
# San Marino Grand Prix EVENT
# Ayrton Senna PERSON
# Johanna Mikl-Leitner PERSON
# European Union ORG
# North Eastern LOC
# Indira Gandhi Regional Institute of Health and Medical Sciences ORG
# 142 CARDINAL
# Russia GPE
# this year DATE
# one CARDINAL
# Pyotr Pavlensky PERSON
# Pussy Riot PERSON
# the next couple of years DATE
# the American Red Cross ORG
# Indiana GPE
# Mitch Daniels PERSON
# Antoni Macierewicz PERSON
# years DATE
# July 1 DATE
# Matt O'Brien PERSON
# The Washington Post ORG
# 1 % PERCENT
# about $ 32,820 MONEY
# the Tax Policy Center ORG
# Kecskemet PRODUCT
# at least one CARDINAL
# CIA ORG
# two weeks earlier DATE
# Russian NORP
# U.S. GPE
# Republican NORP
# Democratic NORP
# Russian NORP
# Poland GPE
# Lithuania GPE
# Adnan PERSON
# over 50 days DATE
# the last couple of weeks DATE
# Independent ORG
# first ORDINAL
# NATO ORG
# Warsaw GPE
# last year DATE
# Sweden GPE
# approximately 115 km QUANTITY
# 70 miles QUANTITY
# Stockholm GPE
# WDBJ ORG
# Jeffrey Marks PERSON
# CBS News ORG
# Flanagan PERSON
# \ ORG
# Jim O'Sullivan PERSON
# High Frequency Economics ORG
# New York GPE
# Operation Atlantic Resolve ORG
# Abrams PRODUCT
# Bradley Fighting Vehicles PERSON
# Paladin PERSON
# first ORDINAL
# Anna Merlan PERSON
# Anthony Taylor PERSON
# the Associated Press ORG
# Trump PERSON
# U.S. GPE
# the U.S. Disciplinary Barracks ORG
# Fort Leavenworth FAC
# Kansas GPE
# 2016 DATE
# months DATE
# Thai NORP
# six year DATE
# \ ORG
# \ ORG
# North Korea GPE
# 48 hours TIME
# Vabbinfaru ORG
# Police ORG
# Mohamed Ibrahim PERSON
# Fehendhoo Island LOC
# Haveeru Daily ORG
# jargon ORG
# the day DATE
# Kudahuvadhoo ORG
# the Indian Ocean LOC
# Mark Meadows PERSON
# North Carolina GPE
# Thailand GPE
# at least 20 CARDINAL
# at least eight CARDINAL
# 100 CARDINAL
# ACT Airlines ORG
# December DATE
# yesterday DATE
# 71 CARDINAL
# Dmitry Peskov PERSON
# Putin PERSON
# At least fifty CARDINAL
# Bishkek GPE
# year DATE
# Brazilian NORP
# Michel Temer PERSON
# Reuters ORG
# yesterday DATE
# nearly thirty CARDINAL
# 2018 DATE
# \ ORG
# five CARDINAL
# second ORDINAL
# first ORDINAL
# Trump ORG
# Martin PERSON
# Dozens CARDINAL
# Bryce Williams ' PERSON
# Twitter PRODUCT
# Facebook PRODUCT
# several hours TIME
# August 27 DATE
# millions of pounds MONEY
# more than 24 hours TIME
# ROS GPE
# Victory Lane PERSON
# first ORDINAL
# Justin PERSON
# \ ORG
# Flight MH370 PRODUCT
# IRS ORG
# 2003 DATE
# 2007 DATE
# the George W. Bush administration FAC
# 2013 DATE
# Marussia F1 PERSON
# the following year DATE
# 2014 DATE
# Monaco Grand Prix EVENT
# Marussia GPE
# first ORDINAL
# ninth ORDINAL
# Lin PERSON
# Today DATE
# Congress ORG
# Thailand GPE
# Hat Yai International Airport FAC
# Songkhla​ GPE
# Thailand GPE
# this morning TIME
# Children 's Day EVENT
# Wilson PERSON
# Formula One ORG
# Champ PRODUCT
# the 2015 season DATE
# Andretti ORG
# seven CARDINAL
# two CARDINAL
# Thai NORP
# Thailand GPE
# \ ORG
# Agence France Presse ORG
# Rio de Janeiro PERSON
# O Globo ORG
# Comando Vermelho PERSON
# Hungary GPE
# Serbian NORP
# Syria GPE
# EU ORG
# Flanagan PERSON
# This week DATE
# Obama PERSON
# Oscar Lopez Rivera ORG
# Puerto Rican NORP
# the 1970s DATE
# 1980s DATE
# James E. Cartwright PERSON
# Marine NORP
# White House ORG
# FBI ORG
# over two hundred CARDINAL
# Yesterday DATE
# some eight feet QUANTITY
# two feet QUANTITY
# about 2.4 CARDINAL
# Baa Atoll PERSON
# Fehendhoo ORG
# Fulhahdhoo PRODUCT
# the past few days DATE
# Żagań GPE
# Polish NORP
# Beata Szydło PERSON
# Defence ORG
# Antoni Macierewicz PERSON
# tomorrow DATE
# Nigerian NORP
# dozens CARDINAL
# Nigerian Air Force ORG
# yesterday DATE
# Nigerian NORP
# Rann , Borno State ORG
# South Korea 's GPE
# Ministry of Unification ORG
# Reuters ORG
# BBC ORG
# Choe PERSON
# December DATE
# Fox News ORG
# Title 11 LAW
# one CARDINAL
# July 27 DATE
# one percent PERCENT
# Bush PERSON
# Republican NORP
# Martin PERSON
# the New Hampshire Primary EVENT
# Iowa Caucus ORG
# Alexander Hamilton PERSON
# U.S. GPE
# Greece GPE
# CNN ORG
# PCC ORG
# Sindicato ORG
# the Republican Party 's ORG
# May DATE
# Thursday DATE
# Hungary GPE
# C-130 PRODUCT
# At least seven CARDINAL
# over 100 CARDINAL
# dozens CARDINAL
# Ahmedabad ORG
# Polish NORP
# Wilson ORG
# MH370 WORK_OF_ART
# Kuala Lumpur GPE
# Malaysia GPE
# Beijing GPE
# China GPE
# March 8 , 2014 DATE
# US GPE
# Barack Obama PERSON
# Russian NORP
# Ukraine GPE
# 2014 DATE
# Crimea GPE
# Martin PERSON
# U.S. GPE
# Barack Obama PERSON
# the Democratic Party ORG
# 1988 DATE
# the Republican Party ORG
# 2000 DATE
# 2012 DATE
# Obamas PERSON
# Bidens GPE
# seventeen CARDINAL
# 6 CARDINAL
# Fox News ORG
# Martin PERSON
# eighteenth ORDINAL
# second ORDINAL
# NASA ORG
# Eugene Cernan PERSON
# 82 CARDINAL
# Eugene Cernan PERSON
# NASA ORG
# Moon PERSON
# Monday DATE
# 82 DATE
# German NORP
# 2009 DATE
# Spanish NORP
# Real Madrid ORG
# Gujurat GPE
# 2002 DATE
# about a thousand CARDINAL
# \ ORG
# America GPE
# US GPE
# Paul James PERSON
# US GPE
# Poland GPE
# Neusiedl PERSON
# Parndorf NORP
# Parndorf NORP
# Two CARDINAL
# Médecins Sans Frontières ORG
# 50 CARDINAL
# Russian NORP
# Alexei Mechkov PERSON
# European NORP
# US GPE
# Balkans LOC
# every nine months DATE
# 12:08 pm TIME
# 0508 DATE
# five kilometers QUANTITY
# a couple of minutes later TIME
# Fernando Portillo ORG
# Koh Tao PERSON
# Green PERSON
# Fairfax GPE
# around 1:30 PM TIME
# 1730 DATE
# Indian NORP
# seven day DATE
# Kalam PERSON
# the American Red Cross ORG
# Indiana GPE
# Mitch Daniels PERSON
# the Korean People 's Army ORG
# 48 hours TIME
# KCNA ORG
# \ PERSON
# The air force WORK_OF_ART
# twelve CARDINAL
# UK GPE
# Thailand GPE
# no more than 100 million years MONEY
# Agus Supriatna PERSON
# the Air Force ORG
# Russia GPE
# US GPE
# August 6 DATE
# Fox News ORG
# Republican NORP
# South Korea GPE
# 11-year DATE
# Nick Bos PERSON
# \ ORG
# \ ORG
# Nick Bos PERSON
# the University of Helsinki ORG
# Robben PERSON
# seven years DATE
# Munich GPE
# Robben GPE
# 82 CARDINAL
# 152 CARDINAL
# 23 CARDINAL
# 53 CARDINAL
# Lin PERSON
# Britain GPE
# the European Union ORG
# every year DATE
# Collins PERSON
# the end of this month DATE
# Bush PERSON
# \ PERSON
# Martin PERSON
# Bush PERSON
# Republican NORP
# \ ORG
# CIA ORG
# 2016 DATE
# Donald Trump PERSON
# Green PERSON
# Austria GPE
# \ PERSON
# ROS GPE
# Reactive Oxygen Species ORG
# ROS GPE
# September last year DATE
# Koh Tao beach PERSON
# SunOnline ORG
# Russian NORP
# Alexei Mechkov PERSON
# European NORP
# 1969 DATE
# Bobby Willis PERSON
# 1999 DATE
# 30 years DATE
# October 5 , 2014 DATE
# the Japanese Grand Prix ORG
# Suzuka Circuit ORG
# Adrian Sutil PERSON
# about twenty CARDINAL
# Karam GPE
# Metropolitan Police ORG
# Austrian NORP
# today DATE
# an estimated 20 CARDINAL
# 50 CARDINAL
# lorry PERSON
# The Royal Courts of Justice ORG
# London GPE
# Fed ORG
# September DATE
# \ PERSON
# Rob Martin PERSON
# Barclays ORG
# New York GPE
# Polish NORP
# Russia GPE
# two CARDINAL
# Tuesday DATE
# Conley ORG
# the Harris County Jail FAC
# Four CARDINAL
# Hungarian NORP
# 71 CARDINAL
# Austria GPE
# Four CARDINAL
# today DATE
# Hungary GPE
# Russia GPE
# Pavlensky ORG
# BBC ORG
# \ ORG
# Sunday DATE
# around 7:15 a.m. TIME
# PAG ORG
# Syria GPE
# Europe LOC
# AirAsia GPE
# the Java Sea LOC
# last December DATE
# the Maldives Police Service ORG
# the Maldives Civil Aviation Authority ORG
# \ PERSON
# Hewlett-Packard ORG
# New York GPE
# George Pataki PERSON
# Lindsey Graham PERSON
# Szydło ORG
# French NORP
# Bruno Le Roux PERSON
# Russia GPE
# Amazonas PERSON
# January 1 DATE
# at least 56 CARDINAL
# the day of the DATE
# Hyza LOC
# NASA ORG
# Finland GPE
# 32-year-old DATE
# Swedish NORP
# 2008 DATE
# twelve CARDINAL
# four CARDINAL
# Kecskemet GPE
# Hungary GPE
# at least two CARDINAL
# Crimea GPE
# Russia GPE
# Kalingrad GPE
# Thailand GPE
# French NORP
# François Hollande PERSON
# last week DATE
# two CARDINAL
# Koreas GPE
# mid-2000s DATE
# Evolution ORG
# Bos PERSON
# Yesterday DATE
# Indian NORP
# APJ Abdul Kalam PERSON
# the age of 83 DATE
# about 6:30 p.m. TIME
# 0000 CARDINAL
# today DATE
# UTC ORG
# Livable Planet Earth WORK_OF_ART
# the Indian Institute of Management Shillong ORG
# Meghalaya GPE
# India GPE
# One CARDINAL
# \ ORG
# \ ORG
# Malaysia Airlines ORG
# Earlier today TIME
# at least 50 CARDINAL
# Gao PERSON
# Mali PERSON
# this morning TIME
# Gao PERSON
# Mali PERSON
# one CARDINAL
# seven CARDINAL
# Maidstone Magistrates ' Court ORG
# February 17 DATE
# Malian NORP
# Ibrahim Boubacar Keita PERSON
# Twitter PRODUCT
# today DATE
# three days DATE
# Baldetti ORG
# Molina PERSON
# half CARDINAL
# Justin Wilson PERSON
# 37 Yesterday DATE
# 37-year old DATE
# IndyCar Series PRODUCT
# Justin Wilson PERSON
# Sunday DATE
# 500 CARDINAL
# Pocono Raceway FAC
# Wilson ORG
# 6 feet QUANTITY
# 3.5 inches QUANTITY
# 1.92 m QUANTITY
# Wilson ORG
# IndyCar Series PRODUCT
# Josef Newgarden PERSON
# \ PERSON
# Yonhap PERSON
# roughly 70 CARDINAL
# Kim Jong-un 's PERSON
# Kim Jong-il PERSON
# December 2011 DATE
# Conley PERSON
# UK GPE
# Thai NORP
# today DATE
# Green PERSON
# the High Court ORG
# London GPE
# two CARDINAL
# Thai NORP
# Beauveria GPE
# Krone ORG
# Burmese NORP
# Zaw Lin PERSON
# Wai Phyo ORG
# 22 CARDINAL
# David Miller PERSON
# 24 DATE
# Jersey GPE
# Hannah Witheridge PERSON
# 23 DATE
# England GPE
# Romania GPE
# ROS GPE
# CCTV ORG
# Pavlensky FAC
# Slonina GPE
# October 31 DATE
# US GPE
# 215,000 CARDINAL
# July DATE
# 5.3 % PERCENT
# US GPE
# 215,000 CARDINAL
# July DATE
# 2004 DATE
# the Kaesong Industrial Region FAC
# two CARDINAL
# The Royal Thai Air Force ORG
# Sunday DATE
# Bayern ORG
# 21-year-old DATE
# Niklas Süle LOC
# 26-year-old DATE
# Sebastian Rudy PERSON
# 1899 DATE
# Hoffenheim GPE
# July DATE
# fourth ORDINAL
# U.S. GPE
# the Medal of Freedom EVENT
# Conley PERSON
# one CARDINAL
# last year DATE
# Gujarat GPE
# more than twelve years DATE
# 17 CARDINAL
# Cernan PERSON
# Apollo ORG
# NASA ORG
# Navy ORG
# 1976 DATE
# 2013 DATE
# 22 CARDINAL
